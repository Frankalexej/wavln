# %% [markdown]
# # New Run
# A_01: Copy from SL_D_E_4.ipynb. Fixed the problem as we have found in normalization. This time we normalize over the whole course.
#
#
# A_05: This time we resume using two linear layers, one before RNN and one after. IN this way we make the last linear layer of both encoder and decoder
# a pure linear layer without other components.
#
# A_07: This time we delete the attention part of the decoder and make it completely autoregressive. See how it performs.
#
# A_08: Restore the inclusion of attention mechanism, and set the first input to decoder to all zero.

# %% [markdown]
# # Sequence Learning - Direct - English
# Version 1: In this version we make the model "simple": make the encoder RNN into normal RNN first and try to see the result.
# Version 2: Learning is not very much. Following Dr Coupe's advice we try simpler model structure.
# Version 3: A simple trial training with Mel spectrogram instead of MFCC.
# Version 4: try to enlarge the hidden dimensions so that we might still make sense of the hidden representation.

# %%
import torch
import torchaudio
from torch import nn
import torch.nn.functional as F
from torch.nn.utils.rnn import pad_sequence, pack_sequence
from torch import optim
from torch.utils.data import Dataset, DataLoader, random_split
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import pickle
from datetime import datetime
import random
from torchinfo import summary

# %%
from model import TwoLinPhxLearner as TheLearner
from my_dataset import DS_Tools
from dataset import SeqDataset, MelTransform, Normalizer, DeNormalizer
from dataset import MelSpecTransformNewNew as TheTransform
from paths import *
from my_utils import *
from recorder import *
from loss import *
from padding import generate_mask_from_lengths_mat, mask_it

# %% [markdown]
# ### Dirs

# %%
model_save_dir = model_eng_save_dir
# random_data:phone_seg_random_path
# anno_data: phone_seg_anno_path

# random_log_path = phone_seg_random_log_path + "log.csv"
random_log_path = word_seg_anno_log_path
random_path = word_seg_anno_path
anno_log_path = phone_seg_anno_path

# %% [markdown]
# ### Constants

# %%
BATCH_SIZE = 128

INPUT_DIM = 64
OUTPUT_DIM = 64 

INTER_DIM_0 = 32
INTER_DIM_1 = 16
INTER_DIM_2 = 8

ENC_SIZE_LIST = [INPUT_DIM, INTER_DIM_0, INTER_DIM_1, INTER_DIM_2]
DEC_SIZE_LIST = [OUTPUT_DIM, INTER_DIM_0, INTER_DIM_1, INTER_DIM_2]

DROPOUT = 0.5

REC_SAMPLE_RATE = 16000
N_FFT = 400
N_MELS = 64

LOADER_WORKER = 16
# LOADER_WORKER = 0

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
recon_loss = nn.MSELoss(reduction='none')
masked_recon_loss = MaskedLoss(recon_loss)
model_loss = masked_recon_loss

model = TheLearner(enc_size_list=ENC_SIZE_LIST, dec_size_list=DEC_SIZE_LIST, num_layers=2)
model.to(device)
optimizer = optim.Adam(model.parameters(), lr=1e-3)

# %%
# # initialize model weights
# def init_weights(m):
#     if isinstance(m, nn.Linear):
#         torch.nn.init.orthogonal_(m.weight)
#         m.bias.data.fill_(0.01)
#     if isinstance(m, nn.LSTM): 
#         for name, p in m.named_parameters():
#             if "weight" in name: 
#                 nn.init.orthogonal_(p)
#             elif "bias" in name: 
#                 nn.init.constant_(p, 0)

# model.apply(init_weights)

# %%
model_parameters = filter(lambda p: p.requires_grad, model.parameters())
params = sum([np.prod(p.size()) for p in model_parameters])

# %%
params
# Out:
# 12512

# %%
# Just for keeping records of training hists. 
# ts = "0918192113"
stop_epoch = "149"
ts = str(get_timestamp())
save_txt_name = "train_txt_{}.hst".format(ts)
save_trainhist_name = "train_hist_{}.hst".format(ts)

save_valhist_name = "val_hist_{}.hst".format(ts)

# %%
train_losses = LossRecorder(model_save_dir + save_trainhist_name)

valid_losses = LossRecorder(model_save_dir + save_valhist_name)

text_hist = HistRecorder(model_save_dir + save_txt_name)

# %%
READ = False
# READ = True

# %%
if READ: 
    valid_losses.read()
    train_losses.read()

    model_raw_name = "PT_{}_{}_full".format(ts, stop_epoch)
    model_name = model_raw_name + ".pt"
    model_path = os.path.join(model_save_dir, model_name)
    state = torch.load(model_path)

    model.load_state_dict(state)
    model.to(device)

# %%
model
# Out:
# TwoLinPhxLearner(
#   (encoder): LRLEncoder(
#     (lin_1): LinearPack(
#       (linear): Linear(in_features=64, out_features=32, bias=True)
#       (layernorm): LayerNorm((32,), eps=1e-05, elementwise_affine=True)
#       (relu): Tanh()
#       (dropout): Dropout(p=0.5, inplace=False)
#     )
#     (rnn): LSTM(32, 16, num_layers=2, batch_first=True)
#     (lin_2): Linear(in_features=16, out_features=8, bias=True)
#   )
#   (decoder): LRALDecoder(
#     (lin_1): LinearPack(
#       (linear): Linear(in_features=64, out_features=32, bias=True)
#       (layernorm): LayerNorm((32,), eps=1e-05, elementwise_affine=True)
#       (relu): Tanh()
#       (dropout): Dropout(p=0.5, inplace=False)
#     )
#     (rnn): LSTM(32, 8, num_layers=2, batch_first=True)
#     (attention): ScaledDotProductAttention(
#       (w_q): Linear(in_features=8, out_features=8, bias=True)
#       (w_k): Linear(in_features=8, out_features=8, bias=True)
#       (w_v): Linear(in_features=8, out_features=8, bias=True)
#     )
#     (lin_3): Linear(in_features=8, out_features=64, bias=True)
#   )
# )

# %%
# mytrans = MelSpecTransform(sample_rate=REC_SAMPLE_RATE, n_fft=N_FFT, n_mels=N_MELS)
# mytrans = nn.Sequential(
#     MelTransform(sample_rate=REC_SAMPLE_RATE, n_fft=N_FFT, n_mels=N_MELS),
#     # torchaudio.transforms.AmplitudeToDB(stype="power", top_db=80), 
#     Normalizer(Normalizer.norm_strip_minmax)
# )
mytrans = TheTransform(sample_rate=REC_SAMPLE_RATE, n_fft=N_FFT, n_mels=N_MELS, normalizer=Normalizer.norm_mvn, denormalizer=DeNormalizer.norm_mvn)
ds = SeqDataset(random_path, os.path.join(random_log_path, "log.csv"), transform=mytrans)

test = False
if test: 
    use_len = int(0.1 * len(ds))
    remain_len = len(ds) - use_len

    # Randomly split the dataset into train and validation sets
    ds, remain_ds = random_split(ds, [use_len, remain_len])


if READ: 
    valid_ds_indices = DS_Tools.read_indices(os.path.join(model_save_dir, "valid_ds_{}.pkl".format(ts)))
    all_indices = list(range(len(ds)))
    train_ds_indices = list(set(all_indices).difference(set(valid_ds_indices)))

    train_ds = torch.utils.data.Subset(ds, train_ds_indices)
    valid_ds = torch.utils.data.Subset(ds, valid_ds_indices)
else: 
    train_len = int(0.8 * len(ds))
    valid_len = len(ds) - train_len

    # Randomly split the dataset into train and validation sets
    train_ds, valid_ds = random_split(ds, [train_len, valid_len])
    DS_Tools.save_indices(os.path.join(model_save_dir, "valid_ds_{}.pkl".format(ts)), valid_ds.indices)

train_loader = DataLoader(train_ds, batch_size=BATCH_SIZE, shuffle=True, num_workers=LOADER_WORKER, collate_fn=SeqDataset.collate_fn)
train_num = len(train_loader.dataset)

valid_loader = DataLoader(valid_ds, batch_size=BATCH_SIZE, shuffle=False, num_workers=LOADER_WORKER, collate_fn=SeqDataset.collate_fn)
valid_num = len(valid_loader.dataset)

# %%
len(train_loader)
# Out:
# 1776

# %%
# Load sample data from train_loader
sample_data = next(iter(valid_loader))
xx_pad, seg = sample_data
print(xx_pad.shape)
# Out:
# torch.Size([128, 69, 64])

# %%
# Set the random seed for reproducibility
# random.seed(101)
# Generate six random indices
random_indices = random.sample(range(len(xx_pad)), 6)
# random_indices = list(range(6, 12))

# Plot the spectrograms and mark the corresponding seg
fig, axes = plt.subplots(2, 3, figsize=(12, 8))
axes = axes.flatten()

for i, idx in enumerate(random_indices):
    spectrogram = xx_pad[idx]
    
    ax = axes[i]
    img = ax.imshow(spectrogram.T, aspect='auto', origin="lower")
    # ax.axvline(x=segment, color='red', linestyle='--')
    # ax.axvline(x=segment[1], color='red', linestyle='--')
    ax.set_title(f'Spectrogram')
    ax.set_xlabel('Time')
    ax.set_ylabel('Frequency')
plt.tight_layout()
plt.colorbar(img,ax=axes)
plt.show()

# %%
ts
# Out:
# '0122184732'

# %%
EPOCHS = 50
BASE = 0

# %%
def train(): 
    for epoch in range(BASE, BASE + EPOCHS):
        text_hist.print("Epoch {}".format(epoch))

        model.train()
        train_loss = 0.
        train_num = len(train_loader)    # train_loader
        for idx, (x, x_lens) in enumerate(train_loader):
            optimizer.zero_grad()
            y = x 
            
            x_mask = generate_mask_from_lengths_mat(x_lens, device=device)
            
            x = x.to(device)
            y = y.to(device)

            recon_x, attn_weight = model(x, x_lens, x_mask)

            loss = model_loss.get_loss(recon_x, y, x_mask)

            train_loss += loss.item()

            loss.backward()
            
            # torch.nn.utils.clip_grad_norm_(model.parameters(), clip_value)
            # 这个函数计算的是全局梯度范数
            # torch.nn.utils.clip_grad_norm(parameters=model.parameters(), max_norm=5, norm_type=2)
            torch.nn.utils.clip_grad_norm_(parameters=model.parameters(), max_norm=5, norm_type=2)
            # parameters: an iterable of Variables that will have gradients normalized
            # max_norm: max norm of the gradients(阈值设定)
            # norm_type: type of the used p-norm. Can be'inf'for infinity norm(定义范数类型)

            optimizer.step()

            if idx % 100 == 0:
                text_hist.print(f"Training loss {loss: .3f} in Step {idx}")

        train_losses.append(train_loss / train_num)
        text_hist.print(f"※※※Training loss {train_loss / train_num: .3f}※※※")

        last_model_name = "PT_{}_{}_full.pt".format(ts, epoch)
        torch.save(model.state_dict(), os.path.join(model_save_dir, last_model_name))
        text_hist.print("Training timepoint saved")

        model.eval()
        valid_loss = 0.
        valid_num = len(valid_loader)
        for idx, (x, x_lens) in enumerate(valid_loader):
            y = x    # extract MFCC-only data
            x_mask = generate_mask_from_lengths_mat(x_lens, device=device)
            
            x = x.to(device)
            y = y.to(device)

            recon_x, attn_weight = model(x, x_lens, x_mask)

            loss = model_loss.get_loss(recon_x, y, x_mask)

            valid_loss += loss.item()

            if idx % 50 == 0:
                text_hist.print(f"Valid loss {loss: .3f} in Step {idx}")

        valid_losses.append(valid_loss / valid_num)

        text_hist.print(f"※※※Valid loss {valid_loss / valid_num: .3f}※※※")

# %%
if __name__ == "__main__": 
    train()
# Out:
# Epoch 0
# Training loss  1.078 in Step 0
# Training loss  0.640 in Step 100
# Training loss  0.587 in Step 200
# Training loss  0.550 in Step 300
# Training loss  0.510 in Step 400
# Training loss  0.508 in Step 500
# Training loss  0.497 in Step 600
# Training loss  0.428 in Step 700
# Training loss  0.372 in Step 800
# Training loss  0.378 in Step 900
# Training loss  0.349 in Step 1000
# Training loss  0.314 in Step 1100
# Training loss  0.285 in Step 1200
# Training loss  0.290 in Step 1300
# Training loss  0.272 in Step 1400
# Training loss  0.261 in Step 1500
# Training loss  0.261 in Step 1600
# Training loss  0.254 in Step 1700
# ※※※Training loss  0.417※※※
# Training timepoint saved
# Valid loss  0.233 in Step 0
# Valid loss  0.238 in Step 50
# Valid loss  0.237 in Step 100
# Valid loss  0.268 in Step 150
# Valid loss  0.231 in Step 200
# Valid loss  0.227 in Step 250
# Valid loss  0.232 in Step 300
# Valid loss  0.237 in Step 350
# Valid loss  0.267 in Step 400
# ※※※Valid loss  0.237※※※
# Epoch 1
# Training loss  0.248 in Step 0
# Training loss  0.236 in Step 100
# Training loss  0.238 in Step 200
# Training loss  0.220 in Step 300
# Training loss  0.227 in Step 400
# Training loss  0.224 in Step 500
# Training loss  0.235 in Step 600
# Training loss  0.227 in Step 700
# Training loss  0.229 in Step 800
# Training loss  0.237 in Step 900
# Training loss  0.222 in Step 1000
# Training loss  0.221 in Step 1100
# Training loss  0.226 in Step 1200
# Training loss  0.221 in Step 1300
# Training loss  0.220 in Step 1400
# Training loss  0.209 in Step 1500
# Training loss  0.216 in Step 1600
# Training loss  0.212 in Step 1700
# ※※※Training loss  0.226※※※
# Training timepoint saved
# Valid loss  0.202 in Step 0
# Valid loss  0.210 in Step 50
# Valid loss  0.204 in Step 100
# Valid loss  0.226 in Step 150
# Valid loss  0.203 in Step 200
# Valid loss  0.196 in Step 250
# Valid loss  0.201 in Step 300
# Valid loss  0.208 in Step 350
# Valid loss  0.232 in Step 400
# ※※※Valid loss  0.206※※※
# Epoch 2
# Training loss  0.215 in Step 0
# Training loss  0.210 in Step 100
# Training loss  0.218 in Step 200
# Training loss  0.210 in Step 300
# Training loss  0.225 in Step 400
# Training loss  0.226 in Step 500
# Training loss  0.208 in Step 600
# Training loss  0.216 in Step 700
# Training loss  0.219 in Step 800
# Training loss  0.197 in Step 900
# Training loss  0.219 in Step 1000
# Training loss  0.223 in Step 1100
# Training loss  0.210 in Step 1200
# Training loss  0.221 in Step 1300
# Training loss  0.212 in Step 1400
# Training loss  0.233 in Step 1500
# Training loss  0.227 in Step 1600
# Training loss  0.226 in Step 1700
# ※※※Training loss  0.213※※※
# Training timepoint saved
# Valid loss  0.196 in Step 0
# Valid loss  0.205 in Step 50
# Valid loss  0.197 in Step 100
# Valid loss  0.219 in Step 150
# Valid loss  0.200 in Step 200
# Valid loss  0.192 in Step 250
# Valid loss  0.196 in Step 300
# Valid loss  0.203 in Step 350
# Valid loss  0.227 in Step 400
# ※※※Valid loss  0.201※※※
# Epoch 3
# Training loss  0.208 in Step 0
# Training loss  0.204 in Step 100
# Training loss  0.228 in Step 200
# Training loss  0.209 in Step 300
# Training loss  0.202 in Step 400
# Training loss  0.214 in Step 500
# Training loss  0.207 in Step 600
# Training loss  0.202 in Step 700
# Training loss  0.201 in Step 800
# Training loss  0.224 in Step 900
# Training loss  0.211 in Step 1000
# Training loss  0.212 in Step 1100
# Training loss  0.218 in Step 1200
# Training loss  0.208 in Step 1300
# Training loss  0.214 in Step 1400
# Training loss  0.214 in Step 1500
# Training loss  0.207 in Step 1600
# Training loss  0.211 in Step 1700
# ※※※Training loss  0.210※※※
# Training timepoint saved
# Valid loss  0.194 in Step 0
# Valid loss  0.203 in Step 50
# Valid loss  0.194 in Step 100
# Valid loss  0.216 in Step 150
# Valid loss  0.198 in Step 200
# Valid loss  0.190 in Step 250
# Valid loss  0.194 in Step 300
# Valid loss  0.201 in Step 350
# Valid loss  0.225 in Step 400
# ※※※Valid loss  0.199※※※
# Epoch 4
# Training loss  0.206 in Step 0
# Training loss  0.199 in Step 100
# Training loss  0.207 in Step 200
# Training loss  0.207 in Step 300
# Training loss  0.210 in Step 400
# Training loss  0.207 in Step 500
# Training loss  0.211 in Step 600
# Training loss  0.193 in Step 700
# Training loss  0.218 in Step 800
# Training loss  0.204 in Step 900
# Training loss  0.212 in Step 1000
# Training loss  0.212 in Step 1100
# Training loss  0.204 in Step 1200
# Training loss  0.209 in Step 1300
# Training loss  0.201 in Step 1400
# Training loss  0.208 in Step 1500
# Training loss  0.211 in Step 1600
# Training loss  0.200 in Step 1700
# ※※※Training loss  0.208※※※
# Training timepoint saved
# Valid loss  0.193 in Step 0
# Valid loss  0.202 in Step 50
# Valid loss  0.193 in Step 100
# Valid loss  0.214 in Step 150
# Valid loss  0.197 in Step 200
# Valid loss  0.190 in Step 250
# Valid loss  0.194 in Step 300
# Valid loss  0.201 in Step 350
# Valid loss  0.224 in Step 400
# ※※※Valid loss  0.198※※※
# Epoch 5
# Training loss  0.196 in Step 0
# Training loss  0.210 in Step 100
# Training loss  0.206 in Step 200
# Training loss  0.196 in Step 300
# Training loss  0.203 in Step 400
# Training loss  0.211 in Step 500
# Training loss  0.208 in Step 600
# Training loss  0.201 in Step 700
# Training loss  0.199 in Step 800
# Training loss  0.195 in Step 900
# Training loss  0.208 in Step 1000
# Training loss  0.204 in Step 1100
# Training loss  0.202 in Step 1200
# Training loss  0.208 in Step 1300
# Training loss  0.216 in Step 1400
# Training loss  0.203 in Step 1500
# Training loss  0.205 in Step 1600
# Training loss  0.204 in Step 1700
# ※※※Training loss  0.207※※※
# Training timepoint saved
# Valid loss  0.193 in Step 0
# Valid loss  0.202 in Step 50
# Valid loss  0.193 in Step 100
# Valid loss  0.213 in Step 150
# Valid loss  0.198 in Step 200
# Valid loss  0.190 in Step 250
# Valid loss  0.194 in Step 300
# Valid loss  0.201 in Step 350
# Valid loss  0.224 in Step 400
# ※※※Valid loss  0.198※※※
# Epoch 6
# Training loss  0.194 in Step 0
# Training loss  0.196 in Step 100
# Training loss  0.225 in Step 200
# Training loss  0.201 in Step 300
# Training loss  0.209 in Step 400
# Training loss  0.205 in Step 500
# Training loss  0.217 in Step 600
# Training loss  0.211 in Step 700
# Training loss  0.200 in Step 800
# Training loss  0.201 in Step 900
# Training loss  0.204 in Step 1000
# Training loss  0.213 in Step 1100
# Training loss  0.204 in Step 1200
# Training loss  0.214 in Step 1300
# Training loss  0.217 in Step 1400
# Training loss  0.205 in Step 1500
# Training loss  0.202 in Step 1600
# Training loss  0.209 in Step 1700
# ※※※Training loss  0.206※※※
# Training timepoint saved
# Valid loss  0.195 in Step 0
# Valid loss  0.203 in Step 50
# Valid loss  0.194 in Step 100
# Valid loss  0.214 in Step 150
# Valid loss  0.199 in Step 200
# Valid loss  0.191 in Step 250
# Valid loss  0.195 in Step 300
# Valid loss  0.202 in Step 350
# Valid loss  0.226 in Step 400
# ※※※Valid loss  0.200※※※
# Epoch 7
# Training loss  0.200 in Step 0
# Training loss  0.199 in Step 100
# Training loss  0.206 in Step 200
# Training loss  0.197 in Step 300
# Training loss  0.187 in Step 400
# Training loss  0.179 in Step 500
# Training loss  0.171 in Step 600
# Training loss  0.184 in Step 700
# Training loss  0.179 in Step 800
# Training loss  0.180 in Step 900
# Training loss  0.170 in Step 1000
# Training loss  0.183 in Step 1100
# Training loss  0.172 in Step 1200
# Training loss  0.190 in Step 1300
# Training loss  0.174 in Step 1400
# Training loss  0.182 in Step 1500
# Training loss  0.171 in Step 1600
# Training loss  0.186 in Step 1700
# ※※※Training loss  0.184※※※
# Training timepoint saved
# Valid loss  0.169 in Step 0
# Valid loss  0.174 in Step 50
# Valid loss  0.172 in Step 100
# Valid loss  0.189 in Step 150
# Valid loss  0.176 in Step 200
# Valid loss  0.163 in Step 250
# Valid loss  0.169 in Step 300
# Valid loss  0.175 in Step 350
# Valid loss  0.199 in Step 400
# ※※※Valid loss  0.175※※※
# Epoch 8
# Training loss  0.175 in Step 0
# Training loss  0.171 in Step 100
# Training loss  0.165 in Step 200
# Training loss  0.193 in Step 300
# Training loss  0.171 in Step 400
# Training loss  0.189 in Step 500
# Training loss  0.158 in Step 600
# Training loss  0.167 in Step 700
# Training loss  0.178 in Step 800
# Training loss  0.172 in Step 900
# Training loss  0.180 in Step 1000
# Training loss  0.189 in Step 1100
# Training loss  0.177 in Step 1200
# Training loss  0.176 in Step 1300
# Training loss  0.178 in Step 1400
# Training loss  0.184 in Step 1500
# Training loss  0.186 in Step 1600
# Training loss  0.180 in Step 1700
# ※※※Training loss  0.176※※※
# Training timepoint saved
# Valid loss  0.175 in Step 0
# Valid loss  0.181 in Step 50
# Valid loss  0.178 in Step 100
# Valid loss  0.196 in Step 150
# Valid loss  0.183 in Step 200
# Valid loss  0.170 in Step 250
# Valid loss  0.176 in Step 300
# Valid loss  0.182 in Step 350
# Valid loss  0.205 in Step 400
# ※※※Valid loss  0.182※※※
# Epoch 9
# Training loss  0.173 in Step 0
# Training loss  0.178 in Step 100
# Training loss  0.171 in Step 200
# Training loss  0.182 in Step 300
# Training loss  0.179 in Step 400
# Training loss  0.179 in Step 500
# Training loss  0.174 in Step 600
# Training loss  0.158 in Step 700
# Training loss  0.177 in Step 800
# Training loss  0.175 in Step 900
# Training loss  0.182 in Step 1000
# Training loss  0.188 in Step 1100
# Training loss  0.168 in Step 1200
# Training loss  0.167 in Step 1300
# Training loss  0.171 in Step 1400
# Training loss  0.177 in Step 1500
# Training loss  0.182 in Step 1600
# Training loss  0.171 in Step 1700
# ※※※Training loss  0.176※※※
# Training timepoint saved
# Valid loss  0.183 in Step 0
# Valid loss  0.187 in Step 50
# Valid loss  0.185 in Step 100
# Valid loss  0.203 in Step 150
# Valid loss  0.191 in Step 200
# Valid loss  0.178 in Step 250
# Valid loss  0.183 in Step 300
# Valid loss  0.189 in Step 350
# Valid loss  0.213 in Step 400
# ※※※Valid loss  0.189※※※
# Epoch 10
# Training loss  0.177 in Step 0
# Training loss  0.173 in Step 100
# Training loss  0.188 in Step 200
# Training loss  0.177 in Step 300
# Training loss  0.168 in Step 400
# Training loss  0.183 in Step 500
# Training loss  0.177 in Step 600
# Training loss  0.173 in Step 700
# Training loss  0.175 in Step 800
# Training loss  0.177 in Step 900
# Training loss  0.173 in Step 1000
# Training loss  0.175 in Step 1100
# Training loss  0.176 in Step 1200
# Training loss  0.184 in Step 1300
# Training loss  0.170 in Step 1400
# Training loss  0.175 in Step 1500
# Training loss  0.174 in Step 1600
# Training loss  0.171 in Step 1700
# ※※※Training loss  0.175※※※
# Training timepoint saved
# Valid loss  0.191 in Step 0
# Valid loss  0.196 in Step 50
# Valid loss  0.193 in Step 100
# Valid loss  0.210 in Step 150
# Valid loss  0.199 in Step 200
# Valid loss  0.186 in Step 250
# Valid loss  0.191 in Step 300
# Valid loss  0.197 in Step 350
# Valid loss  0.220 in Step 400
# ※※※Valid loss  0.197※※※
# Epoch 11
# Training loss  0.172 in Step 0
# Training loss  0.169 in Step 100
# Training loss  0.176 in Step 200
# Training loss  0.177 in Step 300
# Training loss  0.177 in Step 400
# Training loss  0.179 in Step 500
# Training loss  0.171 in Step 600
# Training loss  0.178 in Step 700
# Training loss  0.179 in Step 800
# Training loss  0.178 in Step 900
# Training loss  0.176 in Step 1000
# Training loss  0.162 in Step 1100
# Training loss  0.165 in Step 1200
# Training loss  0.175 in Step 1300
# Training loss  0.179 in Step 1400
# Training loss  0.169 in Step 1500
# Training loss  0.173 in Step 1600
# Training loss  0.167 in Step 1700
# ※※※Training loss  0.175※※※
# Training timepoint saved
# Valid loss  0.217 in Step 0
# Valid loss  0.221 in Step 50
# Valid loss  0.219 in Step 100
# Valid loss  0.236 in Step 150
# Valid loss  0.226 in Step 200
# Valid loss  0.212 in Step 250
# Valid loss  0.218 in Step 300
# Valid loss  0.222 in Step 350
# Valid loss  0.244 in Step 400
# ※※※Valid loss  0.223※※※
# Epoch 12
# Training loss  0.180 in Step 0
# Training loss  0.183 in Step 100
# Training loss  0.169 in Step 200
# Training loss  0.184 in Step 300
# Training loss  0.168 in Step 400
# Training loss  0.185 in Step 500
# Training loss  0.161 in Step 600
# Training loss  0.187 in Step 700
# Training loss  0.176 in Step 800
# Training loss  0.162 in Step 900
# Training loss  0.173 in Step 1000
# Training loss  0.173 in Step 1100
# Training loss  0.174 in Step 1200
# Training loss  0.187 in Step 1300
# Training loss  0.170 in Step 1400
# Training loss  0.181 in Step 1500
# Training loss  0.174 in Step 1600
# Training loss  0.164 in Step 1700
# ※※※Training loss  0.174※※※
# Training timepoint saved
# Valid loss  0.249 in Step 0
# Valid loss  0.255 in Step 50
# Valid loss  0.252 in Step 100
# Valid loss  0.268 in Step 150
# Valid loss  0.261 in Step 200
# Valid loss  0.247 in Step 250
# Valid loss  0.252 in Step 300
# Valid loss  0.254 in Step 350
# Valid loss  0.277 in Step 400
# ※※※Valid loss  0.256※※※
# Epoch 13
# Training loss  0.172 in Step 0
# Training loss  0.172 in Step 100
# Training loss  0.178 in Step 200
# Training loss  0.171 in Step 300
# Training loss  0.167 in Step 400
# Training loss  0.168 in Step 500
# Training loss  0.169 in Step 600
# Training loss  0.164 in Step 700
# Training loss  0.168 in Step 800
# Training loss  0.162 in Step 900
# Training loss  0.176 in Step 1000
# Training loss  0.168 in Step 1100
# Training loss  0.168 in Step 1200
# Training loss  0.173 in Step 1300
# Training loss  0.172 in Step 1400
# Training loss  0.175 in Step 1500
# Training loss  0.174 in Step 1600
# Training loss  0.179 in Step 1700
# ※※※Training loss  0.173※※※
# Training timepoint saved
# Valid loss  0.297 in Step 0
# Valid loss  0.303 in Step 50
# Valid loss  0.302 in Step 100
# Valid loss  0.317 in Step 150
# Valid loss  0.311 in Step 200
# Valid loss  0.298 in Step 250
# Valid loss  0.301 in Step 300
# Valid loss  0.300 in Step 350
# Valid loss  0.328 in Step 400
# ※※※Valid loss  0.305※※※
# Epoch 14
# Training loss  0.174 in Step 0
# Training loss  0.171 in Step 100
# Training loss  0.174 in Step 200
# Training loss  0.188 in Step 300
# Training loss  0.160 in Step 400
# Training loss  0.186 in Step 500
# Training loss  0.172 in Step 600
# Training loss  0.165 in Step 700
# Training loss  0.174 in Step 800
# Training loss  0.166 in Step 900
# Training loss  0.181 in Step 1000
# Training loss  0.171 in Step 1100
# Training loss  0.177 in Step 1200
# Training loss  0.176 in Step 1300
# Training loss  0.168 in Step 1400
# Training loss  0.163 in Step 1500
# Training loss  0.169 in Step 1600
# Training loss  0.163 in Step 1700
# ※※※Training loss  0.173※※※
# Training timepoint saved
# Valid loss  0.341 in Step 0
# Valid loss  0.348 in Step 50
# Valid loss  0.347 in Step 100
# Valid loss  0.361 in Step 150
# Valid loss  0.359 in Step 200
# Valid loss  0.344 in Step 250
# Valid loss  0.345 in Step 300
# Valid loss  0.343 in Step 350
# Valid loss  0.375 in Step 400
# ※※※Valid loss  0.349※※※
# Epoch 15
# Training loss  0.164 in Step 0
# Training loss  0.171 in Step 100
# Training loss  0.177 in Step 200
# Training loss  0.166 in Step 300
# Training loss  0.173 in Step 400
# Training loss  0.166 in Step 500
# Training loss  0.176 in Step 600
# Training loss  0.180 in Step 700
# Training loss  0.166 in Step 800
# Training loss  0.177 in Step 900
# Training loss  0.167 in Step 1000
# Training loss  0.176 in Step 1100
# Training loss  0.183 in Step 1200
# Training loss  0.178 in Step 1300
# Training loss  0.171 in Step 1400
# Training loss  0.175 in Step 1500
# Training loss  0.175 in Step 1600
# Training loss  0.161 in Step 1700
# ※※※Training loss  0.172※※※
# Training timepoint saved
# Valid loss  0.400 in Step 0
# Valid loss  0.409 in Step 50
# Valid loss  0.408 in Step 100
# Valid loss  0.423 in Step 150
# Valid loss  0.421 in Step 200
# Valid loss  0.407 in Step 250
# Valid loss  0.406 in Step 300
# Valid loss  0.402 in Step 350
# Valid loss  0.434 in Step 400
# ※※※Valid loss  0.410※※※
# Epoch 16
# Training loss  0.168 in Step 0
# Training loss  0.173 in Step 100
# Training loss  0.188 in Step 200
# Training loss  0.175 in Step 300
# Training loss  0.158 in Step 400
# Training loss  0.178 in Step 500
# Training loss  0.178 in Step 600
# Training loss  0.180 in Step 700
# Training loss  0.180 in Step 800
# Training loss  0.174 in Step 900
# Training loss  0.178 in Step 1000
# Training loss  0.167 in Step 1100
# Training loss  0.180 in Step 1200
# Training loss  0.172 in Step 1300
# Training loss  0.165 in Step 1400
# Training loss  0.166 in Step 1500
# Training loss  0.168 in Step 1600
# Training loss  0.176 in Step 1700
# ※※※Training loss  0.172※※※
# Training timepoint saved
# Valid loss  0.457 in Step 0
# Valid loss  0.467 in Step 50
# Valid loss  0.468 in Step 100
# Valid loss  0.478 in Step 150
# Valid loss  0.482 in Step 200
# Valid loss  0.466 in Step 250
# Valid loss  0.465 in Step 300
# Valid loss  0.457 in Step 350
# Valid loss  0.492 in Step 400
# ※※※Valid loss  0.467※※※
# Epoch 17
# Training loss  0.187 in Step 0
# Training loss  0.179 in Step 100
# Training loss  0.179 in Step 200
# Training loss  0.189 in Step 300
# Training loss  0.177 in Step 400
# Training loss  0.179 in Step 500
# Training loss  0.175 in Step 600
# Training loss  0.166 in Step 700
# Training loss  0.185 in Step 800
# Training loss  0.171 in Step 900
# Training loss  0.166 in Step 1000
# Training loss  0.163 in Step 1100
# Training loss  0.172 in Step 1200
# Training loss  0.173 in Step 1300
# Training loss  0.178 in Step 1400
# Training loss  0.172 in Step 1500
# Training loss  0.179 in Step 1600
# Training loss  0.163 in Step 1700
# ※※※Training loss  0.172※※※
# Training timepoint saved
# Valid loss  0.491 in Step 0
# Valid loss  0.502 in Step 50
# Valid loss  0.504 in Step 100
# Valid loss  0.515 in Step 150
# Valid loss  0.517 in Step 200
# Valid loss  0.500 in Step 250
# Valid loss  0.501 in Step 300
# Valid loss  0.489 in Step 350
# Valid loss  0.526 in Step 400
# ※※※Valid loss  0.502※※※
# Epoch 18
# Training loss  0.177 in Step 0
# Training loss  0.177 in Step 100
# Training loss  0.174 in Step 200
# Training loss  0.165 in Step 300
# Training loss  0.190 in Step 400
# Training loss  0.159 in Step 500
# Training loss  0.178 in Step 600
# Training loss  0.167 in Step 700
# Training loss  0.173 in Step 800
# Training loss  0.169 in Step 900
# Training loss  0.177 in Step 1000
# Training loss  0.167 in Step 1100
# Training loss  0.173 in Step 1200
# Training loss  0.164 in Step 1300
# Training loss  0.166 in Step 1400
# Training loss  0.176 in Step 1500
# Training loss  0.164 in Step 1600
# Training loss  0.167 in Step 1700
# ※※※Training loss  0.171※※※
# Training timepoint saved
# Valid loss  0.559 in Step 0
# Valid loss  0.573 in Step 50
# Valid loss  0.575 in Step 100
# Valid loss  0.580 in Step 150
# Valid loss  0.590 in Step 200
# Valid loss  0.573 in Step 250
# Valid loss  0.572 in Step 300
# Valid loss  0.558 in Step 350
# Valid loss  0.595 in Step 400
# ※※※Valid loss  0.572※※※
# Epoch 19
# Training loss  0.168 in Step 0
# Training loss  0.169 in Step 100
# Training loss  0.171 in Step 200
# Training loss  0.160 in Step 300
# Training loss  0.169 in Step 400
# Training loss  0.167 in Step 500
# Training loss  0.175 in Step 600
# Training loss  0.168 in Step 700
# Training loss  0.170 in Step 800
# Training loss  0.164 in Step 900
# Training loss  0.157 in Step 1000
# Training loss  0.156 in Step 1100
# Training loss  0.152 in Step 1200
# Training loss  0.158 in Step 1300
# Training loss  0.161 in Step 1400
# Training loss  0.154 in Step 1500
# Training loss  0.163 in Step 1600
# Training loss  0.165 in Step 1700
# ※※※Training loss  0.163※※※
# Training timepoint saved
# Valid loss  0.622 in Step 0
# Valid loss  0.633 in Step 50
# Valid loss  0.635 in Step 100
# Valid loss  0.641 in Step 150
# Valid loss  0.650 in Step 200
# Valid loss  0.636 in Step 250
# Valid loss  0.629 in Step 300
# Valid loss  0.618 in Step 350
# Valid loss  0.658 in Step 400
# ※※※Valid loss  0.633※※※
# Epoch 20
# Training loss  0.152 in Step 0
# Training loss  0.148 in Step 100
# Training loss  0.155 in Step 200
# Training loss  0.156 in Step 300
# Training loss  0.150 in Step 400
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /home/ldlmdl/Documents/wavln/scripts/A_08.ipynb Cell 25 line 2
#       <a href='vscode-notebook-cell:/home/ldlmdl/Documents/wavln/scripts/A_08.ipynb#X33sZmlsZQ%3D%3D?line=0'>1</a> if __name__ == "__main__":
# ----> <a href='vscode-notebook-cell:/home/ldlmdl/Documents/wavln/scripts/A_08.ipynb#X33sZmlsZQ%3D%3D?line=1'>2</a>     train()
#
# /home/ldlmdl/Documents/wavln/scripts/A_08.ipynb Cell 25 line 2
#      <a href='vscode-notebook-cell:/home/ldlmdl/Documents/wavln/scripts/A_08.ipynb#X33sZmlsZQ%3D%3D?line=18'>19</a> loss = model_loss.get_loss(recon_x, y, x_mask)
#      <a href='vscode-notebook-cell:/home/ldlmdl/Documents/wavln/scripts/A_08.ipynb#X33sZmlsZQ%3D%3D?line=20'>21</a> train_loss += loss.item()
# ---> <a href='vscode-notebook-cell:/home/ldlmdl/Documents/wavln/scripts/A_08.ipynb#X33sZmlsZQ%3D%3D?line=22'>23</a> loss.backward()
#      <a href='vscode-notebook-cell:/home/ldlmdl/Documents/wavln/scripts/A_08.ipynb#X33sZmlsZQ%3D%3D?line=24'>25</a> # torch.nn.utils.clip_grad_norm_(model.parameters(), clip_value)
#      <a href='vscode-notebook-cell:/home/ldlmdl/Documents/wavln/scripts/A_08.ipynb#X33sZmlsZQ%3D%3D?line=25'>26</a> # 这个函数计算的是全局梯度范数
#      <a href='vscode-notebook-cell:/home/ldlmdl/Documents/wavln/scripts/A_08.ipynb#X33sZmlsZQ%3D%3D?line=26'>27</a> # torch.nn.utils.clip_grad_norm(parameters=model.parameters(), max_norm=5, norm_type=2)
#      <a href='vscode-notebook-cell:/home/ldlmdl/Documents/wavln/scripts/A_08.ipynb#X33sZmlsZQ%3D%3D?line=27'>28</a> torch.nn.utils.clip_grad_norm_(parameters=model.parameters(), max_norm=5, norm_type=2)
#
# File ~/anaconda3/envs/wavln/lib/python3.11/site-packages/torch/_tensor.py:487, in Tensor.backward(self, gradient, retain_graph, create_graph, inputs)
#     477 if has_torch_function_unary(self):
#     478     return handle_torch_function(
#     479         Tensor.backward,
#     480         (self,),
#    (...)
#     485         inputs=inputs,
#     486     )
# --> 487 torch.autograd.backward(
#     488     self, gradient, retain_graph, create_graph, inputs=inputs
#     489 )
#
# File ~/anaconda3/envs/wavln/lib/python3.11/site-packages/torch/autograd/__init__.py:200, in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables, inputs)
#     195     retain_graph = create_graph
#     197 # The reason we repeat same the comment below is that
#     198 # some Python versions print out the first line of a multi-line function
#     199 # calls in the traceback and some print out the last line
# --> 200 Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
#     201     tensors, grad_tensors_, retain_graph, create_graph, inputs,
#     202     allow_unreachable=True, accumulate_grad=True)
#
# KeyboardInterrupt:

# %%
### Save
train_losses.save()

valid_losses.save()

text_hist.save()

# %%
plt.plot(train_losses.get(), label='Train')
plt.plot(valid_losses.get(), label='Valid')
plt.title("Learning Curve Loss")
plt.legend()

# %% [markdown]
# ## Conclusion
# This model should converge to loss around 0.49x.
