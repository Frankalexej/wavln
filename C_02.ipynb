# %% [markdown]
# # Phenomenon-Target Training (AI Lab Run)
# - C01: This is the first version of phenomenon training. In this we generated a sibilant-stop dataset and a stop-dataset. For S-set we constrain that all at word start. For SS-set we allow in-between ones because we know that basically they are also deaspirated.
# - C02: trial #1: test the natural proportion of 10k vs 2k to see whether the attention & separation is still observable in natural setting.

# %% [markdown]
# ## Preparing

# %%
import torch
from torch import nn
import torch.nn.functional as F
from torch.nn.utils.rnn import pad_sequence, pack_sequence
from torch import optim
from torch.utils.data import Dataset, DataLoader, random_split
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
from model_model import VQVAEV1 as TheLearner
from model_dataset import DS_Tools
from model_dataset import TargetDataset as ThisDataset
from model_dataset import Normalizer, DeNormalizer, TokenMap
from model_dataset import MelSpecTransformDB as TheTransform
from paths import *
from misc_my_utils import *
from misc_recorder import *
from model_loss import *
from model_padding import generate_mask_from_lengths_mat

# %% [markdown]
# ### Dirs

# %%
rec_dir = train_cut_phone_
# train_guide_path = os.path.join(src_, "guide_train.csv")
# valid_guide_path = os.path.join(src_, "guide_validation.csv")
# test_guide_path = os.path.join(src_, "guide_test.csv")
unbalanced_guides_path = os.path.join(src_, "phi-unbalanced-guides")

phi_T_train_path = os.path.join(unbalanced_guides_path, "T-train.csv")
phi_ST_train_path = os.path.join(unbalanced_guides_path, "ST-train.csv")
phi_T_valid_path = os.path.join(unbalanced_guides_path, "T-valid.csv")
phi_ST_valid_path = os.path.join(unbalanced_guides_path, "ST-valid.csv")

# %% [markdown]
# ### Constants

# %%
BATCH_SIZE = 32

# IN_DIM = 64
# HID_DIM = 8

# ENC_SIZE_LIST = {
#     "in": 64, 
#     "hid": 8
# }
# DEC_SIZE_LIST = {
#     "hid": 8
# }

INPUT_DIM = 64
OUTPUT_DIM = 64 

INTER_DIM_0 = 32
INTER_DIM_1 = 16
INTER_DIM_2 = 8

ENC_SIZE_LIST = [INPUT_DIM, INTER_DIM_0, INTER_DIM_1, INTER_DIM_2]
DEC_SIZE_LIST = [OUTPUT_DIM, INTER_DIM_0, INTER_DIM_1, INTER_DIM_2]

DROPOUT = 0.5
NUM_LAYERS = 2
EMBEDDING_DIM = 128

REC_SAMPLE_RATE = 16000
N_FFT = 400
N_MELS = 64

LOADER_WORKER = 32

# %% [markdown]
# ## Prepare for this time of training

# %%
ts = str(get_timestamp())
# ts = "0225215615"
stop_epoch = "29"
train_name = "C_02"
model_save_dir = os.path.join(model_save_, f"{train_name}-{ts}")
mk(model_save_dir)
print(f"{train_name}-{ts}")

train_losses = ListRecorder(os.path.join(model_save_dir, "train.loss"))
train_recon_losses = ListRecorder(os.path.join(model_save_dir, "train.recon.loss"))
train_embedding_losses = ListRecorder(os.path.join(model_save_dir, "train.embedding.loss"))
train_commitment_losses = ListRecorder(os.path.join(model_save_dir, "train.commitment.loss"))

valid_losses = ListRecorder(os.path.join(model_save_dir, "valid.loss"))
valid_recon_losses = ListRecorder(os.path.join(model_save_dir, "valid.recon.loss"))
valid_embedding_losses = ListRecorder(os.path.join(model_save_dir, "valid.embedding.loss"))
valid_commitment_losses = ListRecorder(os.path.join(model_save_dir, "valid.commitment.loss"))

text_hist = HistRecorder(os.path.join(model_save_dir, "trainhist.txt"))
# Out:
# C_02-0301171500

# %% [markdown]
# - 0225215615: first trial.
# - 0226154925: retrained with speakers separated.
#
# - (C2) 0301171500: using natural proportion.

# %%
READ = False
DATAREAD = False

# %%
with open(os.path.join(src_, "no-stress-seg.dict"), "rb") as file:
    # Load the object from the file
    mylist = pickle.load(file)
    mylist = ["BLANK"] + mylist

# Now you can use the loaded object
mymap = TokenMap(mylist)

# We do the random selection here
t_train = pd.read_csv(phi_T_train_path)
st_train = pd.read_csv(phi_ST_train_path)
t_valid = pd.read_csv(phi_T_valid_path)
st_valid = pd.read_csv(phi_ST_valid_path)

all_train = pd.concat([t_train, st_train], ignore_index=True, sort=False)
all_valid = pd.concat([t_valid, st_valid], ignore_index=True, sort=False)

all_train = all_train.sample(frac=1).reset_index(drop=True)
all_valid = all_valid.sample(frac=1).reset_index(drop=True)

mytrans = TheTransform(sample_rate=REC_SAMPLE_RATE, 
                       n_fft=N_FFT, n_mels=N_MELS, 
                       normalizer=Normalizer.norm_mvn, 
                       denormalizer=DeNormalizer.norm_mvn)

train_ds = ThisDataset(rec_dir, 
                       all_train, 
                       mapper=mymap, 
                       transform=mytrans)
valid_ds = ThisDataset(rec_dir, 
                       all_valid, 
                       mapper=mymap, 
                       transform=mytrans)

train_loader = DataLoader(train_ds, batch_size=BATCH_SIZE, shuffle=True, num_workers=LOADER_WORKER, collate_fn=ThisDataset.collate_fn)
train_num = len(train_loader.dataset)

valid_loader = DataLoader(valid_ds, batch_size=BATCH_SIZE, shuffle=False, num_workers=LOADER_WORKER, collate_fn=ThisDataset.collate_fn)
valid_num = len(valid_loader.dataset)

# %%
train_num, valid_num, len(train_loader), len(valid_loader)
# Out:
# (10722, 2617, 336, 82)

# %%
# Load sample data from train_loader
sample_data = next(iter(valid_loader))
xx_pad, x_lens, phi_type, stop_name = sample_data
print(xx_pad.shape)

# Set the random seed for reproducibility
# random.seed(101)
# Generate six random indices
# random_indices = random.sample(range(len(xx_pad)), 6)
random_indices = list(range(6, 12))

# Plot the spectrograms and mark the corresponding seg
fig, axes = plt.subplots(2, 3, figsize=(12, 8))
axes = axes.flatten()

for i, idx in enumerate(random_indices):
    spectrogram = xx_pad[idx]
    this_phi_type, this_stop_name = phi_type[idx], stop_name[idx]
    title = "-".join([this_phi_type, this_stop_name])
    
    ax = axes[i]
    img = ax.imshow(spectrogram.T, aspect='auto', origin="lower")
    # ax.axvline(x=segment, color='red', linestyle='--')
    # ax.axvline(x=segment[1], color='red', linestyle='--')
    ax.set_title(title)
    ax.set_xlabel('Time')
    ax.set_ylabel('Frequency')
plt.tight_layout()
plt.colorbar(img,ax=axes)
plt.show()
# Out:
# torch.Size([32, 21, 64])

# %% [markdown]
# ## Loss
# VAE的损失由重构损失和KL损失组成.
#
# KL散度就不再推导了, 直接放结果:
# $$KL\Big(N(\mu,\sigma^2)\Big\Vert N(0,1)\Big)=\frac{1}{2}\Big(-\log \sigma^2+\mu^2+\sigma^2-1\Big)$$
#
# VAE的目标是最小化$Z$和$\mathcal{N}(0, I)$之间的KL散度, 代码只需要照着写就行了:

# %%
masked_loss = MaskedLoss(loss_fn=nn.MSELoss(reduction="none"))

# %% [markdown]
# ## Prepare Model
# 先定义好训练的epoch和batch_size, 优化器随便选一个世界上最好的优化器Adam(lr=1e-3):

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
model = TheLearner(enc_size_list=ENC_SIZE_LIST, 
                   dec_size_list=DEC_SIZE_LIST, 
                   embedding_dim=EMBEDDING_DIM, 
                   num_layers=NUM_LAYERS, dropout=DROPOUT)
model.to(device)
optimizer = optim.Adam(model.parameters(), lr=1e-3)

model_str = str(model)
model_txt_path = os.path.join(model_save_dir, "model.txt")

with open(model_txt_path, "w") as f:
    f.write(model_str)

# %%
model_parameters = filter(lambda p: p.requires_grad, model.parameters())
params = sum([np.prod(p.size()) for p in model_parameters])
print(params)

# initialize model weights
def init_weights(m):
    if isinstance(m, nn.Linear):
        torch.nn.init.orthogonal_(m.weight)
        m.bias.data.fill_(0.01)
    if isinstance(m, nn.LSTM): 
        for name, p in m.named_parameters():
            if "weight" in name: 
                nn.init.orthogonal_(p)
            elif "bias" in name: 
                nn.init.constant_(p, 0)

model.apply(init_weights)
# Out:
# 6960
# VQVAEV1(
#   (encoder): VQEncoderV1(
#     (lin_1): Linear(in_features=64, out_features=8, bias=True)
#     (rnn): LSTM(8, 8, num_layers=2, batch_first=True, dropout=0.5, bidirectional=True)
#     (lin_2): Linear(in_features=16, out_features=8, bias=True)
#     (act): ReLU()
#   )
#   (decoder): VQDecoderV1(
#     (lin_1): Linear(in_features=64, out_features=8, bias=True)
#     (rnn): LSTM(8, 8, num_layers=2, batch_first=True, dropout=0.5)
#     (attention): ScaledDotProductAttention(
#       (w_q): Linear(in_features=8, out_features=8, bias=True)
#       (w_k): Linear(in_features=8, out_features=8, bias=True)
#       (w_v): Linear(in_features=8, out_features=8, bias=True)
#     )
#     (lin_2): Linear(in_features=8, out_features=64, bias=True)
#     (act): ReLU()
#   )
#   (vq_embedding): Embedding(128, 8)
# )

# %% [markdown]
# ### Load model if READ

# %%
if READ: 
    train_losses.read()
    train_recon_losses.read()
    train_embedding_losses.read()
    train_commitment_losses.read()

    valid_losses.read()
    valid_recon_losses.read()
    valid_embedding_losses.read()
    valid_commitment_losses.read()

    model_name = "{}.pt".format(stop_epoch)
    model_path = os.path.join(model_save_dir, model_name)
    state = torch.load(model_path)

    model.load_state_dict(state)
    model.to(device)

# %% [markdown]
# ## Training

# %%
l_w_embedding = 1
l_w_commitment = 0.25

# %%
EPOCHS = 100
BASE = 0

# %%
for epoch in range(BASE, BASE + EPOCHS):
    text_hist.print("Epoch {}".format(epoch))

    model.train()
    train_loss = 0.
    train_cumulative_l_reconstruct = 0.
    train_cumulative_l_embedding = 0.
    train_cumulative_l_commitment = 0.
    train_num = len(train_loader.dataset)    # train_loader
    for idx, (x, x_lens, pt, sn) in enumerate(train_loader):
        current_batch_size = x.shape[0]
        # y_lens should be the same as x_lens
        optimizer.zero_grad()
        x_mask = generate_mask_from_lengths_mat(x_lens, device=device)
        y = x
        x = x.to(device)
        y = y.to(device)

        x_hat, attn_w, (ze, zq) = model(x, x_lens, x_mask)

        l_reconstruct = masked_loss.get_loss(x_hat, y, x_mask)
        l_embedding = masked_loss.get_loss(ze.detach(), zq, x_mask)
        l_commitment = masked_loss.get_loss(ze, zq.detach(), x_mask)
        loss = l_reconstruct + \
            l_w_embedding * l_embedding + l_w_commitment * l_commitment

        loss.backward()
        # torch.nn.utils.clip_grad_norm_(parameters=model.parameters(), max_norm=5, norm_type=2)
        optimizer.step()

        train_loss += loss.item() * current_batch_size
        train_cumulative_l_reconstruct += l_reconstruct.item() * current_batch_size
        train_cumulative_l_embedding += l_embedding.item() * current_batch_size
        train_cumulative_l_commitment += l_commitment.item() * current_batch_size

        if idx % 100 == 0:
            text_hist.print(f"""Training step {idx} loss {loss: .3f} \t recon {l_reconstruct: .3f} \t embed {l_embedding: .3f} \t commit {l_commitment: .3f}""")

    train_losses.append(train_loss / train_num)
    train_recon_losses.append(train_cumulative_l_reconstruct / train_num)
    train_embedding_losses.append(train_cumulative_l_embedding / train_num)
    train_commitment_losses.append(train_cumulative_l_commitment / train_num)

    text_hist.print(f"""※※※Training loss {train_loss / train_num: .3f} \t recon {train_cumulative_l_reconstruct / train_num: .3f} \t embed {train_cumulative_l_embedding / train_num: .3f} \t commit {train_cumulative_l_commitment / train_num: .3f}※※※""")

    last_model_name = "{}.pt".format(epoch)
    torch.save(model.state_dict(), os.path.join(model_save_dir, last_model_name))


    model.eval()
    valid_loss = 0.
    valid_cumulative_l_reconstruct = 0.
    valid_cumulative_l_embedding = 0.
    valid_cumulative_l_commitment = 0.
    valid_num = len(valid_loader.dataset)
    for idx, (x, x_lens, pt, sn) in enumerate(valid_loader):
        current_batch_size = x.shape[0]
        x_mask = generate_mask_from_lengths_mat(x_lens, device=device)

        y = x
        x = x.to(device)
        y = y.to(device)

        x_hat, attn_w, (ze, zq) = model(x, x_lens, x_mask)

        l_reconstruct = masked_loss.get_loss(x_hat, y, x_mask)
        l_embedding = masked_loss.get_loss(ze.detach(), zq, x_mask)
        l_commitment = masked_loss.get_loss(ze, zq.detach(), x_mask)
        loss = l_reconstruct + \
            l_w_embedding * l_embedding + l_w_commitment * l_commitment

        valid_loss += loss.item() * current_batch_size
        valid_cumulative_l_reconstruct += l_reconstruct.item() * current_batch_size
        valid_cumulative_l_embedding += l_embedding.item() * current_batch_size
        valid_cumulative_l_commitment += l_commitment.item() * current_batch_size

    text_hist.print(f"""※※※Valid loss {valid_loss / valid_num: .3f} \t recon {valid_cumulative_l_reconstruct / valid_num: .3f} \t embed {valid_cumulative_l_embedding / valid_num: .3f} \t commit {valid_cumulative_l_commitment / valid_num: .3f}※※※""")
    valid_losses.append(valid_loss / valid_num)
    valid_recon_losses.append(valid_cumulative_l_reconstruct / valid_num)
    valid_embedding_losses.append(valid_cumulative_l_embedding / valid_num)
    valid_commitment_losses.append(valid_cumulative_l_commitment / valid_num)
# Out:
# Epoch 0
# Training step 0 loss  1.002 	 recon  1.000 	 embed  0.002 	 commit  0.002
# Training step 100 loss  1.461 	 recon  0.921 	 embed  0.432 	 commit  0.432
# Training step 200 loss  1.052 	 recon  0.884 	 embed  0.135 	 commit  0.135
# Training step 300 loss  0.897 	 recon  0.785 	 embed  0.089 	 commit  0.089
# ※※※Training loss  1.160 	 recon  0.859 	 embed  0.240 	 commit  0.240※※※
# ※※※Valid loss  0.835 	 recon  0.746 	 embed  0.072 	 commit  0.072※※※
# Epoch 1
# Training step 0 loss  0.891 	 recon  0.769 	 embed  0.098 	 commit  0.098
# Training step 100 loss  0.823 	 recon  0.756 	 embed  0.053 	 commit  0.053
# Training step 200 loss  0.733 	 recon  0.683 	 embed  0.040 	 commit  0.040
# Training step 300 loss  0.653 	 recon  0.634 	 embed  0.015 	 commit  0.015
# ※※※Training loss  0.724 	 recon  0.669 	 embed  0.044 	 commit  0.044※※※
# ※※※Valid loss  0.600 	 recon  0.583 	 embed  0.013 	 commit  0.013※※※
# Epoch 2
# Training step 0 loss  0.634 	 recon  0.615 	 embed  0.015 	 commit  0.015
# Training step 100 loss  0.568 	 recon  0.547 	 embed  0.016 	 commit  0.016
# Training step 200 loss  0.578 	 recon  0.547 	 embed  0.025 	 commit  0.025
# Training step 300 loss  0.592 	 recon  0.563 	 embed  0.024 	 commit  0.024
# ※※※Training loss  0.591 	 recon  0.563 	 embed  0.022 	 commit  0.022※※※
# ※※※Valid loss  0.576 	 recon  0.550 	 embed  0.021 	 commit  0.021※※※
# Epoch 3
# Training step 0 loss  0.601 	 recon  0.573 	 embed  0.022 	 commit  0.022
# Training step 100 loss  0.671 	 recon  0.634 	 embed  0.030 	 commit  0.030
# Training step 200 loss  0.587 	 recon  0.558 	 embed  0.024 	 commit  0.024
# Training step 300 loss  0.559 	 recon  0.524 	 embed  0.028 	 commit  0.028
# ※※※Training loss  0.572 	 recon  0.534 	 embed  0.031 	 commit  0.031※※※
# ※※※Valid loss  0.555 	 recon  0.519 	 embed  0.029 	 commit  0.029※※※
# Epoch 4
# Training step 0 loss  0.566 	 recon  0.518 	 embed  0.038 	 commit  0.038
# Training step 100 loss  0.569 	 recon  0.535 	 embed  0.027 	 commit  0.027
# Training step 200 loss  0.545 	 recon  0.501 	 embed  0.035 	 commit  0.035
# Training step 300 loss  0.559 	 recon  0.514 	 embed  0.036 	 commit  0.036
# ※※※Training loss  0.554 	 recon  0.506 	 embed  0.039 	 commit  0.039※※※
# ※※※Valid loss  0.543 	 recon  0.498 	 embed  0.037 	 commit  0.037※※※
# Epoch 5
# Training step 0 loss  0.556 	 recon  0.488 	 embed  0.055 	 commit  0.055
# Training step 100 loss  0.564 	 recon  0.503 	 embed  0.049 	 commit  0.049
# Training step 200 loss  0.576 	 recon  0.523 	 embed  0.043 	 commit  0.043
# Training step 300 loss  0.607 	 recon  0.552 	 embed  0.044 	 commit  0.044
# ※※※Training loss  0.547 	 recon  0.486 	 embed  0.048 	 commit  0.048※※※
# ※※※Valid loss  0.566 	 recon  0.514 	 embed  0.042 	 commit  0.042※※※
# Epoch 6
# Training step 0 loss  0.603 	 recon  0.541 	 embed  0.049 	 commit  0.049
# Training step 100 loss  0.567 	 recon  0.508 	 embed  0.047 	 commit  0.047
# Training step 200 loss  0.493 	 recon  0.430 	 embed  0.050 	 commit  0.050
# Training step 300 loss  0.522 	 recon  0.454 	 embed  0.054 	 commit  0.054
# ※※※Training loss  0.541 	 recon  0.478 	 embed  0.051 	 commit  0.051※※※
# ※※※Valid loss  0.523 	 recon  0.467 	 embed  0.045 	 commit  0.045※※※
# Epoch 7
# Training step 0 loss  0.526 	 recon  0.460 	 embed  0.053 	 commit  0.053
# Training step 100 loss  0.604 	 recon  0.523 	 embed  0.065 	 commit  0.065
# Training step 200 loss  0.540 	 recon  0.479 	 embed  0.049 	 commit  0.049
# Training step 300 loss  0.472 	 recon  0.402 	 embed  0.056 	 commit  0.056
# ※※※Training loss  0.522 	 recon  0.455 	 embed  0.054 	 commit  0.054※※※
# ※※※Valid loss  0.508 	 recon  0.450 	 embed  0.046 	 commit  0.046※※※
# Epoch 8
# Training step 0 loss  0.552 	 recon  0.478 	 embed  0.059 	 commit  0.059
# Training step 100 loss  0.551 	 recon  0.468 	 embed  0.067 	 commit  0.067
# Training step 200 loss  0.490 	 recon  0.420 	 embed  0.056 	 commit  0.056
# Training step 300 loss  0.484 	 recon  0.417 	 embed  0.054 	 commit  0.054
# ※※※Training loss  0.509 	 recon  0.441 	 embed  0.054 	 commit  0.054※※※
# ※※※Valid loss  0.549 	 recon  0.490 	 embed  0.048 	 commit  0.048※※※
# Epoch 9
# Training step 0 loss  0.611 	 recon  0.540 	 embed  0.056 	 commit  0.056
# Training step 100 loss  0.468 	 recon  0.398 	 embed  0.056 	 commit  0.056
# Training step 200 loss  0.550 	 recon  0.478 	 embed  0.057 	 commit  0.057
# Training step 300 loss  0.534 	 recon  0.459 	 embed  0.060 	 commit  0.060
# ※※※Training loss  0.502 	 recon  0.433 	 embed  0.055 	 commit  0.055※※※
# ※※※Valid loss  0.496 	 recon  0.435 	 embed  0.048 	 commit  0.048※※※
# Epoch 10
# Training step 0 loss  0.516 	 recon  0.449 	 embed  0.054 	 commit  0.054
# Training step 100 loss  0.460 	 recon  0.390 	 embed  0.056 	 commit  0.056
# Training step 200 loss  0.460 	 recon  0.392 	 embed  0.054 	 commit  0.054
# Training step 300 loss  0.523 	 recon  0.437 	 embed  0.069 	 commit  0.069
# ※※※Training loss  0.505 	 recon  0.431 	 embed  0.059 	 commit  0.059※※※
# ※※※Valid loss  0.498 	 recon  0.431 	 embed  0.053 	 commit  0.053※※※
# Epoch 11
# Training step 0 loss  0.470 	 recon  0.392 	 embed  0.063 	 commit  0.063
# Training step 100 loss  0.522 	 recon  0.436 	 embed  0.069 	 commit  0.069
# Training step 200 loss  0.439 	 recon  0.373 	 embed  0.053 	 commit  0.053
# Training step 300 loss  0.508 	 recon  0.439 	 embed  0.055 	 commit  0.055
# ※※※Training loss  0.496 	 recon  0.420 	 embed  0.061 	 commit  0.061※※※
# ※※※Valid loss  0.503 	 recon  0.434 	 embed  0.055 	 commit  0.055※※※
# Epoch 12
# Training step 0 loss  0.515 	 recon  0.431 	 embed  0.067 	 commit  0.067
# Training step 100 loss  0.438 	 recon  0.366 	 embed  0.058 	 commit  0.058
# Training step 200 loss  0.456 	 recon  0.389 	 embed  0.053 	 commit  0.053
# Training step 300 loss  0.443 	 recon  0.366 	 embed  0.062 	 commit  0.062
# ※※※Training loss  0.492 	 recon  0.415 	 embed  0.061 	 commit  0.061※※※
# ※※※Valid loss  0.485 	 recon  0.417 	 embed  0.055 	 commit  0.055※※※
# Epoch 13
# Training step 0 loss  0.457 	 recon  0.380 	 embed  0.062 	 commit  0.062
# Training step 100 loss  0.533 	 recon  0.450 	 embed  0.067 	 commit  0.067
# Training step 200 loss  0.477 	 recon  0.402 	 embed  0.060 	 commit  0.060
# Training step 300 loss  0.470 	 recon  0.390 	 embed  0.064 	 commit  0.064
# ※※※Training loss  0.490 	 recon  0.410 	 embed  0.064 	 commit  0.064※※※
# ※※※Valid loss  0.484 	 recon  0.412 	 embed  0.057 	 commit  0.057※※※
# Epoch 14
# Training step 0 loss  0.456 	 recon  0.375 	 embed  0.064 	 commit  0.064
# Training step 100 loss  0.498 	 recon  0.420 	 embed  0.062 	 commit  0.062
# Training step 200 loss  0.469 	 recon  0.385 	 embed  0.067 	 commit  0.067
# Training step 300 loss  0.445 	 recon  0.360 	 embed  0.068 	 commit  0.068
# ※※※Training loss  0.490 	 recon  0.405 	 embed  0.068 	 commit  0.068※※※
# ※※※Valid loss  0.491 	 recon  0.413 	 embed  0.063 	 commit  0.063※※※
# Epoch 15
# Training step 0 loss  0.472 	 recon  0.395 	 embed  0.062 	 commit  0.062
# Training step 100 loss  0.526 	 recon  0.430 	 embed  0.077 	 commit  0.077
# Training step 200 loss  0.489 	 recon  0.395 	 embed  0.074 	 commit  0.074
# Training step 300 loss  0.448 	 recon  0.357 	 embed  0.073 	 commit  0.073
# ※※※Training loss  0.493 	 recon  0.400 	 embed  0.074 	 commit  0.074※※※
# ※※※Valid loss  0.493 	 recon  0.406 	 embed  0.070 	 commit  0.070※※※
# Epoch 16
# Training step 0 loss  0.515 	 recon  0.392 	 embed  0.099 	 commit  0.099
# Training step 100 loss  0.484 	 recon  0.387 	 embed  0.078 	 commit  0.078
# Training step 200 loss  0.448 	 recon  0.342 	 embed  0.085 	 commit  0.085
# Training step 300 loss  0.487 	 recon  0.378 	 embed  0.087 	 commit  0.087
# ※※※Training loss  0.500 	 recon  0.396 	 embed  0.083 	 commit  0.083※※※
# ※※※Valid loss  0.503 	 recon  0.406 	 embed  0.078 	 commit  0.078※※※
# Epoch 17
# Training step 0 loss  0.481 	 recon  0.383 	 embed  0.078 	 commit  0.078
# Training step 100 loss  0.478 	 recon  0.376 	 embed  0.082 	 commit  0.082
# Training step 200 loss  0.485 	 recon  0.372 	 embed  0.091 	 commit  0.091
# Training step 300 loss  0.447 	 recon  0.334 	 embed  0.090 	 commit  0.090
# ※※※Training loss  0.504 	 recon  0.392 	 embed  0.089 	 commit  0.089※※※
# ※※※Valid loss  0.504 	 recon  0.402 	 embed  0.082 	 commit  0.082※※※
# Epoch 18
# Training step 0 loss  0.514 	 recon  0.405 	 embed  0.087 	 commit  0.087
# Training step 100 loss  0.518 	 recon  0.401 	 embed  0.094 	 commit  0.094
# Training step 200 loss  0.501 	 recon  0.376 	 embed  0.100 	 commit  0.100
# Training step 300 loss  0.570 	 recon  0.429 	 embed  0.113 	 commit  0.113
# ※※※Training loss  0.509 	 recon  0.391 	 embed  0.094 	 commit  0.094※※※
# ※※※Valid loss  0.534 	 recon  0.414 	 embed  0.095 	 commit  0.095※※※
# Epoch 19
# Training step 0 loss  0.508 	 recon  0.381 	 embed  0.102 	 commit  0.102
# Training step 100 loss  0.508 	 recon  0.378 	 embed  0.104 	 commit  0.104
# Training step 200 loss  0.538 	 recon  0.421 	 embed  0.093 	 commit  0.093
# Training step 300 loss  0.514 	 recon  0.380 	 embed  0.107 	 commit  0.107
# ※※※Training loss  0.507 	 recon  0.386 	 embed  0.097 	 commit  0.097※※※
# ※※※Valid loss  0.506 	 recon  0.401 	 embed  0.084 	 commit  0.084※※※
# Epoch 20
# Training step 0 loss  0.518 	 recon  0.388 	 embed  0.104 	 commit  0.104
# Training step 100 loss  0.551 	 recon  0.425 	 embed  0.101 	 commit  0.101
# Training step 200 loss  0.508 	 recon  0.380 	 embed  0.102 	 commit  0.102
# Training step 300 loss  0.543 	 recon  0.433 	 embed  0.088 	 commit  0.088
# ※※※Training loss  0.514 	 recon  0.390 	 embed  0.099 	 commit  0.099※※※
# ※※※Valid loss  0.510 	 recon  0.400 	 embed  0.088 	 commit  0.088※※※
# Epoch 21
# Training step 0 loss  0.481 	 recon  0.365 	 embed  0.092 	 commit  0.092
# Training step 100 loss  0.491 	 recon  0.370 	 embed  0.096 	 commit  0.096
# Training step 200 loss  0.480 	 recon  0.369 	 embed  0.089 	 commit  0.089
# Training step 300 loss  0.456 	 recon  0.326 	 embed  0.104 	 commit  0.104
# ※※※Training loss  0.504 	 recon  0.380 	 embed  0.099 	 commit  0.099※※※
# ※※※Valid loss  0.502 	 recon  0.389 	 embed  0.090 	 commit  0.090※※※
# Epoch 22
# Training step 0 loss  0.509 	 recon  0.392 	 embed  0.094 	 commit  0.094
# Training step 100 loss  0.493 	 recon  0.363 	 embed  0.104 	 commit  0.104
# Training step 200 loss  0.465 	 recon  0.343 	 embed  0.098 	 commit  0.098
# Training step 300 loss  0.561 	 recon  0.430 	 embed  0.105 	 commit  0.105
# ※※※Training loss  0.521 	 recon  0.393 	 embed  0.102 	 commit  0.102※※※
# ※※※Valid loss  0.527 	 recon  0.411 	 embed  0.093 	 commit  0.093※※※
# Epoch 23
# Training step 0 loss  0.504 	 recon  0.382 	 embed  0.098 	 commit  0.098
# Training step 100 loss  0.481 	 recon  0.357 	 embed  0.099 	 commit  0.099
# Training step 200 loss  0.482 	 recon  0.356 	 embed  0.101 	 commit  0.101
# Training step 300 loss  0.421 	 recon  0.306 	 embed  0.092 	 commit  0.092
# ※※※Training loss  0.506 	 recon  0.375 	 embed  0.104 	 commit  0.104※※※
# ※※※Valid loss  0.504 	 recon  0.387 	 embed  0.093 	 commit  0.093※※※
# Epoch 24
# Training step 0 loss  0.502 	 recon  0.377 	 embed  0.100 	 commit  0.100
# Training step 100 loss  0.536 	 recon  0.405 	 embed  0.105 	 commit  0.105
# Training step 200 loss  0.429 	 recon  0.315 	 embed  0.091 	 commit  0.091
# Training step 300 loss  0.535 	 recon  0.397 	 embed  0.110 	 commit  0.110
# ※※※Training loss  0.502 	 recon  0.371 	 embed  0.105 	 commit  0.105※※※
# ※※※Valid loss  0.505 	 recon  0.387 	 embed  0.094 	 commit  0.094※※※
# Epoch 25
# Training step 0 loss  0.462 	 recon  0.337 	 embed  0.100 	 commit  0.100
# Training step 100 loss  0.474 	 recon  0.346 	 embed  0.102 	 commit  0.102
# Training step 200 loss  0.520 	 recon  0.393 	 embed  0.102 	 commit  0.102
# Training step 300 loss  0.566 	 recon  0.412 	 embed  0.123 	 commit  0.123
# ※※※Training loss  0.506 	 recon  0.370 	 embed  0.109 	 commit  0.109※※※
# ※※※Valid loss  0.512 	 recon  0.385 	 embed  0.102 	 commit  0.102※※※
# Epoch 26
# Training step 0 loss  0.510 	 recon  0.380 	 embed  0.104 	 commit  0.104
# Training step 100 loss  0.564 	 recon  0.423 	 embed  0.113 	 commit  0.113
# Training step 200 loss  0.501 	 recon  0.357 	 embed  0.115 	 commit  0.115
# Training step 300 loss  0.448 	 recon  0.313 	 embed  0.108 	 commit  0.108
# ※※※Training loss  0.508 	 recon  0.368 	 embed  0.112 	 commit  0.112※※※
# ※※※Valid loss  0.518 	 recon  0.385 	 embed  0.106 	 commit  0.106※※※
# Epoch 27
# Training step 0 loss  0.475 	 recon  0.350 	 embed  0.100 	 commit  0.100
# Training step 100 loss  0.522 	 recon  0.377 	 embed  0.115 	 commit  0.115
# Training step 200 loss  0.520 	 recon  0.377 	 embed  0.115 	 commit  0.115
# Training step 300 loss  0.440 	 recon  0.300 	 embed  0.112 	 commit  0.112
# ※※※Training loss  0.512 	 recon  0.367 	 embed  0.116 	 commit  0.116※※※
# ※※※Valid loss  0.514 	 recon  0.381 	 embed  0.106 	 commit  0.106※※※
# Epoch 28
# Training step 0 loss  0.496 	 recon  0.356 	 embed  0.112 	 commit  0.112
# Training step 100 loss  0.473 	 recon  0.322 	 embed  0.120 	 commit  0.120
# Training step 200 loss  0.569 	 recon  0.390 	 embed  0.143 	 commit  0.143
# Training step 300 loss  0.545 	 recon  0.381 	 embed  0.131 	 commit  0.131
# ※※※Training loss  0.528 	 recon  0.374 	 embed  0.123 	 commit  0.123※※※
# ※※※Valid loss  0.595 	 recon  0.434 	 embed  0.128 	 commit  0.128※※※
# Epoch 29
# Training step 0 loss  0.536 	 recon  0.379 	 embed  0.125 	 commit  0.125
# Training step 100 loss  0.545 	 recon  0.393 	 embed  0.121 	 commit  0.121
# Training step 200 loss  0.551 	 recon  0.394 	 embed  0.125 	 commit  0.125
# Training step 300 loss  0.535 	 recon  0.385 	 embed  0.120 	 commit  0.120
# ※※※Training loss  0.527 	 recon  0.375 	 embed  0.121 	 commit  0.121※※※
# ※※※Valid loss  0.530 	 recon  0.386 	 embed  0.116 	 commit  0.116※※※
# Epoch 30
# Training step 0 loss  0.471 	 recon  0.327 	 embed  0.115 	 commit  0.115
# Training step 100 loss  0.563 	 recon  0.399 	 embed  0.131 	 commit  0.131
# Training step 200 loss  0.539 	 recon  0.388 	 embed  0.121 	 commit  0.121
# Training step 300 loss  0.492 	 recon  0.344 	 embed  0.118 	 commit  0.118
# ※※※Training loss  0.518 	 recon  0.363 	 embed  0.124 	 commit  0.124※※※
# ※※※Valid loss  0.527 	 recon  0.376 	 embed  0.121 	 commit  0.121※※※
# Epoch 31
# Training step 0 loss  0.639 	 recon  0.453 	 embed  0.149 	 commit  0.149
# Training step 100 loss  0.635 	 recon  0.474 	 embed  0.129 	 commit  0.129
# Training step 200 loss  0.545 	 recon  0.377 	 embed  0.134 	 commit  0.134
# Training step 300 loss  0.591 	 recon  0.408 	 embed  0.147 	 commit  0.147
# ※※※Training loss  0.530 	 recon  0.369 	 embed  0.129 	 commit  0.129※※※
# ※※※Valid loss  0.524 	 recon  0.372 	 embed  0.122 	 commit  0.122※※※
# Epoch 32
# Training step 0 loss  0.467 	 recon  0.323 	 embed  0.115 	 commit  0.115
# Training step 100 loss  0.535 	 recon  0.383 	 embed  0.121 	 commit  0.121
# Training step 200 loss  0.579 	 recon  0.414 	 embed  0.132 	 commit  0.132
# Training step 300 loss  0.512 	 recon  0.353 	 embed  0.128 	 commit  0.128
# ※※※Training loss  0.529 	 recon  0.367 	 embed  0.130 	 commit  0.130※※※
# ※※※Valid loss  0.530 	 recon  0.373 	 embed  0.125 	 commit  0.125※※※
# Epoch 33
# Training step 0 loss  0.505 	 recon  0.355 	 embed  0.120 	 commit  0.120
# Training step 100 loss  0.516 	 recon  0.358 	 embed  0.127 	 commit  0.127
# Training step 200 loss  0.583 	 recon  0.385 	 embed  0.158 	 commit  0.158
# Training step 300 loss  0.547 	 recon  0.381 	 embed  0.133 	 commit  0.133
# ※※※Training loss  0.528 	 recon  0.361 	 embed  0.134 	 commit  0.134※※※
# ※※※Valid loss  0.531 	 recon  0.371 	 embed  0.128 	 commit  0.128※※※
# Epoch 34
# Training step 0 loss  0.554 	 recon  0.393 	 embed  0.129 	 commit  0.129
# Training step 100 loss  0.497 	 recon  0.350 	 embed  0.117 	 commit  0.117
# Training step 200 loss  0.548 	 recon  0.378 	 embed  0.136 	 commit  0.136
# Training step 300 loss  0.503 	 recon  0.332 	 embed  0.137 	 commit  0.137
# ※※※Training loss  0.528 	 recon  0.357 	 embed  0.137 	 commit  0.137※※※
# ※※※Valid loss  0.540 	 recon  0.369 	 embed  0.137 	 commit  0.137※※※
# Epoch 35
# Training step 0 loss  0.551 	 recon  0.359 	 embed  0.153 	 commit  0.153
# Training step 100 loss  0.517 	 recon  0.320 	 embed  0.158 	 commit  0.158
# Training step 200 loss  0.572 	 recon  0.374 	 embed  0.159 	 commit  0.159
# Training step 300 loss  0.565 	 recon  0.372 	 embed  0.155 	 commit  0.155
# ※※※Training loss  0.533 	 recon  0.356 	 embed  0.142 	 commit  0.142※※※
# ※※※Valid loss  0.538 	 recon  0.366 	 embed  0.138 	 commit  0.138※※※
# Epoch 36
# Training step 0 loss  0.536 	 recon  0.354 	 embed  0.146 	 commit  0.146
# Training step 100 loss  0.599 	 recon  0.404 	 embed  0.156 	 commit  0.156
# Training step 200 loss  0.466 	 recon  0.289 	 embed  0.142 	 commit  0.142
# Training step 300 loss  0.583 	 recon  0.385 	 embed  0.158 	 commit  0.158
# ※※※Training loss  0.541 	 recon  0.358 	 embed  0.147 	 commit  0.147※※※
# ※※※Valid loss  0.547 	 recon  0.366 	 embed  0.145 	 commit  0.145※※※
# Epoch 37
# Training step 0 loss  0.535 	 recon  0.355 	 embed  0.143 	 commit  0.143
# Training step 100 loss  0.491 	 recon  0.318 	 embed  0.139 	 commit  0.139
# Training step 200 loss  0.544 	 recon  0.352 	 embed  0.154 	 commit  0.154
# Training step 300 loss  0.527 	 recon  0.345 	 embed  0.146 	 commit  0.146
# ※※※Training loss  0.540 	 recon  0.356 	 embed  0.147 	 commit  0.147※※※
# ※※※Valid loss  0.541 	 recon  0.369 	 embed  0.138 	 commit  0.138※※※
# Epoch 38
# Training step 0 loss  0.519 	 recon  0.341 	 embed  0.142 	 commit  0.142
# Training step 100 loss  0.519 	 recon  0.344 	 embed  0.140 	 commit  0.140
# Training step 200 loss  0.579 	 recon  0.371 	 embed  0.167 	 commit  0.167
# Training step 300 loss  0.512 	 recon  0.340 	 embed  0.138 	 commit  0.138
# ※※※Training loss  0.544 	 recon  0.354 	 embed  0.151 	 commit  0.151※※※
# ※※※Valid loss  0.645 	 recon  0.439 	 embed  0.165 	 commit  0.165※※※
# Epoch 39
# Training step 0 loss  0.735 	 recon  0.471 	 embed  0.212 	 commit  0.212
# Training step 100 loss  0.595 	 recon  0.372 	 embed  0.178 	 commit  0.178
# Training step 200 loss  0.581 	 recon  0.360 	 embed  0.176 	 commit  0.176
# Training step 300 loss  0.496 	 recon  0.315 	 embed  0.146 	 commit  0.146
# ※※※Training loss  0.560 	 recon  0.360 	 embed  0.160 	 commit  0.160※※※
# ※※※Valid loss  0.556 	 recon  0.362 	 embed  0.155 	 commit  0.155※※※
# Epoch 40
# Training step 0 loss  0.571 	 recon  0.376 	 embed  0.155 	 commit  0.155
# Training step 100 loss  0.517 	 recon  0.339 	 embed  0.142 	 commit  0.142
# Training step 200 loss  0.506 	 recon  0.327 	 embed  0.143 	 commit  0.143
# Training step 300 loss  0.516 	 recon  0.320 	 embed  0.157 	 commit  0.157
# ※※※Training loss  0.544 	 recon  0.348 	 embed  0.157 	 commit  0.157※※※
# ※※※Valid loss  0.551 	 recon  0.366 	 embed  0.148 	 commit  0.148※※※
# Epoch 41
# Training step 0 loss  0.603 	 recon  0.401 	 embed  0.161 	 commit  0.161
# Training step 100 loss  0.542 	 recon  0.334 	 embed  0.166 	 commit  0.166
# Training step 200 loss  0.664 	 recon  0.433 	 embed  0.185 	 commit  0.185
# Training step 300 loss  0.573 	 recon  0.361 	 embed  0.169 	 commit  0.169
# ※※※Training loss  0.551 	 recon  0.352 	 embed  0.159 	 commit  0.159※※※
# ※※※Valid loss  0.570 	 recon  0.369 	 embed  0.160 	 commit  0.160※※※
# Epoch 42
# Training step 0 loss  0.591 	 recon  0.378 	 embed  0.170 	 commit  0.170
# Training step 100 loss  0.575 	 recon  0.358 	 embed  0.173 	 commit  0.173
# Training step 200 loss  0.544 	 recon  0.334 	 embed  0.168 	 commit  0.168
# Training step 300 loss  0.501 	 recon  0.311 	 embed  0.152 	 commit  0.152
# ※※※Training loss  0.552 	 recon  0.348 	 embed  0.163 	 commit  0.163※※※
# ※※※Valid loss  0.566 	 recon  0.362 	 embed  0.163 	 commit  0.163※※※
# Epoch 43
# Training step 0 loss  0.590 	 recon  0.371 	 embed  0.174 	 commit  0.174
# Training step 100 loss  0.555 	 recon  0.360 	 embed  0.156 	 commit  0.156
# Training step 200 loss  0.679 	 recon  0.444 	 embed  0.188 	 commit  0.188
# Training step 300 loss  0.578 	 recon  0.374 	 embed  0.163 	 commit  0.163
# ※※※Training loss  0.553 	 recon  0.349 	 embed  0.163 	 commit  0.163※※※
# ※※※Valid loss  0.557 	 recon  0.360 	 embed  0.158 	 commit  0.158※※※
# Epoch 44
# Training step 0 loss  0.531 	 recon  0.342 	 embed  0.151 	 commit  0.151
# Training step 100 loss  0.519 	 recon  0.326 	 embed  0.155 	 commit  0.155
# Training step 200 loss  0.542 	 recon  0.337 	 embed  0.164 	 commit  0.164
# Training step 300 loss  0.563 	 recon  0.346 	 embed  0.173 	 commit  0.173
# ※※※Training loss  0.550 	 recon  0.343 	 embed  0.165 	 commit  0.165※※※
# ※※※Valid loss  0.565 	 recon  0.360 	 embed  0.164 	 commit  0.164※※※
# Epoch 45
# Training step 0 loss  0.519 	 recon  0.331 	 embed  0.150 	 commit  0.150
# Training step 100 loss  0.521 	 recon  0.327 	 embed  0.155 	 commit  0.155
# Training step 200 loss  0.586 	 recon  0.357 	 embed  0.184 	 commit  0.184
# Training step 300 loss  0.539 	 recon  0.327 	 embed  0.169 	 commit  0.169
# ※※※Training loss  0.549 	 recon  0.341 	 embed  0.167 	 commit  0.167※※※
# ※※※Valid loss  0.566 	 recon  0.356 	 embed  0.169 	 commit  0.169※※※
# Epoch 46
# Training step 0 loss  0.591 	 recon  0.358 	 embed  0.187 	 commit  0.187
# Training step 100 loss  0.571 	 recon  0.356 	 embed  0.172 	 commit  0.172
# Training step 200 loss  0.516 	 recon  0.324 	 embed  0.154 	 commit  0.154
# Training step 300 loss  0.539 	 recon  0.337 	 embed  0.162 	 commit  0.162
# ※※※Training loss  0.553 	 recon  0.339 	 embed  0.171 	 commit  0.171※※※
# ※※※Valid loss  0.561 	 recon  0.355 	 embed  0.165 	 commit  0.165※※※
# Epoch 47
# Training step 0 loss  0.572 	 recon  0.339 	 embed  0.186 	 commit  0.186
# Training step 100 loss  0.515 	 recon  0.315 	 embed  0.160 	 commit  0.160
# Training step 200 loss  0.507 	 recon  0.313 	 embed  0.155 	 commit  0.155
# Training step 300 loss  0.541 	 recon  0.333 	 embed  0.167 	 commit  0.167
# ※※※Training loss  0.561 	 recon  0.342 	 embed  0.176 	 commit  0.176※※※
# ※※※Valid loss  0.563 	 recon  0.356 	 embed  0.165 	 commit  0.165※※※
# Epoch 48
# Training step 0 loss  0.541 	 recon  0.335 	 embed  0.165 	 commit  0.165
# Training step 100 loss  0.594 	 recon  0.338 	 embed  0.204 	 commit  0.204
# Training step 200 loss  0.540 	 recon  0.319 	 embed  0.177 	 commit  0.177
# Training step 300 loss  0.504 	 recon  0.300 	 embed  0.163 	 commit  0.163
# ※※※Training loss  0.557 	 recon  0.336 	 embed  0.177 	 commit  0.177※※※
# ※※※Valid loss  0.559 	 recon  0.352 	 embed  0.166 	 commit  0.166※※※
# Epoch 49
# Training step 0 loss  0.516 	 recon  0.310 	 embed  0.165 	 commit  0.165
# Training step 100 loss  0.544 	 recon  0.347 	 embed  0.158 	 commit  0.158
# Training step 200 loss  0.547 	 recon  0.326 	 embed  0.177 	 commit  0.177
# Training step 300 loss  0.612 	 recon  0.353 	 embed  0.207 	 commit  0.207
# ※※※Training loss  0.570 	 recon  0.343 	 embed  0.182 	 commit  0.182※※※
# ※※※Valid loss  0.584 	 recon  0.366 	 embed  0.175 	 commit  0.175※※※
# Epoch 50
# Training step 0 loss  0.568 	 recon  0.339 	 embed  0.183 	 commit  0.183
# Training step 100 loss  0.545 	 recon  0.329 	 embed  0.173 	 commit  0.173
# Training step 200 loss  0.651 	 recon  0.414 	 embed  0.189 	 commit  0.189
# Training step 300 loss  0.577 	 recon  0.344 	 embed  0.186 	 commit  0.186
# ※※※Training loss  0.564 	 recon  0.338 	 embed  0.181 	 commit  0.181※※※
# ※※※Valid loss  0.566 	 recon  0.347 	 embed  0.176 	 commit  0.176※※※
# Epoch 51
# Training step 0 loss  0.544 	 recon  0.320 	 embed  0.179 	 commit  0.179
# Training step 100 loss  0.588 	 recon  0.343 	 embed  0.196 	 commit  0.196
# Training step 200 loss  0.570 	 recon  0.334 	 embed  0.189 	 commit  0.189
# Training step 300 loss  0.630 	 recon  0.395 	 embed  0.188 	 commit  0.188
# ※※※Training loss  0.566 	 recon  0.335 	 embed  0.185 	 commit  0.185※※※
# ※※※Valid loss  0.572 	 recon  0.347 	 embed  0.180 	 commit  0.180※※※
# Epoch 52
# Training step 0 loss  0.530 	 recon  0.312 	 embed  0.174 	 commit  0.174
# Training step 100 loss  0.536 	 recon  0.321 	 embed  0.172 	 commit  0.172
# Training step 200 loss  0.564 	 recon  0.340 	 embed  0.180 	 commit  0.180
# Training step 300 loss  0.543 	 recon  0.290 	 embed  0.202 	 commit  0.202
# ※※※Training loss  0.562 	 recon  0.329 	 embed  0.186 	 commit  0.186※※※
# ※※※Valid loss  0.574 	 recon  0.348 	 embed  0.181 	 commit  0.181※※※
# Epoch 53
# Training step 0 loss  0.555 	 recon  0.300 	 embed  0.204 	 commit  0.204
# Training step 100 loss  0.478 	 recon  0.274 	 embed  0.163 	 commit  0.163
# Training step 200 loss  0.555 	 recon  0.319 	 embed  0.189 	 commit  0.189
# Training step 300 loss  0.547 	 recon  0.316 	 embed  0.185 	 commit  0.185
# ※※※Training loss  0.565 	 recon  0.327 	 embed  0.191 	 commit  0.191※※※
# ※※※Valid loss  0.573 	 recon  0.341 	 embed  0.186 	 commit  0.186※※※
# Epoch 54
# Training step 0 loss  0.553 	 recon  0.322 	 embed  0.185 	 commit  0.185
# Training step 100 loss  0.608 	 recon  0.363 	 embed  0.196 	 commit  0.196
# Training step 200 loss  0.535 	 recon  0.296 	 embed  0.192 	 commit  0.192
# Training step 300 loss  0.609 	 recon  0.320 	 embed  0.231 	 commit  0.231
# ※※※Training loss  0.570 	 recon  0.326 	 embed  0.195 	 commit  0.195※※※
# ※※※Valid loss  0.577 	 recon  0.341 	 embed  0.189 	 commit  0.189※※※
# Epoch 55
# Training step 0 loss  0.577 	 recon  0.325 	 embed  0.202 	 commit  0.202
# Training step 100 loss  0.611 	 recon  0.368 	 embed  0.194 	 commit  0.194
# Training step 200 loss  0.539 	 recon  0.309 	 embed  0.184 	 commit  0.184
# Training step 300 loss  0.609 	 recon  0.347 	 embed  0.209 	 commit  0.209
# ※※※Training loss  0.584 	 recon  0.338 	 embed  0.197 	 commit  0.197※※※
# ※※※Valid loss  0.586 	 recon  0.351 	 embed  0.188 	 commit  0.188※※※
# Epoch 56
# Training step 0 loss  0.596 	 recon  0.338 	 embed  0.206 	 commit  0.206
# Training step 100 loss  0.561 	 recon  0.334 	 embed  0.182 	 commit  0.182
# Training step 200 loss  0.655 	 recon  0.396 	 embed  0.207 	 commit  0.207
# Training step 300 loss  0.587 	 recon  0.332 	 embed  0.204 	 commit  0.204
# ※※※Training loss  0.574 	 recon  0.328 	 embed  0.197 	 commit  0.197※※※
# ※※※Valid loss  0.582 	 recon  0.342 	 embed  0.192 	 commit  0.192※※※
# Epoch 57
# Training step 0 loss  0.553 	 recon  0.300 	 embed  0.202 	 commit  0.202
# Training step 100 loss  0.564 	 recon  0.315 	 embed  0.199 	 commit  0.199
# Training step 200 loss  0.617 	 recon  0.374 	 embed  0.195 	 commit  0.195
# Training step 300 loss  0.563 	 recon  0.309 	 embed  0.203 	 commit  0.203
# ※※※Training loss  0.575 	 recon  0.324 	 embed  0.201 	 commit  0.201※※※
# ※※※Valid loss  0.580 	 recon  0.337 	 embed  0.194 	 commit  0.194※※※
# Epoch 58
# Training step 0 loss  0.650 	 recon  0.369 	 embed  0.225 	 commit  0.225
# Training step 100 loss  0.602 	 recon  0.330 	 embed  0.217 	 commit  0.217
# Training step 200 loss  0.551 	 recon  0.290 	 embed  0.208 	 commit  0.208
# Training step 300 loss  0.554 	 recon  0.307 	 embed  0.197 	 commit  0.197
# ※※※Training loss  0.578 	 recon  0.322 	 embed  0.205 	 commit  0.205※※※
# ※※※Valid loss  0.583 	 recon  0.337 	 embed  0.197 	 commit  0.197※※※
# Epoch 59
# Training step 0 loss  0.515 	 recon  0.304 	 embed  0.169 	 commit  0.169
# Training step 100 loss  0.570 	 recon  0.299 	 embed  0.217 	 commit  0.217
# Training step 200 loss  0.524 	 recon  0.296 	 embed  0.182 	 commit  0.182
# Training step 300 loss  0.637 	 recon  0.374 	 embed  0.210 	 commit  0.210
# ※※※Training loss  0.579 	 recon  0.319 	 embed  0.208 	 commit  0.208※※※
# ※※※Valid loss  0.593 	 recon  0.338 	 embed  0.204 	 commit  0.204※※※
# Epoch 60
# Training step 0 loss  0.578 	 recon  0.307 	 embed  0.217 	 commit  0.217
# Training step 100 loss  0.529 	 recon  0.303 	 embed  0.180 	 commit  0.180
# Training step 200 loss  0.607 	 recon  0.355 	 embed  0.202 	 commit  0.202
# Training step 300 loss  0.618 	 recon  0.320 	 embed  0.239 	 commit  0.239
# ※※※Training loss  0.581 	 recon  0.319 	 embed  0.210 	 commit  0.210※※※
# ※※※Valid loss  0.587 	 recon  0.334 	 embed  0.202 	 commit  0.202※※※
# Epoch 61
# Training step 0 loss  0.569 	 recon  0.287 	 embed  0.226 	 commit  0.226
# Training step 100 loss  0.596 	 recon  0.322 	 embed  0.219 	 commit  0.219
# Training step 200 loss  0.575 	 recon  0.321 	 embed  0.203 	 commit  0.203
# Training step 300 loss  0.592 	 recon  0.319 	 embed  0.218 	 commit  0.218
# ※※※Training loss  0.583 	 recon  0.317 	 embed  0.213 	 commit  0.213※※※
# ※※※Valid loss  0.585 	 recon  0.330 	 embed  0.204 	 commit  0.204※※※
# Epoch 62
# Training step 0 loss  0.682 	 recon  0.374 	 embed  0.247 	 commit  0.247
# Training step 100 loss  0.612 	 recon  0.346 	 embed  0.213 	 commit  0.213
# Training step 200 loss  0.570 	 recon  0.308 	 embed  0.209 	 commit  0.209
# Training step 300 loss  0.528 	 recon  0.299 	 embed  0.183 	 commit  0.183
# ※※※Training loss  0.584 	 recon  0.319 	 embed  0.212 	 commit  0.212※※※
# ※※※Valid loss  0.580 	 recon  0.328 	 embed  0.202 	 commit  0.202※※※
# Epoch 63
# Training step 0 loss  0.604 	 recon  0.317 	 embed  0.229 	 commit  0.229
# Training step 100 loss  0.597 	 recon  0.332 	 embed  0.211 	 commit  0.211
# Training step 200 loss  0.569 	 recon  0.328 	 embed  0.193 	 commit  0.193
# Training step 300 loss  0.529 	 recon  0.277 	 embed  0.201 	 commit  0.201
# ※※※Training loss  0.581 	 recon  0.314 	 embed  0.214 	 commit  0.214※※※
# ※※※Valid loss  0.584 	 recon  0.330 	 embed  0.203 	 commit  0.203※※※
# Epoch 64
# Training step 0 loss  0.558 	 recon  0.292 	 embed  0.213 	 commit  0.213
# Training step 100 loss  0.546 	 recon  0.297 	 embed  0.199 	 commit  0.199
# Training step 200 loss  0.564 	 recon  0.307 	 embed  0.205 	 commit  0.205
# Training step 300 loss  0.535 	 recon  0.268 	 embed  0.214 	 commit  0.214
# ※※※Training loss  0.581 	 recon  0.313 	 embed  0.215 	 commit  0.215※※※
# ※※※Valid loss  0.586 	 recon  0.330 	 embed  0.205 	 commit  0.205※※※
# Epoch 65
# Training step 0 loss  0.609 	 recon  0.309 	 embed  0.239 	 commit  0.239
# Training step 100 loss  0.590 	 recon  0.302 	 embed  0.230 	 commit  0.230
# Training step 200 loss  0.599 	 recon  0.312 	 embed  0.230 	 commit  0.230
# Training step 300 loss  0.601 	 recon  0.329 	 embed  0.217 	 commit  0.217
# ※※※Training loss  0.586 	 recon  0.312 	 embed  0.219 	 commit  0.219※※※
# ※※※Valid loss  0.594 	 recon  0.328 	 embed  0.213 	 commit  0.213※※※
# Epoch 66
# Training step 0 loss  0.572 	 recon  0.293 	 embed  0.223 	 commit  0.223
# Training step 100 loss  0.562 	 recon  0.297 	 embed  0.212 	 commit  0.212
# Training step 200 loss  0.502 	 recon  0.244 	 embed  0.206 	 commit  0.206
# Training step 300 loss  0.579 	 recon  0.320 	 embed  0.207 	 commit  0.207
# ※※※Training loss  0.588 	 recon  0.312 	 embed  0.221 	 commit  0.221※※※
# ※※※Valid loss  0.590 	 recon  0.327 	 embed  0.210 	 commit  0.210※※※
# Epoch 67
# Training step 0 loss  0.617 	 recon  0.326 	 embed  0.232 	 commit  0.232
# Training step 100 loss  0.606 	 recon  0.315 	 embed  0.233 	 commit  0.233
# Training step 200 loss  0.624 	 recon  0.317 	 embed  0.245 	 commit  0.245
# Training step 300 loss  0.536 	 recon  0.281 	 embed  0.204 	 commit  0.204
# ※※※Training loss  0.589 	 recon  0.310 	 embed  0.223 	 commit  0.223※※※
# ※※※Valid loss  0.600 	 recon  0.328 	 embed  0.218 	 commit  0.218※※※
# Epoch 68
# Training step 0 loss  0.594 	 recon  0.305 	 embed  0.231 	 commit  0.231
# Training step 100 loss  0.592 	 recon  0.330 	 embed  0.209 	 commit  0.209
# Training step 200 loss  0.573 	 recon  0.300 	 embed  0.218 	 commit  0.218
# Training step 300 loss  0.608 	 recon  0.340 	 embed  0.215 	 commit  0.215
# ※※※Training loss  0.590 	 recon  0.310 	 embed  0.224 	 commit  0.224※※※
# ※※※Valid loss  0.590 	 recon  0.325 	 embed  0.212 	 commit  0.212※※※
# Epoch 69
# Training step 0 loss  0.600 	 recon  0.290 	 embed  0.248 	 commit  0.248
# Training step 100 loss  0.582 	 recon  0.302 	 embed  0.224 	 commit  0.224
# Training step 200 loss  0.610 	 recon  0.291 	 embed  0.255 	 commit  0.255
# Training step 300 loss  0.586 	 recon  0.278 	 embed  0.247 	 commit  0.247
# ※※※Training loss  0.591 	 recon  0.310 	 embed  0.225 	 commit  0.225※※※
# ※※※Valid loss  0.587 	 recon  0.326 	 embed  0.209 	 commit  0.209※※※
# Epoch 70
# Training step 0 loss  0.624 	 recon  0.338 	 embed  0.229 	 commit  0.229
# Training step 100 loss  0.644 	 recon  0.349 	 embed  0.236 	 commit  0.236
# Training step 200 loss  0.617 	 recon  0.318 	 embed  0.239 	 commit  0.239
# Training step 300 loss  0.640 	 recon  0.310 	 embed  0.264 	 commit  0.264
# ※※※Training loss  0.594 	 recon  0.309 	 embed  0.228 	 commit  0.228※※※
# ※※※Valid loss  0.596 	 recon  0.327 	 embed  0.216 	 commit  0.216※※※
# Epoch 71
# Training step 0 loss  0.573 	 recon  0.308 	 embed  0.212 	 commit  0.212
# Training step 100 loss  0.583 	 recon  0.287 	 embed  0.236 	 commit  0.236
# Training step 200 loss  0.575 	 recon  0.303 	 embed  0.218 	 commit  0.218
# Training step 300 loss  0.602 	 recon  0.299 	 embed  0.242 	 commit  0.242
# ※※※Training loss  0.597 	 recon  0.308 	 embed  0.231 	 commit  0.231※※※
# ※※※Valid loss  0.602 	 recon  0.327 	 embed  0.220 	 commit  0.220※※※
# Epoch 72
# Training step 0 loss  0.604 	 recon  0.309 	 embed  0.236 	 commit  0.236
# Training step 100 loss  0.650 	 recon  0.341 	 embed  0.247 	 commit  0.247
# Training step 200 loss  0.653 	 recon  0.344 	 embed  0.247 	 commit  0.247
# Training step 300 loss  0.618 	 recon  0.311 	 embed  0.245 	 commit  0.245
# ※※※Training loss  0.609 	 recon  0.311 	 embed  0.239 	 commit  0.239※※※
# ※※※Valid loss  0.597 	 recon  0.328 	 embed  0.216 	 commit  0.216※※※
# Epoch 73
# Training step 0 loss  0.619 	 recon  0.332 	 embed  0.229 	 commit  0.229
# Training step 100 loss  0.614 	 recon  0.331 	 embed  0.227 	 commit  0.227
# Training step 200 loss  0.603 	 recon  0.307 	 embed  0.237 	 commit  0.237
# Training step 300 loss  0.624 	 recon  0.310 	 embed  0.252 	 commit  0.252
# ※※※Training loss  0.606 	 recon  0.307 	 embed  0.239 	 commit  0.239※※※
# ※※※Valid loss  0.607 	 recon  0.326 	 embed  0.225 	 commit  0.225※※※
# Epoch 74
# Training step 0 loss  0.662 	 recon  0.352 	 embed  0.248 	 commit  0.248
# Training step 100 loss  0.616 	 recon  0.324 	 embed  0.233 	 commit  0.233
# Training step 200 loss  0.637 	 recon  0.314 	 embed  0.258 	 commit  0.258
# Training step 300 loss  0.608 	 recon  0.303 	 embed  0.244 	 commit  0.244
# ※※※Training loss  0.614 	 recon  0.308 	 embed  0.245 	 commit  0.245※※※
# ※※※Valid loss  0.608 	 recon  0.324 	 embed  0.228 	 commit  0.228※※※
# Epoch 75
# Training step 0 loss  0.592 	 recon  0.292 	 embed  0.240 	 commit  0.240
# Training step 100 loss  0.609 	 recon  0.283 	 embed  0.261 	 commit  0.261
# Training step 200 loss  0.564 	 recon  0.268 	 embed  0.237 	 commit  0.237
# Training step 300 loss  0.635 	 recon  0.317 	 embed  0.254 	 commit  0.254
# ※※※Training loss  0.623 	 recon  0.307 	 embed  0.253 	 commit  0.253※※※
# ※※※Valid loss  0.628 	 recon  0.328 	 embed  0.241 	 commit  0.241※※※
# Epoch 76
# Training step 0 loss  0.605 	 recon  0.293 	 embed  0.250 	 commit  0.250
# Training step 100 loss  0.643 	 recon  0.308 	 embed  0.268 	 commit  0.268
# Training step 200 loss  0.615 	 recon  0.299 	 embed  0.252 	 commit  0.252
# Training step 300 loss  0.623 	 recon  0.300 	 embed  0.258 	 commit  0.258
# ※※※Training loss  0.636 	 recon  0.306 	 embed  0.264 	 commit  0.264※※※
# ※※※Valid loss  0.634 	 recon  0.326 	 embed  0.246 	 commit  0.246※※※
# Epoch 77
# Training step 0 loss  0.670 	 recon  0.295 	 embed  0.300 	 commit  0.300
# Training step 100 loss  0.653 	 recon  0.304 	 embed  0.279 	 commit  0.279
# Training step 200 loss  0.702 	 recon  0.330 	 embed  0.298 	 commit  0.298
# Training step 300 loss  0.681 	 recon  0.291 	 embed  0.311 	 commit  0.311
# ※※※Training loss  0.650 	 recon  0.306 	 embed  0.275 	 commit  0.275※※※
# ※※※Valid loss  0.647 	 recon  0.324 	 embed  0.259 	 commit  0.259※※※
# Epoch 78
# Training step 0 loss  0.646 	 recon  0.300 	 embed  0.276 	 commit  0.276
# Training step 100 loss  0.665 	 recon  0.308 	 embed  0.286 	 commit  0.286
# Training step 200 loss  0.697 	 recon  0.330 	 embed  0.293 	 commit  0.293
# Training step 300 loss  0.615 	 recon  0.269 	 embed  0.277 	 commit  0.277
# ※※※Training loss  0.660 	 recon  0.305 	 embed  0.283 	 commit  0.283※※※
# ※※※Valid loss  0.666 	 recon  0.325 	 embed  0.273 	 commit  0.273※※※
# Epoch 79
# Training step 0 loss  0.615 	 recon  0.272 	 embed  0.274 	 commit  0.274
# Training step 100 loss  0.653 	 recon  0.309 	 embed  0.276 	 commit  0.276
# Training step 200 loss  0.619 	 recon  0.279 	 embed  0.272 	 commit  0.272
# Training step 300 loss  0.605 	 recon  0.275 	 embed  0.264 	 commit  0.264
# ※※※Training loss  0.674 	 recon  0.305 	 embed  0.295 	 commit  0.295※※※
# ※※※Valid loss  0.691 	 recon  0.322 	 embed  0.295 	 commit  0.295※※※
# Epoch 80
# Training step 0 loss  0.676 	 recon  0.321 	 embed  0.283 	 commit  0.283
# Training step 100 loss  0.699 	 recon  0.306 	 embed  0.314 	 commit  0.314
# Training step 200 loss  0.700 	 recon  0.306 	 embed  0.315 	 commit  0.315
# Training step 300 loss  0.712 	 recon  0.304 	 embed  0.327 	 commit  0.327
# ※※※Training loss  0.691 	 recon  0.306 	 embed  0.309 	 commit  0.309※※※
# ※※※Valid loss  0.690 	 recon  0.322 	 embed  0.294 	 commit  0.294※※※
# Epoch 81
# Training step 0 loss  0.676 	 recon  0.290 	 embed  0.308 	 commit  0.308
# Training step 100 loss  0.712 	 recon  0.318 	 embed  0.316 	 commit  0.316
# Training step 200 loss  0.707 	 recon  0.312 	 embed  0.316 	 commit  0.316
# Training step 300 loss  0.686 	 recon  0.301 	 embed  0.308 	 commit  0.308
# ※※※Training loss  0.704 	 recon  0.307 	 embed  0.317 	 commit  0.317※※※
# ※※※Valid loss  0.710 	 recon  0.323 	 embed  0.310 	 commit  0.310※※※
# Epoch 82
# Training step 0 loss  0.694 	 recon  0.299 	 embed  0.316 	 commit  0.316
# Training step 100 loss  0.732 	 recon  0.327 	 embed  0.325 	 commit  0.325
# Training step 200 loss  0.786 	 recon  0.331 	 embed  0.364 	 commit  0.364
# Training step 300 loss  0.653 	 recon  0.279 	 embed  0.300 	 commit  0.300
# ※※※Training loss  0.708 	 recon  0.304 	 embed  0.323 	 commit  0.323※※※
# ※※※Valid loss  0.707 	 recon  0.319 	 embed  0.310 	 commit  0.310※※※
# Epoch 83
# Training step 0 loss  0.673 	 recon  0.262 	 embed  0.328 	 commit  0.328
# Training step 100 loss  0.631 	 recon  0.264 	 embed  0.294 	 commit  0.294
# Training step 200 loss  0.723 	 recon  0.316 	 embed  0.326 	 commit  0.326
# Training step 300 loss  0.742 	 recon  0.307 	 embed  0.348 	 commit  0.348
# ※※※Training loss  0.709 	 recon  0.303 	 embed  0.324 	 commit  0.324※※※
# ※※※Valid loss  0.718 	 recon  0.320 	 embed  0.319 	 commit  0.319※※※
# Epoch 84
# Training step 0 loss  0.752 	 recon  0.332 	 embed  0.336 	 commit  0.336
# Training step 100 loss  0.741 	 recon  0.302 	 embed  0.351 	 commit  0.351
# Training step 200 loss  0.704 	 recon  0.297 	 embed  0.325 	 commit  0.325
# Training step 300 loss  0.736 	 recon  0.301 	 embed  0.348 	 commit  0.348
# ※※※Training loss  0.712 	 recon  0.302 	 embed  0.328 	 commit  0.328※※※
# ※※※Valid loss  0.723 	 recon  0.317 	 embed  0.325 	 commit  0.325※※※
# Epoch 85
# Training step 0 loss  0.723 	 recon  0.301 	 embed  0.337 	 commit  0.337
# Training step 100 loss  0.679 	 recon  0.299 	 embed  0.304 	 commit  0.304
# Training step 200 loss  0.718 	 recon  0.290 	 embed  0.342 	 commit  0.342
# Training step 300 loss  0.728 	 recon  0.304 	 embed  0.339 	 commit  0.339
# ※※※Training loss  0.714 	 recon  0.301 	 embed  0.330 	 commit  0.330※※※
# ※※※Valid loss  0.727 	 recon  0.316 	 embed  0.329 	 commit  0.329※※※
# Epoch 86
# Training step 0 loss  0.661 	 recon  0.299 	 embed  0.289 	 commit  0.289
# Training step 100 loss  0.740 	 recon  0.296 	 embed  0.356 	 commit  0.356
# Training step 200 loss  0.687 	 recon  0.285 	 embed  0.321 	 commit  0.321
# Training step 300 loss  0.704 	 recon  0.299 	 embed  0.325 	 commit  0.325
# ※※※Training loss  0.712 	 recon  0.301 	 embed  0.329 	 commit  0.329※※※
# ※※※Valid loss  0.725 	 recon  0.317 	 embed  0.327 	 commit  0.327※※※
# Epoch 87
# Training step 0 loss  0.690 	 recon  0.293 	 embed  0.318 	 commit  0.318
# Training step 100 loss  0.720 	 recon  0.273 	 embed  0.357 	 commit  0.357
# Training step 200 loss  0.652 	 recon  0.263 	 embed  0.311 	 commit  0.311
# Training step 300 loss  0.721 	 recon  0.284 	 embed  0.349 	 commit  0.349
# ※※※Training loss  0.714 	 recon  0.301 	 embed  0.330 	 commit  0.330※※※
# ※※※Valid loss  0.717 	 recon  0.316 	 embed  0.321 	 commit  0.321※※※
# Epoch 88
# Training step 0 loss  0.755 	 recon  0.310 	 embed  0.355 	 commit  0.355
# Training step 100 loss  0.711 	 recon  0.269 	 embed  0.354 	 commit  0.354
# Training step 200 loss  0.703 	 recon  0.310 	 embed  0.315 	 commit  0.315
# Training step 300 loss  0.668 	 recon  0.280 	 embed  0.310 	 commit  0.310
# ※※※Training loss  0.711 	 recon  0.300 	 embed  0.329 	 commit  0.329※※※
# ※※※Valid loss  0.727 	 recon  0.318 	 embed  0.326 	 commit  0.326※※※
# Epoch 89
# Training step 0 loss  0.740 	 recon  0.336 	 embed  0.323 	 commit  0.323
# Training step 100 loss  0.715 	 recon  0.287 	 embed  0.342 	 commit  0.342
# Training step 200 loss  0.724 	 recon  0.296 	 embed  0.342 	 commit  0.342
# Training step 300 loss  0.755 	 recon  0.316 	 embed  0.352 	 commit  0.352
# ※※※Training loss  0.714 	 recon  0.299 	 embed  0.332 	 commit  0.332※※※
# ※※※Valid loss  0.737 	 recon  0.316 	 embed  0.337 	 commit  0.337※※※
# Epoch 90
# Training step 0 loss  0.694 	 recon  0.301 	 embed  0.314 	 commit  0.314
# Training step 100 loss  0.696 	 recon  0.272 	 embed  0.339 	 commit  0.339
# Training step 200 loss  0.688 	 recon  0.286 	 embed  0.321 	 commit  0.321
# Training step 300 loss  0.674 	 recon  0.273 	 embed  0.321 	 commit  0.321
# ※※※Training loss  0.714 	 recon  0.300 	 embed  0.331 	 commit  0.331※※※
# ※※※Valid loss  0.716 	 recon  0.313 	 embed  0.323 	 commit  0.323※※※
# Epoch 91
# Training step 0 loss  0.729 	 recon  0.286 	 embed  0.354 	 commit  0.354
# Training step 100 loss  0.705 	 recon  0.296 	 embed  0.328 	 commit  0.328
# Training step 200 loss  0.679 	 recon  0.286 	 embed  0.314 	 commit  0.314
# Training step 300 loss  0.740 	 recon  0.302 	 embed  0.350 	 commit  0.350
# ※※※Training loss  0.713 	 recon  0.299 	 embed  0.332 	 commit  0.332※※※
# ※※※Valid loss  0.723 	 recon  0.311 	 embed  0.329 	 commit  0.329※※※
# Epoch 92
# Training step 0 loss  0.726 	 recon  0.305 	 embed  0.337 	 commit  0.337
# Training step 100 loss  0.766 	 recon  0.329 	 embed  0.350 	 commit  0.350
# Training step 200 loss  0.795 	 recon  0.336 	 embed  0.367 	 commit  0.367
# Training step 300 loss  0.704 	 recon  0.287 	 embed  0.334 	 commit  0.334
# ※※※Training loss  0.714 	 recon  0.298 	 embed  0.332 	 commit  0.332※※※
# ※※※Valid loss  0.736 	 recon  0.314 	 embed  0.338 	 commit  0.338※※※
# Epoch 93
# Training step 0 loss  0.720 	 recon  0.287 	 embed  0.347 	 commit  0.347
# Training step 100 loss  0.633 	 recon  0.263 	 embed  0.296 	 commit  0.296
# Training step 200 loss  0.762 	 recon  0.300 	 embed  0.370 	 commit  0.370
# Training step 300 loss  0.730 	 recon  0.292 	 embed  0.350 	 commit  0.350
# ※※※Training loss  0.715 	 recon  0.299 	 embed  0.333 	 commit  0.333※※※
# ※※※Valid loss  0.734 	 recon  0.315 	 embed  0.335 	 commit  0.335※※※
# Epoch 94
# Training step 0 loss  0.667 	 recon  0.291 	 embed  0.300 	 commit  0.300
# Training step 100 loss  0.649 	 recon  0.265 	 embed  0.307 	 commit  0.307
# Training step 200 loss  0.729 	 recon  0.307 	 embed  0.337 	 commit  0.337
# Training step 300 loss  0.712 	 recon  0.305 	 embed  0.326 	 commit  0.326
# ※※※Training loss  0.713 	 recon  0.297 	 embed  0.333 	 commit  0.333※※※
# ※※※Valid loss  0.733 	 recon  0.312 	 embed  0.336 	 commit  0.336※※※
# Epoch 95
# Training step 0 loss  0.723 	 recon  0.312 	 embed  0.329 	 commit  0.329
# Training step 100 loss  0.745 	 recon  0.300 	 embed  0.356 	 commit  0.356
# Training step 200 loss  0.748 	 recon  0.315 	 embed  0.346 	 commit  0.346
# Training step 300 loss  0.787 	 recon  0.345 	 embed  0.354 	 commit  0.354
# ※※※Training loss  0.713 	 recon  0.297 	 embed  0.333 	 commit  0.333※※※
# ※※※Valid loss  0.735 	 recon  0.312 	 embed  0.339 	 commit  0.339※※※
# Epoch 96
# Training step 0 loss  0.690 	 recon  0.267 	 embed  0.339 	 commit  0.339
# Training step 100 loss  0.653 	 recon  0.282 	 embed  0.297 	 commit  0.297
# Training step 200 loss  0.694 	 recon  0.277 	 embed  0.334 	 commit  0.334
# Training step 300 loss  0.720 	 recon  0.309 	 embed  0.328 	 commit  0.328
# ※※※Training loss  0.713 	 recon  0.297 	 embed  0.333 	 commit  0.333※※※
# ※※※Valid loss  0.718 	 recon  0.312 	 embed  0.325 	 commit  0.325※※※
# Epoch 97
# Training step 0 loss  0.673 	 recon  0.291 	 embed  0.305 	 commit  0.305
# Training step 100 loss  0.663 	 recon  0.285 	 embed  0.302 	 commit  0.302
# Training step 200 loss  0.625 	 recon  0.268 	 embed  0.286 	 commit  0.286
# Training step 300 loss  0.753 	 recon  0.325 	 embed  0.342 	 commit  0.342
# ※※※Training loss  0.713 	 recon  0.297 	 embed  0.333 	 commit  0.333※※※
# ※※※Valid loss  0.716 	 recon  0.312 	 embed  0.323 	 commit  0.323※※※
# Epoch 98
# Training step 0 loss  0.629 	 recon  0.263 	 embed  0.293 	 commit  0.293
# Training step 100 loss  0.684 	 recon  0.291 	 embed  0.314 	 commit  0.314
# Training step 200 loss  0.713 	 recon  0.294 	 embed  0.335 	 commit  0.335
# Training step 300 loss  0.741 	 recon  0.330 	 embed  0.328 	 commit  0.328
# ※※※Training loss  0.713 	 recon  0.296 	 embed  0.334 	 commit  0.334※※※
# ※※※Valid loss  0.736 	 recon  0.314 	 embed  0.338 	 commit  0.338※※※
# Epoch 99
# Training step 0 loss  0.686 	 recon  0.284 	 embed  0.322 	 commit  0.322
# Training step 100 loss  0.693 	 recon  0.263 	 embed  0.343 	 commit  0.343
# Training step 200 loss  0.731 	 recon  0.316 	 embed  0.333 	 commit  0.333
# Training step 300 loss  0.775 	 recon  0.310 	 embed  0.372 	 commit  0.372
# ※※※Training loss  0.716 	 recon  0.296 	 embed  0.336 	 commit  0.336※※※
# ※※※Valid loss  0.722 	 recon  0.311 	 embed  0.329 	 commit  0.329※※※

# %% [markdown]
# 觉得Loss位数保留太多的可以自己设置.
#
# 下面画出训练过程中训练集和验证集上的损失曲线:

# %%
train_losses.save()
train_recon_losses.save()
train_embedding_losses.save()
train_commitment_losses.save()
valid_losses.save()
valid_recon_losses.save()
valid_embedding_losses.save()
valid_commitment_losses.save()

# %%
start, end = 0, 100

fig, ((ax1, ax2), (ax3, ax4)) = plt.subplots(2, 2, figsize=(12, 4))
# Plot Loss on the left subplot
ax1.plot(train_losses.get()[start:end], label='Train')
ax1.plot(valid_losses.get()[start:end], label='Valid')
ax1.set_title("Learning Curve Loss")

# Plot Recon Loss on the right subplot
ax2.plot(train_recon_losses.get()[start:end], label='Train')
ax2.plot(valid_recon_losses.get()[start:end], label='Valid')
ax2.set_title("Learning Curve Recon Loss")

# Plot Embedding Loss on the left subplot
ax3.plot(train_embedding_losses.get()[start:end], label='Train')
ax3.plot(valid_embedding_losses.get()[start:end], label='Valid')
ax3.set_title("Learning Curve Embedding Loss")

# Plot Commitment Loss on the right subplot
ax4.plot(train_commitment_losses.get()[start:end], label='Train')
ax4.plot(valid_commitment_losses.get()[start:end], label='Valid')
ax4.set_title("Learning Curve Commitment Loss")
# Out:
# Text(0.5, 1.0, 'Learning Curve Commitment Loss')

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
l_reconstruct, l_embedding, l_commitment
# Out:
# (tensor(0.3002, device='cuda:0', grad_fn=<DivBackward0>),
#  tensor(0.3199, device='cuda:0', grad_fn=<DivBackward0>),
#  tensor(0.3199, device='cuda:0', grad_fn=<DivBackward0>))

# %% [markdown]
# 基本上Valid Loss稳定了(其实还有下降空间). 同时要保存在验证集上结果最好的模型, 因为等会还要用最好的模型做生成.

# %%
ts
# Out:
# '0301171500'
