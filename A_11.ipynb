# %% [markdown]
# # New Run
# A_01: Copy from SL_D_E_4.ipynb. Fixed the problem as we have found in normalization. This time we normalize over the whole course.
#
#
# A_05: This time we resume using two linear layers, one before RNN and one after. IN this way we make the last linear layer of both encoder and decoder
# a pure linear layer without other components.
#
# A_07: This time we delete the attention part of the decoder and make it completely autoregressive. See how it performs.
#
# A_08: Restore the inclusion of attention mechanism, and set the first input to decoder to all zero.
#
# A_10: This time we want to really try the autoregressive model and see how well it performs.

# %% [markdown]
# # Sequence Learning - Direct - English
# Version 1: In this version we make the model "simple": make the encoder RNN into normal RNN first and try to see the result.
# Version 2: Learning is not very much. Following Dr Coupe's advice we try simpler model structure.
# Version 3: A simple trial training with Mel spectrogram instead of MFCC.
# Version 4: try to enlarge the hidden dimensions so that we might still make sense of the hidden representation.

# %%
import torch
import torchaudio
from torch import nn
import torch.nn.functional as F
from torch.nn.utils.rnn import pad_sequence, pack_sequence
from torch import optim
from torch.utils.data import Dataset, DataLoader, random_split
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import pickle
from datetime import datetime
import random
from torchinfo import summary

# %%
from model import TwoLinNoAttentionPhxLearner as TheLearner
from my_dataset import DS_Tools
from dataset import SeqDataset, MelTransform, Normalizer, DeNormalizer
from dataset import MelSpecTransformNoDB as TheTransform
from paths import *
from my_utils import *
from recorder import *
from loss import *
from padding import generate_mask_from_lengths_mat, mask_it

# %% [markdown]
# ### Dirs

# %%
model_save_dir = model_eng_save_dir
# random_data:phone_seg_random_path
# anno_data: phone_seg_anno_path

# random_log_path = phone_seg_random_log_path + "log.csv"
random_log_path = word_seg_anno_log_path
random_path = word_seg_anno_path
anno_log_path = phone_seg_anno_path

# %% [markdown]
# ### Constants

# %%
BATCH_SIZE = 128

INPUT_DIM = 64
OUTPUT_DIM = 64 

INTER_DIM_0 = 32
INTER_DIM_1 = 16
INTER_DIM_2 = 8

ENC_SIZE_LIST = [INPUT_DIM, INTER_DIM_0, INTER_DIM_1, INTER_DIM_2]
DEC_SIZE_LIST = [OUTPUT_DIM, INTER_DIM_0, INTER_DIM_1, INTER_DIM_2]

DROPOUT = 0.5

REC_SAMPLE_RATE = 16000
N_FFT = 400
N_MELS = 64

LOADER_WORKER = 16
# LOADER_WORKER = 0

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
recon_loss = nn.MSELoss(reduction='none')
masked_recon_loss = MaskedLoss(recon_loss)
model_loss = masked_recon_loss

model = TheLearner(enc_size_list=ENC_SIZE_LIST, dec_size_list=DEC_SIZE_LIST, num_layers=1)
# model = TheLearner(enc_size_list=ENC_SIZE_LIST, dec_size_list=DEC_SIZE_LIST, num_layers=1)
model.to(device)
optimizer = optim.Adam(model.parameters(), lr=1e-3)

# %%
# # initialize model weights
# def init_weights(m):
#     if isinstance(m, nn.Linear):
#         torch.nn.init.orthogonal_(m.weight)
#         m.bias.data.fill_(0.01)
#     if isinstance(m, nn.LSTM): 
#         for name, p in m.named_parameters():
#             if "weight" in name: 
#                 nn.init.orthogonal_(p)
#             elif "bias" in name: 
#                 nn.init.constant_(p, 0)

# model.apply(init_weights)

# %%
model_parameters = filter(lambda p: p.requires_grad, model.parameters())
params = sum([np.prod(p.size()) for p in model_parameters])

# %%
params
# Out:
# 9416

# %%
# Just for keeping records of training hists. 
# ts = "0918192113"
stop_epoch = "149"
ts = str(get_timestamp())
save_txt_name = "train_txt_{}.hst".format(ts)
save_trainhist_name = "train_hist_{}.hst".format(ts)

save_valhist_name = "val_hist_{}.hst".format(ts)

# %%
train_losses = LossRecorder(model_save_dir + save_trainhist_name)

valid_losses = LossRecorder(model_save_dir + save_valhist_name)

text_hist = HistRecorder(model_save_dir + save_txt_name)

# %%
READ = False
# READ = True

# %%
if READ: 
    valid_losses.read()
    train_losses.read()

    model_raw_name = "PT_{}_{}_full".format(ts, stop_epoch)
    model_name = model_raw_name + ".pt"
    model_path = os.path.join(model_save_dir, model_name)
    state = torch.load(model_path)

    model.load_state_dict(state)
    model.to(device)

# %%
model
# Out:
# TwoLinNoAttentionPhxLearner(
#   (encoder): LRLEncoder(
#     (lin_1): LinearPack(
#       (linear): Linear(in_features=64, out_features=32, bias=True)
#       (relu): ReLU()
#       (dropout): Dropout(p=0.5, inplace=False)
#     )
#     (rnn): LSTM(32, 16, batch_first=True)
#     (lin_2): Linear(in_features=16, out_features=8, bias=True)
#   )
#   (decoder): LRLDecoder(
#     (lin_1): LinearPack(
#       (linear): Linear(in_features=64, out_features=32, bias=True)
#       (relu): ReLU()
#       (dropout): Dropout(p=0.5, inplace=False)
#     )
#     (rnn): LSTM(32, 8, batch_first=True)
#     (lin_3): Linear(in_features=8, out_features=64, bias=True)
#     (last_element_extractor): LastElementExtractor()
#   )
# )

# %%
DATAREAD = False

# %%
# mytrans = MelSpecTransform(sample_rate=REC_SAMPLE_RATE, n_fft=N_FFT, n_mels=N_MELS)
# mytrans = nn.Sequential(
#     MelTransform(sample_rate=REC_SAMPLE_RATE, n_fft=N_FFT, n_mels=N_MELS),
#     # torchaudio.transforms.AmplitudeToDB(stype="power", top_db=80), 
#     Normalizer(Normalizer.norm_strip_minmax)
# )
# mytrans = TheTransform(sample_rate=REC_SAMPLE_RATE, n_fft=N_FFT, n_mels=N_MELS, normalizer=Normalizer.norm_strip_mvn, denormalizer=DeNormalizer.norm_strip_mvn)
mytrans = TheTransform(sample_rate=REC_SAMPLE_RATE, n_fft=N_FFT, n_mels=N_MELS, normalizer=Normalizer.norm_mvn, denormalizer=DeNormalizer.norm_mvn)
ds = SeqDataset(random_path, os.path.join(random_log_path, "log.csv"), transform=mytrans)

test = False
if test: 
    use_len = int(0.1 * len(ds))
    remain_len = len(ds) - use_len

    # Randomly split the dataset into train and validation sets
    ds, remain_ds = random_split(ds, [use_len, remain_len])


if READ or DATAREAD: 
    valid_ds_indices = DS_Tools.read_indices(os.path.join(model_save_dir, "valid_ds_{}.pkl".format(ts)))
    all_indices = list(range(len(ds)))
    train_ds_indices = list(set(all_indices).difference(set(valid_ds_indices)))

    train_ds = torch.utils.data.Subset(ds, train_ds_indices)
    valid_ds = torch.utils.data.Subset(ds, valid_ds_indices)
else: 
    train_len = int(0.8 * len(ds))
    valid_len = len(ds) - train_len

    # Randomly split the dataset into train and validation sets
    train_ds, valid_ds = random_split(ds, [train_len, valid_len])
    DS_Tools.save_indices(os.path.join(model_save_dir, "valid_ds_{}.pkl".format(ts)), valid_ds.indices)

train_loader = DataLoader(train_ds, batch_size=BATCH_SIZE, shuffle=True, num_workers=LOADER_WORKER, collate_fn=SeqDataset.collate_fn)
train_num = len(train_loader.dataset)

valid_loader = DataLoader(valid_ds, batch_size=BATCH_SIZE, shuffle=False, num_workers=LOADER_WORKER, collate_fn=SeqDataset.collate_fn)
valid_num = len(valid_loader.dataset)

# %%
len(train_loader)
# Out:
# 1776

# %%
# Load sample data from train_loader
sample_data = next(iter(valid_loader))
xx_pad, seg = sample_data
print(xx_pad.shape)
# Out:
# torch.Size([128, 68, 64])

# %%
# Set the random seed for reproducibility
# random.seed(101)
# Generate six random indices
# random_indices = random.sample(range(len(xx_pad)), 6)
random_indices = list(range(6, 12))

# Plot the spectrograms and mark the corresponding seg
fig, axes = plt.subplots(2, 3, figsize=(12, 8))
axes = axes.flatten()

for i, idx in enumerate(random_indices):
    spectrogram = xx_pad[idx]
    
    ax = axes[i]
    img = ax.imshow(spectrogram.T, aspect='auto', origin="lower")
    # ax.axvline(x=segment, color='red', linestyle='--')
    # ax.axvline(x=segment[1], color='red', linestyle='--')
    ax.set_title(f'Spectrogram')
    ax.set_xlabel('Time')
    ax.set_ylabel('Frequency')
plt.tight_layout()
plt.colorbar(img,ax=axes)
plt.show()

# %%
ts
# Out:
# '0122222146'

# %%
EPOCHS = 50
BASE = 0

# %%
def train(): 
    for epoch in range(BASE, BASE + EPOCHS):
        text_hist.print("Epoch {}".format(epoch))

        model.train()
        train_loss = 0.
        train_num = len(train_loader)    # train_loader
        for idx, (x, x_lens) in enumerate(train_loader):
            optimizer.zero_grad()
            y = x 
            
            x_mask = generate_mask_from_lengths_mat(x_lens, device=device)
            
            x = x.to(device)
            y = y.to(device)

            recon_x, attn_weight = model(x, x_lens, x_mask)

            loss = model_loss.get_loss(recon_x, y, x_mask)

            train_loss += loss.item()

            loss.backward()
            
            # torch.nn.utils.clip_grad_norm_(model.parameters(), clip_value)
            # 这个函数计算的是全局梯度范数
            # torch.nn.utils.clip_grad_norm(parameters=model.parameters(), max_norm=5, norm_type=2)
            torch.nn.utils.clip_grad_norm_(parameters=model.parameters(), max_norm=5, norm_type=2)
            # parameters: an iterable of Variables that will have gradients normalized
            # max_norm: max norm of the gradients(阈值设定)
            # norm_type: type of the used p-norm. Can be'inf'for infinity norm(定义范数类型)

            optimizer.step()

            if idx % 100 == 0:
                text_hist.print(f"Training loss {loss: .3f} in Step {idx}")

        train_losses.append(train_loss / train_num)
        text_hist.print(f"※※※Training loss {train_loss / train_num: .3f}※※※")

        last_model_name = "PT_{}_{}_full.pt".format(ts, epoch)
        torch.save(model.state_dict(), os.path.join(model_save_dir, last_model_name))
        text_hist.print("Training timepoint saved")

        model.eval()
        valid_loss = 0.
        valid_num = len(valid_loader)
        for idx, (x, x_lens) in enumerate(valid_loader):
            y = x    # extract MFCC-only data
            x_mask = generate_mask_from_lengths_mat(x_lens, device=device)
            
            x = x.to(device)
            y = y.to(device)

            recon_x, attn_weight = model(x, x_lens, x_mask)

            loss = model_loss.get_loss(recon_x, y, x_mask)

            valid_loss += loss.item()

            if idx % 50 == 0:
                text_hist.print(f"Valid loss {loss: .3f} in Step {idx}")

        valid_losses.append(valid_loss / valid_num)

        text_hist.print(f"※※※Valid loss {valid_loss / valid_num: .3f}※※※")

# %%
if __name__ == "__main__": 
    train()
# Out:
# Epoch 0
# Training loss  1.026 in Step 0
# Training loss  0.859 in Step 100
# Training loss  0.866 in Step 200
# Training loss  0.842 in Step 300
# Training loss  0.843 in Step 400
# Training loss  0.846 in Step 500
# Training loss  0.818 in Step 600
# Training loss  0.841 in Step 700
# Training loss  0.835 in Step 800
# Training loss  0.827 in Step 900
# Training loss  0.821 in Step 1000
# Training loss  0.841 in Step 1100
# Training loss  0.823 in Step 1200
# Training loss  0.815 in Step 1300
# Training loss  0.810 in Step 1400
# Training loss  0.793 in Step 1500
# Training loss  0.782 in Step 1600
# Training loss  0.797 in Step 1700
# ※※※Training loss  0.829※※※
# Training timepoint saved
# Valid loss  0.768 in Step 0
# Valid loss  0.812 in Step 50
# Valid loss  0.791 in Step 100
# Valid loss  0.778 in Step 150
# Valid loss  0.777 in Step 200
# Valid loss  0.812 in Step 250
# Valid loss  0.794 in Step 300
# Valid loss  0.780 in Step 350
# Valid loss  0.764 in Step 400
# ※※※Valid loss  0.784※※※
# Epoch 1
# Training loss  0.790 in Step 0
# Training loss  0.793 in Step 100
# Training loss  0.766 in Step 200
# Training loss  0.771 in Step 300
# Training loss  0.763 in Step 400
# Training loss  0.778 in Step 500
# Training loss  0.760 in Step 600
# Training loss  0.797 in Step 700
# Training loss  0.770 in Step 800
# Training loss  0.783 in Step 900
# Training loss  0.763 in Step 1000
# Training loss  0.763 in Step 1100
# Training loss  0.768 in Step 1200
# Training loss  0.752 in Step 1300
# Training loss  0.762 in Step 1400
# Training loss  0.784 in Step 1500
# Training loss  0.771 in Step 1600
# Training loss  0.782 in Step 1700
# ※※※Training loss  0.776※※※
# Training timepoint saved
# Valid loss  0.767 in Step 0
# Valid loss  0.813 in Step 50
# Valid loss  0.798 in Step 100
# Valid loss  0.782 in Step 150
# Valid loss  0.772 in Step 200
# Valid loss  0.819 in Step 250
# Valid loss  0.800 in Step 300
# Valid loss  0.785 in Step 350
# Valid loss  0.758 in Step 400
# ※※※Valid loss  0.788※※※
# Epoch 2
# Training loss  0.776 in Step 0
# Training loss  0.774 in Step 100
# Training loss  0.758 in Step 200
# Training loss  0.751 in Step 300
# Training loss  0.760 in Step 400
# Training loss  0.729 in Step 500
# Training loss  0.779 in Step 600
# Training loss  0.788 in Step 700
# Training loss  0.780 in Step 800
# Training loss  0.747 in Step 900
# Training loss  0.785 in Step 1000
# Training loss  0.750 in Step 1100
# Training loss  0.732 in Step 1200
# Training loss  0.810 in Step 1300
# Training loss  0.785 in Step 1400
# Training loss  0.776 in Step 1500
# Training loss  0.739 in Step 1600
# Training loss  0.763 in Step 1700
# ※※※Training loss  0.768※※※
# Training timepoint saved
# Valid loss  0.754 in Step 0
# Valid loss  0.794 in Step 50
# Valid loss  0.786 in Step 100
# Valid loss  0.771 in Step 150
# Valid loss  0.766 in Step 200
# Valid loss  0.799 in Step 250
# Valid loss  0.786 in Step 300
# Valid loss  0.777 in Step 350
# Valid loss  0.747 in Step 400
# ※※※Valid loss  0.774※※※
# Epoch 3
# Training loss  0.778 in Step 0
# Training loss  0.781 in Step 100
# Training loss  0.767 in Step 200
# Training loss  0.752 in Step 300
# Training loss  0.778 in Step 400
# Training loss  0.763 in Step 500
# Training loss  0.748 in Step 600
# Training loss  0.752 in Step 700
# Training loss  0.769 in Step 800
# Training loss  0.744 in Step 900
# Training loss  0.780 in Step 1000
# Training loss  0.734 in Step 1100
# Training loss  0.757 in Step 1200
# Training loss  0.758 in Step 1300
# Training loss  0.764 in Step 1400
# Training loss  0.740 in Step 1500
# Training loss  0.776 in Step 1600
# Training loss  0.746 in Step 1700
# ※※※Training loss  0.761※※※
# Training timepoint saved
# Valid loss  0.734 in Step 0
# Valid loss  0.784 in Step 50
# Valid loss  0.770 in Step 100
# Valid loss  0.760 in Step 150
# Valid loss  0.745 in Step 200
# Valid loss  0.789 in Step 250
# Valid loss  0.768 in Step 300
# Valid loss  0.762 in Step 350
# Valid loss  0.736 in Step 400
# ※※※Valid loss  0.760※※※
# Epoch 4
# Training loss  0.760 in Step 0
# Training loss  0.734 in Step 100
# Training loss  0.746 in Step 200
# Training loss  0.791 in Step 300
# Training loss  0.762 in Step 400
# Training loss  0.742 in Step 500
# Training loss  0.776 in Step 600
# Training loss  0.743 in Step 700
# Training loss  0.748 in Step 800
# Training loss  0.737 in Step 900
# Training loss  0.744 in Step 1000
# Training loss  0.765 in Step 1100
# Training loss  0.752 in Step 1200
# Training loss  0.762 in Step 1300
# Training loss  0.778 in Step 1400
# Training loss  0.735 in Step 1500
# Training loss  0.751 in Step 1600
# Training loss  0.782 in Step 1700
# ※※※Training loss  0.756※※※
# Training timepoint saved
# Valid loss  0.737 in Step 0
# Valid loss  0.778 in Step 50
# Valid loss  0.768 in Step 100
# Valid loss  0.761 in Step 150
# Valid loss  0.749 in Step 200
# Valid loss  0.785 in Step 250
# Valid loss  0.763 in Step 300
# Valid loss  0.757 in Step 350
# Valid loss  0.732 in Step 400
# ※※※Valid loss  0.758※※※
# Epoch 5
# Training loss  0.726 in Step 0
# Training loss  0.745 in Step 100
# Training loss  0.722 in Step 200
# Training loss  0.757 in Step 300
# Training loss  0.754 in Step 400
# Training loss  0.764 in Step 500
# Training loss  0.749 in Step 600
# Training loss  0.733 in Step 700
# Training loss  0.746 in Step 800
# Training loss  0.748 in Step 900
# Training loss  0.766 in Step 1000
# Training loss  0.725 in Step 1100
# Training loss  0.723 in Step 1200
# Training loss  0.750 in Step 1300
# Training loss  0.761 in Step 1400
# Training loss  0.734 in Step 1500
# Training loss  0.726 in Step 1600
# Training loss  0.751 in Step 1700
# ※※※Training loss  0.751※※※
# Training timepoint saved
# Valid loss  0.731 in Step 0
# Valid loss  0.773 in Step 50
# Valid loss  0.762 in Step 100
# Valid loss  0.757 in Step 150
# Valid loss  0.747 in Step 200
# Valid loss  0.783 in Step 250
# Valid loss  0.761 in Step 300
# Valid loss  0.754 in Step 350
# Valid loss  0.728 in Step 400
# ※※※Valid loss  0.755※※※
# Epoch 6
# Training loss  0.757 in Step 0
# Training loss  0.751 in Step 100
# Training loss  0.751 in Step 200
# Training loss  0.748 in Step 300
# Training loss  0.724 in Step 400
# Training loss  0.764 in Step 500
# Training loss  0.758 in Step 600
# Training loss  0.737 in Step 700
# Training loss  0.737 in Step 800
# Training loss  0.757 in Step 900
# Training loss  0.753 in Step 1000
# Training loss  0.770 in Step 1100
# Training loss  0.720 in Step 1200
# Training loss  0.737 in Step 1300
# Training loss  0.724 in Step 1400
# Training loss  0.779 in Step 1500
# Training loss  0.751 in Step 1600
# Training loss  0.729 in Step 1700
# ※※※Training loss  0.747※※※
# Training timepoint saved
# Valid loss  0.730 in Step 0
# Valid loss  0.764 in Step 50
# Valid loss  0.757 in Step 100
# Valid loss  0.756 in Step 150
# Valid loss  0.741 in Step 200
# Valid loss  0.785 in Step 250
# Valid loss  0.762 in Step 300
# Valid loss  0.757 in Step 350
# Valid loss  0.725 in Step 400
# ※※※Valid loss  0.753※※※
# Epoch 7
# Training loss  0.724 in Step 0
# Training loss  0.736 in Step 100
# Training loss  0.746 in Step 200
# Training loss  0.743 in Step 300
# Training loss  0.742 in Step 400
# Training loss  0.728 in Step 500
# Training loss  0.735 in Step 600
# Training loss  0.732 in Step 700
# Training loss  0.759 in Step 800
# Training loss  0.738 in Step 900
# Training loss  0.769 in Step 1000
# Training loss  0.724 in Step 1100
# Training loss  0.755 in Step 1200
# Training loss  0.739 in Step 1300
# Training loss  0.735 in Step 1400
# Training loss  0.754 in Step 1500
# Training loss  0.758 in Step 1600
# Training loss  0.711 in Step 1700
# ※※※Training loss  0.746※※※
# Training timepoint saved
# Valid loss  0.738 in Step 0
# Valid loss  0.772 in Step 50
# Valid loss  0.764 in Step 100
# Valid loss  0.757 in Step 150
# Valid loss  0.744 in Step 200
# Valid loss  0.780 in Step 250
# Valid loss  0.763 in Step 300
# Valid loss  0.756 in Step 350
# Valid loss  0.728 in Step 400
# ※※※Valid loss  0.755※※※
# Epoch 8
# Training loss  0.737 in Step 0
# Training loss  0.757 in Step 100
# Training loss  0.765 in Step 200
# Training loss  0.760 in Step 300
# Training loss  0.763 in Step 400
# Training loss  0.755 in Step 500
# Training loss  0.749 in Step 600
# Training loss  0.738 in Step 700
# Training loss  0.748 in Step 800
# Training loss  0.757 in Step 900
# Training loss  0.747 in Step 1000
# Training loss  0.777 in Step 1100
# Training loss  0.734 in Step 1200
# Training loss  0.753 in Step 1300
# Training loss  0.752 in Step 1400
# Training loss  0.734 in Step 1500
# Training loss  0.755 in Step 1600
# Training loss  0.729 in Step 1700
# ※※※Training loss  0.743※※※
# Training timepoint saved
# Valid loss  0.729 in Step 0
# Valid loss  0.768 in Step 50
# Valid loss  0.755 in Step 100
# Valid loss  0.748 in Step 150
# Valid loss  0.736 in Step 200
# Valid loss  0.781 in Step 250
# Valid loss  0.754 in Step 300
# Valid loss  0.751 in Step 350
# Valid loss  0.729 in Step 400
# ※※※Valid loss  0.749※※※
# Epoch 9
# Training loss  0.747 in Step 0
# Training loss  0.697 in Step 100
# Training loss  0.731 in Step 200
# Training loss  0.736 in Step 300
# Training loss  0.761 in Step 400
# Training loss  0.748 in Step 500
# Training loss  0.737 in Step 600
# Training loss  0.739 in Step 700
# Training loss  0.768 in Step 800
# Training loss  0.733 in Step 900
# Training loss  0.722 in Step 1000
# Training loss  0.733 in Step 1100
# Training loss  0.756 in Step 1200
# Training loss  0.775 in Step 1300
# Training loss  0.727 in Step 1400
# Training loss  0.720 in Step 1500
# Training loss  0.733 in Step 1600
# Training loss  0.748 in Step 1700
# ※※※Training loss  0.741※※※
# Training timepoint saved
# Valid loss  0.736 in Step 0
# Valid loss  0.765 in Step 50
# Valid loss  0.753 in Step 100
# Valid loss  0.752 in Step 150
# Valid loss  0.744 in Step 200
# Valid loss  0.782 in Step 250
# Valid loss  0.758 in Step 300
# Valid loss  0.759 in Step 350
# Valid loss  0.728 in Step 400
# ※※※Valid loss  0.753※※※
# Epoch 10
# Training loss  0.740 in Step 0
# Training loss  0.760 in Step 100
# Training loss  0.735 in Step 200
# Training loss  0.724 in Step 300
# Training loss  0.735 in Step 400
# Training loss  0.722 in Step 500
# Training loss  0.753 in Step 600
# Training loss  0.753 in Step 700
# Training loss  0.725 in Step 800
# Training loss  0.737 in Step 900
# Training loss  0.720 in Step 1000
# Training loss  0.754 in Step 1100
# Training loss  0.736 in Step 1200
# Training loss  0.742 in Step 1300
# Training loss  0.707 in Step 1400
# Training loss  0.731 in Step 1500
# Training loss  0.761 in Step 1600
# Training loss  0.717 in Step 1700
# ※※※Training loss  0.737※※※
# Training timepoint saved
# Valid loss  0.725 in Step 0
# Valid loss  0.767 in Step 50
# Valid loss  0.752 in Step 100
# Valid loss  0.750 in Step 150
# Valid loss  0.744 in Step 200
# Valid loss  0.791 in Step 250
# Valid loss  0.770 in Step 300
# Valid loss  0.747 in Step 350
# Valid loss  0.729 in Step 400
# ※※※Valid loss  0.751※※※
# Epoch 11
# Training loss  0.740 in Step 0
# Training loss  0.750 in Step 100
# Training loss  0.748 in Step 200
# Training loss  0.740 in Step 300
# Training loss  0.741 in Step 400
# Training loss  0.731 in Step 500
# Training loss  0.735 in Step 600
# Training loss  0.713 in Step 700
# Training loss  0.729 in Step 800
# Training loss  0.744 in Step 900
# Training loss  0.754 in Step 1000
# Training loss  0.729 in Step 1100
# Training loss  0.730 in Step 1200
# Training loss  0.718 in Step 1300
# Training loss  0.749 in Step 1400
# Training loss  0.764 in Step 1500
# Training loss  0.710 in Step 1600
# Training loss  0.711 in Step 1700
# ※※※Training loss  0.734※※※
# Training timepoint saved
# Valid loss  0.718 in Step 0
# Valid loss  0.748 in Step 50
# Valid loss  0.746 in Step 100
# Valid loss  0.735 in Step 150
# Valid loss  0.728 in Step 200
# Valid loss  0.772 in Step 250
# Valid loss  0.750 in Step 300
# Valid loss  0.740 in Step 350
# Valid loss  0.718 in Step 400
# ※※※Valid loss  0.740※※※
# Epoch 12
# Training loss  0.725 in Step 0
# Training loss  0.734 in Step 100
# Training loss  0.720 in Step 200
# Training loss  0.750 in Step 300
# Training loss  0.760 in Step 400
# Training loss  0.734 in Step 500
# Training loss  0.716 in Step 600
# Training loss  0.732 in Step 700
# Training loss  0.750 in Step 800
# Training loss  0.720 in Step 900
# Training loss  0.722 in Step 1000
# Training loss  0.728 in Step 1100
# Training loss  0.709 in Step 1200
# Training loss  0.699 in Step 1300
# Training loss  0.743 in Step 1400
# Training loss  0.709 in Step 1500
# Training loss  0.722 in Step 1600
# Training loss  0.748 in Step 1700
# ※※※Training loss  0.730※※※
# Training timepoint saved
# Valid loss  0.731 in Step 0
# Valid loss  0.755 in Step 50
# Valid loss  0.741 in Step 100
# Valid loss  0.744 in Step 150
# Valid loss  0.735 in Step 200
# Valid loss  0.778 in Step 250
# Valid loss  0.756 in Step 300
# Valid loss  0.746 in Step 350
# Valid loss  0.733 in Step 400
# ※※※Valid loss  0.744※※※
# Epoch 13
# Training loss  0.708 in Step 0
# Training loss  0.718 in Step 100
# Training loss  0.728 in Step 200
# Training loss  0.729 in Step 300
# Training loss  0.721 in Step 400
# Training loss  0.753 in Step 500
# Training loss  0.714 in Step 600
# Training loss  0.742 in Step 700
# Training loss  0.733 in Step 800
# Training loss  0.716 in Step 900
# Training loss  0.739 in Step 1000
# Training loss  0.737 in Step 1100
# Training loss  0.731 in Step 1200
# Training loss  0.715 in Step 1300
# Training loss  0.735 in Step 1400
# Training loss  0.721 in Step 1500
# Training loss  0.720 in Step 1600
# Training loss  0.727 in Step 1700
# ※※※Training loss  0.725※※※
# Training timepoint saved
# Valid loss  0.724 in Step 0
# Valid loss  0.750 in Step 50
# Valid loss  0.740 in Step 100
# Valid loss  0.745 in Step 150
# Valid loss  0.732 in Step 200
# Valid loss  0.780 in Step 250
# Valid loss  0.750 in Step 300
# Valid loss  0.743 in Step 350
# Valid loss  0.732 in Step 400
# ※※※Valid loss  0.742※※※
# Epoch 14
# Training loss  0.692 in Step 0
# Training loss  0.721 in Step 100
# Training loss  0.709 in Step 200
# Training loss  0.711 in Step 300
# Training loss  0.714 in Step 400
# Training loss  0.702 in Step 500
# Training loss  0.720 in Step 600
# Training loss  0.739 in Step 700
# Training loss  0.762 in Step 800
# Training loss  0.733 in Step 900
# Training loss  0.724 in Step 1000
# Training loss  0.732 in Step 1100
# Training loss  0.745 in Step 1200
# Training loss  0.704 in Step 1300
# Training loss  0.714 in Step 1400
# Training loss  0.735 in Step 1500
# Training loss  0.717 in Step 1600
# Training loss  0.684 in Step 1700
# ※※※Training loss  0.724※※※
# Training timepoint saved
# Valid loss  0.700 in Step 0
# Valid loss  0.745 in Step 50
# Valid loss  0.735 in Step 100
# Valid loss  0.733 in Step 150
# Valid loss  0.709 in Step 200
# Valid loss  0.776 in Step 250
# Valid loss  0.733 in Step 300
# Valid loss  0.726 in Step 350
# Valid loss  0.714 in Step 400
# ※※※Valid loss  0.729※※※
# Epoch 15
# Training loss  0.698 in Step 0
# Training loss  0.744 in Step 100
# Training loss  0.667 in Step 200
# Training loss  0.703 in Step 300
# Training loss  0.728 in Step 400
# Training loss  0.737 in Step 500
# Training loss  0.722 in Step 600
# Training loss  0.690 in Step 700
# Training loss  0.710 in Step 800
# Training loss  0.697 in Step 900
# Training loss  0.709 in Step 1000
# Training loss  0.720 in Step 1100
# Training loss  0.689 in Step 1200
# Training loss  0.721 in Step 1300
# Training loss  0.737 in Step 1400
# Training loss  0.728 in Step 1500
# Training loss  0.705 in Step 1600
# Training loss  0.699 in Step 1700
# ※※※Training loss  0.714※※※
# Training timepoint saved
# Valid loss  0.676 in Step 0
# Valid loss  0.726 in Step 50
# Valid loss  0.716 in Step 100
# Valid loss  0.698 in Step 150
# Valid loss  0.677 in Step 200
# Valid loss  0.746 in Step 250
# Valid loss  0.715 in Step 300
# Valid loss  0.707 in Step 350
# Valid loss  0.684 in Step 400
# ※※※Valid loss  0.704※※※
# Epoch 16
# Training loss  0.779 in Step 0
# Training loss  0.713 in Step 100
# Training loss  0.731 in Step 200
# Training loss  0.706 in Step 300
# Training loss  0.673 in Step 400
# Training loss  0.722 in Step 500
# Training loss  0.686 in Step 600
# Training loss  0.700 in Step 700
# Training loss  0.706 in Step 800
# Training loss  0.711 in Step 900
# Training loss  0.676 in Step 1000
# Training loss  0.692 in Step 1100
# Training loss  0.681 in Step 1200
# Training loss  0.706 in Step 1300
# Training loss  0.691 in Step 1400
# Training loss  0.699 in Step 1500
# Training loss  0.706 in Step 1600
# Training loss  0.726 in Step 1700
# ※※※Training loss  0.707※※※
# Training timepoint saved
# Valid loss  0.688 in Step 0
# Valid loss  0.735 in Step 50
# Valid loss  0.740 in Step 100
# Valid loss  0.719 in Step 150
# Valid loss  0.697 in Step 200
# Valid loss  0.771 in Step 250
# Valid loss  0.727 in Step 300
# Valid loss  0.732 in Step 350
# Valid loss  0.703 in Step 400
# ※※※Valid loss  0.720※※※
# Epoch 17
# Training loss  0.675 in Step 0
# Training loss  0.696 in Step 100
# Training loss  0.696 in Step 200
# Training loss  0.738 in Step 300
# Training loss  0.708 in Step 400
# Training loss  0.722 in Step 500
# Training loss  0.695 in Step 600
# Training loss  0.714 in Step 700
# Training loss  0.685 in Step 800
# Training loss  0.694 in Step 900
# Training loss  0.690 in Step 1000
# Training loss  0.703 in Step 1100
# Training loss  0.680 in Step 1200
# Training loss  0.713 in Step 1300
# Training loss  0.666 in Step 1400
# Training loss  0.677 in Step 1500
# Training loss  0.708 in Step 1600
# Training loss  0.705 in Step 1700
# ※※※Training loss  0.699※※※
# Training timepoint saved
# Valid loss  0.690 in Step 0
# Valid loss  0.725 in Step 50
# Valid loss  0.728 in Step 100
# Valid loss  0.714 in Step 150
# Valid loss  0.698 in Step 200
# Valid loss  0.762 in Step 250
# Valid loss  0.723 in Step 300
# Valid loss  0.726 in Step 350
# Valid loss  0.696 in Step 400
# ※※※Valid loss  0.715※※※
# Epoch 18
# Training loss  0.707 in Step 0
# Training loss  0.697 in Step 100
# Training loss  0.717 in Step 200
# Training loss  0.685 in Step 300
# Training loss  0.703 in Step 400
# Training loss  0.712 in Step 500
# Training loss  0.687 in Step 600
# Training loss  0.700 in Step 700
# Training loss  0.700 in Step 800
# Training loss  0.702 in Step 900
# Training loss  0.692 in Step 1000
# Training loss  0.695 in Step 1100
# Training loss  0.716 in Step 1200
# Training loss  0.716 in Step 1300
# Training loss  0.716 in Step 1400
# Training loss  0.700 in Step 1500
# Training loss  0.651 in Step 1600
# Training loss  0.675 in Step 1700
# ※※※Training loss  0.696※※※
# Training timepoint saved
# Valid loss  0.686 in Step 0
# Valid loss  0.734 in Step 50
# Valid loss  0.730 in Step 100
# Valid loss  0.728 in Step 150
# Valid loss  0.694 in Step 200
# Valid loss  0.760 in Step 250
# Valid loss  0.720 in Step 300
# Valid loss  0.728 in Step 350
# Valid loss  0.692 in Step 400
# ※※※Valid loss  0.717※※※
# Epoch 19
# Training loss  0.698 in Step 0
# Training loss  0.688 in Step 100
# Training loss  0.715 in Step 200
# Training loss  0.697 in Step 300
# Training loss  0.669 in Step 400
# Training loss  0.692 in Step 500
# Training loss  0.699 in Step 600
# Training loss  0.739 in Step 700
# Training loss  0.684 in Step 800
# Training loss  0.715 in Step 900
# Training loss  0.694 in Step 1000
# Training loss  0.690 in Step 1100
# Training loss  0.700 in Step 1200
# Training loss  0.701 in Step 1300
# Training loss  0.687 in Step 1400
# Training loss  0.695 in Step 1500
# Training loss  0.702 in Step 1600
# Training loss  0.690 in Step 1700
# ※※※Training loss  0.694※※※
# Training timepoint saved
# Valid loss  0.690 in Step 0
# Valid loss  0.728 in Step 50
# Valid loss  0.736 in Step 100
# Valid loss  0.721 in Step 150
# Valid loss  0.697 in Step 200
# Valid loss  0.763 in Step 250
# Valid loss  0.727 in Step 300
# Valid loss  0.729 in Step 350
# Valid loss  0.690 in Step 400
# ※※※Valid loss  0.717※※※
# Epoch 20
# Training loss  0.685 in Step 0
# Training loss  0.718 in Step 100
# Training loss  0.678 in Step 200
# Training loss  0.696 in Step 300
# Training loss  0.694 in Step 400
# Training loss  0.688 in Step 500
# Training loss  0.704 in Step 600
# Training loss  0.687 in Step 700
# Training loss  0.681 in Step 800
# Training loss  0.686 in Step 900
# Training loss  0.706 in Step 1000
# Training loss  0.683 in Step 1100
# Training loss  0.684 in Step 1200
# Training loss  0.676 in Step 1300
# Training loss  0.694 in Step 1400
# Training loss  0.678 in Step 1500
# Training loss  0.701 in Step 1600
# Training loss  0.687 in Step 1700
# ※※※Training loss  0.690※※※
# Training timepoint saved
# Valid loss  0.689 in Step 0
# Valid loss  0.729 in Step 50
# Valid loss  0.734 in Step 100
# Valid loss  0.717 in Step 150
# Valid loss  0.697 in Step 200
# Valid loss  0.769 in Step 250
# Valid loss  0.718 in Step 300
# Valid loss  0.728 in Step 350
# Valid loss  0.683 in Step 400
# ※※※Valid loss  0.715※※※
# Epoch 21
# Training loss  0.691 in Step 0
# Training loss  0.681 in Step 100
# Training loss  0.699 in Step 200
# Training loss  0.654 in Step 300
# Training loss  0.697 in Step 400
# Training loss  0.682 in Step 500
# Training loss  0.707 in Step 600
# Training loss  0.660 in Step 700
# Training loss  0.712 in Step 800
# Training loss  0.696 in Step 900
# Training loss  0.672 in Step 1000
# Training loss  0.731 in Step 1100
# Training loss  0.699 in Step 1200
# Training loss  0.692 in Step 1300
# Training loss  0.688 in Step 1400
# Training loss  0.691 in Step 1500
# Training loss  0.680 in Step 1600
# Training loss  0.685 in Step 1700
# ※※※Training loss  0.689※※※
# Training timepoint saved
# Valid loss  0.717 in Step 0
# Valid loss  0.748 in Step 50
# Valid loss  0.749 in Step 100
# Valid loss  0.739 in Step 150
# Valid loss  0.720 in Step 200
# Valid loss  0.786 in Step 250
# Valid loss  0.744 in Step 300
# Valid loss  0.749 in Step 350
# Valid loss  0.719 in Step 400
# ※※※Valid loss  0.736※※※
# Epoch 22
# Training loss  0.681 in Step 0
# Training loss  0.686 in Step 100
# Training loss  0.689 in Step 200
# Training loss  0.696 in Step 300
# Training loss  0.676 in Step 400
# Training loss  0.676 in Step 500
# Training loss  0.705 in Step 600
# Training loss  0.699 in Step 700
# Training loss  0.732 in Step 800
# Training loss  0.698 in Step 900
# Training loss  0.680 in Step 1000
# Training loss  0.709 in Step 1100
# Training loss  0.694 in Step 1200
# Training loss  0.679 in Step 1300
# Training loss  0.714 in Step 1400
# Training loss  0.681 in Step 1500
# Training loss  0.677 in Step 1600
# Training loss  0.676 in Step 1700
# ※※※Training loss  0.688※※※
# Training timepoint saved
# Valid loss  0.712 in Step 0
# Valid loss  0.745 in Step 50
# Valid loss  0.740 in Step 100
# Valid loss  0.724 in Step 150
# Valid loss  0.712 in Step 200
# Valid loss  0.767 in Step 250
# Valid loss  0.727 in Step 300
# Valid loss  0.739 in Step 350
# Valid loss  0.708 in Step 400
# ※※※Valid loss  0.725※※※
# Epoch 23
# Training loss  0.695 in Step 0
# Training loss  0.675 in Step 100
# Training loss  0.662 in Step 200
# Training loss  0.681 in Step 300
# Training loss  0.685 in Step 400
# Training loss  0.671 in Step 500
# Training loss  0.709 in Step 600
# Training loss  0.718 in Step 700
# Training loss  0.706 in Step 800
# Training loss  0.685 in Step 900
# Training loss  0.678 in Step 1000
# Training loss  0.669 in Step 1100
# Training loss  0.681 in Step 1200
# Training loss  0.692 in Step 1300
# Training loss  0.698 in Step 1400
# Training loss  0.654 in Step 1500
# Training loss  0.663 in Step 1600
# Training loss  0.666 in Step 1700
# ※※※Training loss  0.688※※※
# Training timepoint saved
# Valid loss  0.686 in Step 0
# Valid loss  0.717 in Step 50
# Valid loss  0.730 in Step 100
# Valid loss  0.717 in Step 150
# Valid loss  0.692 in Step 200
# Valid loss  0.754 in Step 250
# Valid loss  0.719 in Step 300
# Valid loss  0.725 in Step 350
# Valid loss  0.687 in Step 400
# ※※※Valid loss  0.710※※※
# Epoch 24
# Training loss  0.714 in Step 0
# Training loss  0.679 in Step 100
# Training loss  0.685 in Step 200
# Training loss  0.672 in Step 300
# Training loss  0.658 in Step 400
# Training loss  0.686 in Step 500
# Training loss  0.672 in Step 600
# Training loss  0.686 in Step 700
# Training loss  0.669 in Step 800
# Training loss  0.667 in Step 900
# Training loss  0.721 in Step 1000
# Training loss  0.651 in Step 1100
# Training loss  0.682 in Step 1200
# Training loss  0.690 in Step 1300
# Training loss  0.710 in Step 1400
# Training loss  0.696 in Step 1500
# Training loss  0.682 in Step 1600
# Training loss  0.693 in Step 1700
# ※※※Training loss  0.684※※※
# Training timepoint saved
# Valid loss  0.731 in Step 0
# Valid loss  0.755 in Step 50
# Valid loss  0.756 in Step 100
# Valid loss  0.745 in Step 150
# Valid loss  0.727 in Step 200
# Valid loss  0.797 in Step 250
# Valid loss  0.741 in Step 300
# Valid loss  0.757 in Step 350
# Valid loss  0.724 in Step 400
# ※※※Valid loss  0.743※※※
# Epoch 25
# Training loss  0.682 in Step 0
# Training loss  0.689 in Step 100
# Training loss  0.709 in Step 200
# Training loss  0.684 in Step 300
# Training loss  0.678 in Step 400
# Training loss  0.668 in Step 500
# Training loss  0.671 in Step 600
# Training loss  0.692 in Step 700
# Training loss  0.713 in Step 800
# Training loss  0.654 in Step 900
# Training loss  0.696 in Step 1000
# Training loss  0.686 in Step 1100
# Training loss  0.683 in Step 1200
# Training loss  0.669 in Step 1300
# Training loss  0.695 in Step 1400
# Training loss  0.701 in Step 1500
# Training loss  0.676 in Step 1600
# Training loss  0.688 in Step 1700
# ※※※Training loss  0.685※※※
# Training timepoint saved
# Valid loss  0.712 in Step 0
# Valid loss  0.744 in Step 50
# Valid loss  0.749 in Step 100
# Valid loss  0.730 in Step 150
# Valid loss  0.716 in Step 200
# Valid loss  0.774 in Step 250
# Valid loss  0.736 in Step 300
# Valid loss  0.749 in Step 350
# Valid loss  0.707 in Step 400
# ※※※Valid loss  0.730※※※
# Epoch 26
# Training loss  0.717 in Step 0
# Training loss  0.690 in Step 100
# Training loss  0.656 in Step 200
# Training loss  0.685 in Step 300
# Training loss  0.684 in Step 400
# Training loss  0.713 in Step 500
# Training loss  0.683 in Step 600
# Training loss  0.675 in Step 700
# Training loss  0.681 in Step 800
# Training loss  0.680 in Step 900
# Training loss  0.680 in Step 1000
# Training loss  0.660 in Step 1100
# Training loss  0.693 in Step 1200
# Training loss  0.682 in Step 1300
# Training loss  0.675 in Step 1400
# Training loss  0.692 in Step 1500
# Training loss  0.677 in Step 1600
# Training loss  0.695 in Step 1700
# ※※※Training loss  0.685※※※
# Training timepoint saved
# Valid loss  0.710 in Step 0
# Valid loss  0.742 in Step 50
# Valid loss  0.750 in Step 100
# Valid loss  0.734 in Step 150
# Valid loss  0.714 in Step 200
# Valid loss  0.776 in Step 250
# Valid loss  0.738 in Step 300
# Valid loss  0.742 in Step 350
# Valid loss  0.713 in Step 400
# ※※※Valid loss  0.730※※※
# Epoch 27
# Training loss  0.659 in Step 0
# Training loss  0.680 in Step 100
# Training loss  0.701 in Step 200
# Training loss  0.698 in Step 300
# Training loss  0.648 in Step 400
# Training loss  0.672 in Step 500
# Training loss  0.703 in Step 600
# Training loss  0.667 in Step 700
# Training loss  0.682 in Step 800
# Training loss  0.671 in Step 900
# Training loss  0.672 in Step 1000
# Training loss  0.684 in Step 1100
# Training loss  0.690 in Step 1200
# Training loss  0.680 in Step 1300
# Training loss  0.667 in Step 1400
# Training loss  0.696 in Step 1500
# Training loss  0.666 in Step 1600
# Training loss  0.706 in Step 1700
# ※※※Training loss  0.682※※※
# Training timepoint saved
# Valid loss  0.714 in Step 0
# Valid loss  0.744 in Step 50
# Valid loss  0.746 in Step 100
# Valid loss  0.742 in Step 150
# Valid loss  0.714 in Step 200
# Valid loss  0.780 in Step 250
# Valid loss  0.736 in Step 300
# Valid loss  0.743 in Step 350
# Valid loss  0.716 in Step 400
# ※※※Valid loss  0.732※※※
# Epoch 28
# Training loss  0.657 in Step 0
# Training loss  0.657 in Step 100
# Training loss  0.653 in Step 200
# Training loss  0.653 in Step 300
# Training loss  0.680 in Step 400
# Training loss  0.710 in Step 500
# Training loss  0.670 in Step 600
# Training loss  0.716 in Step 700
# Training loss  0.672 in Step 800
# Training loss  0.679 in Step 900
# Training loss  0.717 in Step 1000
# Training loss  0.704 in Step 1100
# Training loss  0.684 in Step 1200
# Training loss  0.690 in Step 1300
# Training loss  0.664 in Step 1400
# Training loss  0.699 in Step 1500
# Training loss  0.689 in Step 1600
# Training loss  0.683 in Step 1700
# ※※※Training loss  0.680※※※
# Training timepoint saved
# Valid loss  0.704 in Step 0
# Valid loss  0.732 in Step 50
# Valid loss  0.741 in Step 100
# Valid loss  0.725 in Step 150
# Valid loss  0.710 in Step 200
# Valid loss  0.770 in Step 250
# Valid loss  0.732 in Step 300
# Valid loss  0.736 in Step 350
# Valid loss  0.701 in Step 400
# ※※※Valid loss  0.723※※※
# Epoch 29
# Training loss  0.693 in Step 0
# Training loss  0.680 in Step 100
# Training loss  0.688 in Step 200
# Training loss  0.675 in Step 300
# Training loss  0.714 in Step 400
# Training loss  0.690 in Step 500
# Training loss  0.651 in Step 600
# Training loss  0.686 in Step 700
# Training loss  0.687 in Step 800
# Training loss  0.672 in Step 900
# Training loss  0.694 in Step 1000
# Training loss  0.688 in Step 1100
# Training loss  0.678 in Step 1200
# Training loss  0.682 in Step 1300
# Training loss  0.664 in Step 1400
# Training loss  0.677 in Step 1500
# Training loss  0.662 in Step 1600
# Training loss  0.694 in Step 1700
# ※※※Training loss  0.683※※※
# Training timepoint saved
# Valid loss  0.708 in Step 0
# Valid loss  0.741 in Step 50
# Valid loss  0.747 in Step 100
# Valid loss  0.729 in Step 150
# Valid loss  0.716 in Step 200
# Valid loss  0.781 in Step 250
# Valid loss  0.748 in Step 300
# Valid loss  0.742 in Step 350
# Valid loss  0.708 in Step 400
# ※※※Valid loss  0.731※※※
# Epoch 30
# Training loss  0.688 in Step 0
# Training loss  0.673 in Step 100
# Training loss  0.694 in Step 200
# Training loss  0.701 in Step 300
# Training loss  0.686 in Step 400
# Training loss  0.707 in Step 500
# Training loss  0.677 in Step 600
# Training loss  0.680 in Step 700
# Training loss  0.663 in Step 800
# Training loss  0.677 in Step 900
# Training loss  0.653 in Step 1000
# Training loss  0.693 in Step 1100
# Training loss  0.677 in Step 1200
# Training loss  0.632 in Step 1300
# Training loss  0.664 in Step 1400
# Training loss  0.682 in Step 1500
# Training loss  0.692 in Step 1600
# Training loss  0.702 in Step 1700
# ※※※Training loss  0.679※※※
# Training timepoint saved
# Valid loss  0.723 in Step 0
# Valid loss  0.743 in Step 50
# Valid loss  0.750 in Step 100
# Valid loss  0.733 in Step 150
# Valid loss  0.711 in Step 200
# Valid loss  0.783 in Step 250
# Valid loss  0.735 in Step 300
# Valid loss  0.745 in Step 350
# Valid loss  0.713 in Step 400
# ※※※Valid loss  0.732※※※
# Epoch 31
# Training loss  0.691 in Step 0
# Training loss  0.691 in Step 100
# Training loss  0.683 in Step 200
# Training loss  0.709 in Step 300
# Training loss  0.674 in Step 400
# Training loss  0.711 in Step 500
# Training loss  0.678 in Step 600
# Training loss  0.699 in Step 700
# Training loss  0.699 in Step 800
# Training loss  0.677 in Step 900
# Training loss  0.679 in Step 1000
# Training loss  0.683 in Step 1100
# Training loss  0.677 in Step 1200
# Training loss  0.683 in Step 1300
# Training loss  0.694 in Step 1400
# Training loss  0.679 in Step 1500
# Training loss  0.697 in Step 1600
# Training loss  0.709 in Step 1700
# ※※※Training loss  0.683※※※
# Training timepoint saved
# Valid loss  0.716 in Step 0
# Valid loss  0.743 in Step 50
# Valid loss  0.743 in Step 100
# Valid loss  0.727 in Step 150
# Valid loss  0.710 in Step 200
# Valid loss  0.773 in Step 250
# Valid loss  0.732 in Step 300
# Valid loss  0.737 in Step 350
# Valid loss  0.706 in Step 400
# ※※※Valid loss  0.727※※※
# Epoch 32
# Training loss  0.661 in Step 0
# Training loss  0.679 in Step 100
# Training loss  0.692 in Step 200
# Training loss  0.675 in Step 300
# Training loss  0.695 in Step 400
# Training loss  0.673 in Step 500
# Training loss  0.684 in Step 600
# Training loss  0.663 in Step 700
# Training loss  0.682 in Step 800
# Training loss  0.676 in Step 900
# Training loss  0.679 in Step 1000
# Training loss  0.700 in Step 1100
# Training loss  0.714 in Step 1200
# Training loss  0.683 in Step 1300
# Training loss  0.681 in Step 1400
# Training loss  0.671 in Step 1500
# Training loss  0.685 in Step 1600
# Training loss  0.659 in Step 1700
# ※※※Training loss  0.677※※※
# Training timepoint saved
# Valid loss  0.720 in Step 0
# Valid loss  0.735 in Step 50
# Valid loss  0.748 in Step 100
# Valid loss  0.736 in Step 150
# Valid loss  0.716 in Step 200
# Valid loss  0.786 in Step 250
# Valid loss  0.746 in Step 300
# Valid loss  0.743 in Step 350
# Valid loss  0.714 in Step 400
# ※※※Valid loss  0.733※※※
# Epoch 33
# Training loss  0.663 in Step 0
# Training loss  0.677 in Step 100
# Training loss  0.696 in Step 200
# Training loss  0.677 in Step 300
# Training loss  0.708 in Step 400
# Training loss  0.695 in Step 500
# Training loss  0.693 in Step 600
# Training loss  0.699 in Step 700
# Training loss  0.671 in Step 800
# Training loss  0.678 in Step 900
# Training loss  0.689 in Step 1000
# Training loss  0.649 in Step 1100
# Training loss  0.687 in Step 1200
# Training loss  0.686 in Step 1300
# Training loss  0.665 in Step 1400
# Training loss  0.668 in Step 1500
# Training loss  0.732 in Step 1600
# Training loss  0.681 in Step 1700
# ※※※Training loss  0.676※※※
# Training timepoint saved
# Valid loss  0.719 in Step 0
# Valid loss  0.735 in Step 50
# Valid loss  0.748 in Step 100
# Valid loss  0.740 in Step 150
# Valid loss  0.715 in Step 200
# Valid loss  0.786 in Step 250
# Valid loss  0.737 in Step 300
# Valid loss  0.742 in Step 350
# Valid loss  0.712 in Step 400
# ※※※Valid loss  0.733※※※
# Epoch 34
# Training loss  0.661 in Step 0
# Training loss  0.692 in Step 100
# Training loss  0.683 in Step 200
# Training loss  0.678 in Step 300
# Training loss  0.700 in Step 400
# Training loss  0.697 in Step 500
# Training loss  0.666 in Step 600
# Training loss  0.699 in Step 700
# Training loss  0.699 in Step 800
# Training loss  0.690 in Step 900
# Training loss  0.644 in Step 1000
# Training loss  0.685 in Step 1100
# Training loss  0.698 in Step 1200
# Training loss  0.652 in Step 1300
# Training loss  0.694 in Step 1400
# Training loss  0.655 in Step 1500
# Training loss  0.655 in Step 1600
# Training loss  0.680 in Step 1700
# ※※※Training loss  0.676※※※
# Training timepoint saved
# Valid loss  0.712 in Step 0
# Valid loss  0.728 in Step 50
# Valid loss  0.743 in Step 100
# Valid loss  0.732 in Step 150
# Valid loss  0.706 in Step 200
# Valid loss  0.774 in Step 250
# Valid loss  0.737 in Step 300
# Valid loss  0.736 in Step 350
# Valid loss  0.701 in Step 400
# ※※※Valid loss  0.726※※※
# Epoch 35
# Training loss  0.678 in Step 0
# Training loss  0.654 in Step 100
# Training loss  0.674 in Step 200
# Training loss  0.667 in Step 300
# Training loss  0.677 in Step 400
# Training loss  0.684 in Step 500
# Training loss  0.701 in Step 600
# Training loss  0.686 in Step 700
# Training loss  0.697 in Step 800
# Training loss  0.690 in Step 900
# Training loss  0.685 in Step 1000
# Training loss  0.691 in Step 1100
# Training loss  0.685 in Step 1200
# Training loss  0.731 in Step 1300
# Training loss  0.675 in Step 1400
# Training loss  0.663 in Step 1500
# Training loss  0.666 in Step 1600
# Training loss  0.684 in Step 1700
# ※※※Training loss  0.679※※※
# Training timepoint saved
# Valid loss  0.719 in Step 0
# Valid loss  0.738 in Step 50
# Valid loss  0.750 in Step 100
# Valid loss  0.731 in Step 150
# Valid loss  0.703 in Step 200
# Valid loss  0.770 in Step 250
# Valid loss  0.724 in Step 300
# Valid loss  0.736 in Step 350
# Valid loss  0.707 in Step 400
# ※※※Valid loss  0.726※※※
# Epoch 36
# Training loss  0.699 in Step 0
# Training loss  0.681 in Step 100
# Training loss  0.674 in Step 200
# Training loss  0.659 in Step 300
# Training loss  0.660 in Step 400
# Training loss  0.681 in Step 500
# Training loss  0.701 in Step 600
# Training loss  0.674 in Step 700
# Training loss  0.649 in Step 800
# Training loss  0.660 in Step 900
# Training loss  0.696 in Step 1000
# Training loss  0.664 in Step 1100
# Training loss  0.666 in Step 1200
# Training loss  0.666 in Step 1300
# Training loss  0.666 in Step 1400
# Training loss  0.684 in Step 1500
# Training loss  0.695 in Step 1600
# Training loss  0.673 in Step 1700
# ※※※Training loss  0.676※※※
# Training timepoint saved
# Valid loss  0.713 in Step 0
# Valid loss  0.739 in Step 50
# Valid loss  0.741 in Step 100
# Valid loss  0.733 in Step 150
# Valid loss  0.706 in Step 200
# Valid loss  0.765 in Step 250
# Valid loss  0.721 in Step 300
# Valid loss  0.736 in Step 350
# Valid loss  0.704 in Step 400
# ※※※Valid loss  0.726※※※
# Epoch 37
# Training loss  0.665 in Step 0
# Training loss  0.710 in Step 100
# Training loss  0.696 in Step 200
# Training loss  0.688 in Step 300
# Training loss  0.702 in Step 400
# Training loss  0.694 in Step 500
# Training loss  0.673 in Step 600
# Training loss  0.662 in Step 700
# Training loss  0.691 in Step 800
# Training loss  0.685 in Step 900
# Training loss  0.686 in Step 1000
# Training loss  0.675 in Step 1100
# Training loss  0.691 in Step 1200
# Training loss  0.685 in Step 1300
# Training loss  0.683 in Step 1400
# Training loss  0.673 in Step 1500
# Training loss  0.656 in Step 1600
# Training loss  0.695 in Step 1700
# ※※※Training loss  0.678※※※
# Training timepoint saved
# Valid loss  0.706 in Step 0
# Valid loss  0.731 in Step 50
# Valid loss  0.743 in Step 100
# Valid loss  0.738 in Step 150
# Valid loss  0.712 in Step 200
# Valid loss  0.778 in Step 250
# Valid loss  0.733 in Step 300
# Valid loss  0.739 in Step 350
# Valid loss  0.703 in Step 400
# ※※※Valid loss  0.727※※※
# Epoch 38
# Training loss  0.670 in Step 0
# Training loss  0.649 in Step 100
# Training loss  0.698 in Step 200
# Training loss  0.692 in Step 300
# Training loss  0.657 in Step 400
# Training loss  0.662 in Step 500
# Training loss  0.662 in Step 600
# Training loss  0.667 in Step 700
# Training loss  0.712 in Step 800
# Training loss  0.690 in Step 900
# Training loss  0.657 in Step 1000
# Training loss  0.681 in Step 1100
# Training loss  0.670 in Step 1200
# Training loss  0.685 in Step 1300
# Training loss  0.672 in Step 1400
# Training loss  0.675 in Step 1500
# Training loss  0.658 in Step 1600
# Training loss  0.712 in Step 1700
# ※※※Training loss  0.673※※※
# Training timepoint saved
# Valid loss  0.727 in Step 0
# Valid loss  0.740 in Step 50
# Valid loss  0.761 in Step 100
# Valid loss  0.749 in Step 150
# Valid loss  0.722 in Step 200
# Valid loss  0.794 in Step 250
# Valid loss  0.742 in Step 300
# Valid loss  0.752 in Step 350
# Valid loss  0.725 in Step 400
# ※※※Valid loss  0.739※※※
# Epoch 39
# Training loss  0.640 in Step 0
# Training loss  0.677 in Step 100
# Training loss  0.690 in Step 200
# Training loss  0.707 in Step 300
# Training loss  0.668 in Step 400
# Training loss  0.649 in Step 500
# Training loss  0.669 in Step 600
# Training loss  0.662 in Step 700
# Training loss  0.685 in Step 800
# Training loss  0.657 in Step 900
# Training loss  0.677 in Step 1000
# Training loss  0.657 in Step 1100
# Training loss  0.679 in Step 1200
# Training loss  0.685 in Step 1300
# Training loss  0.711 in Step 1400
# Training loss  0.670 in Step 1500
# Training loss  0.692 in Step 1600
# Training loss  0.682 in Step 1700
# ※※※Training loss  0.675※※※
# Training timepoint saved
# Valid loss  0.725 in Step 0
# Valid loss  0.732 in Step 50
# Valid loss  0.756 in Step 100
# Valid loss  0.744 in Step 150
# Valid loss  0.714 in Step 200
# Valid loss  0.782 in Step 250
# Valid loss  0.734 in Step 300
# Valid loss  0.748 in Step 350
# Valid loss  0.720 in Step 400
# ※※※Valid loss  0.734※※※
# Epoch 40
# Training loss  0.659 in Step 0
# Training loss  0.691 in Step 100
# Training loss  0.679 in Step 200
# Training loss  0.691 in Step 300
# Training loss  0.667 in Step 400
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /home/ldlmdl/Documents/wavln/scripts/A_11.ipynb Cell 26 line 2
#       <a href='vscode-notebook-cell:/home/ldlmdl/Documents/wavln/scripts/A_11.ipynb#X33sZmlsZQ%3D%3D?line=0'>1</a> if __name__ == "__main__":
# ----> <a href='vscode-notebook-cell:/home/ldlmdl/Documents/wavln/scripts/A_11.ipynb#X33sZmlsZQ%3D%3D?line=1'>2</a>     train()
#
# /home/ldlmdl/Documents/wavln/scripts/A_11.ipynb Cell 26 line 2
#      <a href='vscode-notebook-cell:/home/ldlmdl/Documents/wavln/scripts/A_11.ipynb#X33sZmlsZQ%3D%3D?line=18'>19</a> loss = model_loss.get_loss(recon_x, y, x_mask)
#      <a href='vscode-notebook-cell:/home/ldlmdl/Documents/wavln/scripts/A_11.ipynb#X33sZmlsZQ%3D%3D?line=20'>21</a> train_loss += loss.item()
# ---> <a href='vscode-notebook-cell:/home/ldlmdl/Documents/wavln/scripts/A_11.ipynb#X33sZmlsZQ%3D%3D?line=22'>23</a> loss.backward()
#      <a href='vscode-notebook-cell:/home/ldlmdl/Documents/wavln/scripts/A_11.ipynb#X33sZmlsZQ%3D%3D?line=24'>25</a> # torch.nn.utils.clip_grad_norm_(model.parameters(), clip_value)
#      <a href='vscode-notebook-cell:/home/ldlmdl/Documents/wavln/scripts/A_11.ipynb#X33sZmlsZQ%3D%3D?line=25'>26</a> # 这个函数计算的是全局梯度范数
#      <a href='vscode-notebook-cell:/home/ldlmdl/Documents/wavln/scripts/A_11.ipynb#X33sZmlsZQ%3D%3D?line=26'>27</a> # torch.nn.utils.clip_grad_norm(parameters=model.parameters(), max_norm=5, norm_type=2)
#      <a href='vscode-notebook-cell:/home/ldlmdl/Documents/wavln/scripts/A_11.ipynb#X33sZmlsZQ%3D%3D?line=27'>28</a> torch.nn.utils.clip_grad_norm_(parameters=model.parameters(), max_norm=5, norm_type=2)
#
# File ~/anaconda3/envs/wavln/lib/python3.11/site-packages/torch/_tensor.py:487, in Tensor.backward(self, gradient, retain_graph, create_graph, inputs)
#     477 if has_torch_function_unary(self):
#     478     return handle_torch_function(
#     479         Tensor.backward,
#     480         (self,),
#    (...)
#     485         inputs=inputs,
#     486     )
# --> 487 torch.autograd.backward(
#     488     self, gradient, retain_graph, create_graph, inputs=inputs
#     489 )
#
# File ~/anaconda3/envs/wavln/lib/python3.11/site-packages/torch/autograd/__init__.py:200, in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables, inputs)
#     195     retain_graph = create_graph
#     197 # The reason we repeat same the comment below is that
#     198 # some Python versions print out the first line of a multi-line function
#     199 # calls in the traceback and some print out the last line
# --> 200 Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
#     201     tensors, grad_tensors_, retain_graph, create_graph, inputs,
#     202     allow_unreachable=True, accumulate_grad=True)
#
# KeyboardInterrupt:

# %%
### Save
train_losses.save()

valid_losses.save()

text_hist.save()

# %%
plt.plot(train_losses.get(), label='Train')
plt.plot(valid_losses.get(), label='Valid')
plt.title("Learning Curve Loss")
plt.legend()

# %% [markdown]
# ## Conclusion
# This model should converge to loss around 0.49x.
