# %% [markdown]
# # AI Lab Run
# V1: New dataset, old model.

# %%
import torch
from torch import nn
import torch.nn.functional as F
from torch.nn.utils.rnn import pad_sequence, pack_sequence
from torch import optim
from torch.utils.data import Dataset, DataLoader, random_split
import matplotlib.pyplot as plt
import numpy as np

# %%
from model_model import SimplerPhxLearnerInit as TheLearner
from model_dataset import DS_Tools
from model_dataset import WordDataset as ThisDataset
from model_dataset import Normalizer, DeNormalizer
from model_dataset import MelSpecTransformNoDB as TheTransform
from paths import *
from misc_my_utils import *
from misc_recorder import *
from model_loss import *
from model_padding import generate_mask_from_lengths_mat

# %% [markdown]
# ### Dirs

# %%
rec_dir = train_cut_word_
train_guide_path = os.path.join(src_, "guide_train.csv")
valid_guide_path = os.path.join(src_, "guide_validation.csv")
test_guide_path = os.path.join(src_, "guide_test.csv")

# %% [markdown]
# ### Constants

# %%
BATCH_SIZE = 128

INPUT_DIM = 64
OUTPUT_DIM = 64 

INTER_DIM_0 = 32
INTER_DIM_1 = 16
INTER_DIM_2 = 8

ENC_SIZE_LIST = [INPUT_DIM, INTER_DIM_0, INTER_DIM_1, INTER_DIM_2]
DEC_SIZE_LIST = [OUTPUT_DIM, INTER_DIM_0, INTER_DIM_1, INTER_DIM_2]

DROPOUT = 0.5

REC_SAMPLE_RATE = 16000
N_FFT = 400
N_MELS = 64

LOADER_WORKER = 16
# LOADER_WORKER = 0

# %% [markdown]
# ## Prepare for this time of training

# %%
# ts = "0918192113"
stop_epoch = "149"
ts = str(get_timestamp())
train_name = "A_01"
model_save_dir = os.path.join(model_save_, f"{train_name}-{ts}")
mk(model_save_dir)
print(f"{train_name}-{ts}")

train_losses = ListRecorder(os.path.join(model_save_dir, "train.loss"))
valid_losses = ListRecorder(os.path.join(model_save_dir, "valid.loss"))
text_hist = HistRecorder(os.path.join(model_save_dir, "trainhist.txt"))
# Out:
# A_01-0128212552

# %%
READ = False
# READ = True

# %%
DATAREAD = False

# %%
mytrans = TheTransform(sample_rate=REC_SAMPLE_RATE, 
                       n_fft=N_FFT, n_mels=N_MELS, 
                       normalizer=Normalizer.norm_mvn, 
                       denormalizer=DeNormalizer.norm_mvn)

train_ds = ThisDataset(rec_dir, 
                       train_guide_path, 
                       transform=mytrans)
valid_ds = ThisDataset(rec_dir, 
                       valid_guide_path, 
                       transform=mytrans)

use_proportion = 0.005

if READ or DATAREAD: 
    train_ds_indices = DS_Tools.read_indices(os.path.join(model_save_dir, "train.use"))
    valid_ds_indices = DS_Tools.read_indices(os.path.join(model_save_dir, "valid.use"))

    use_train_ds = torch.utils.data.Subset(train_ds, train_ds_indices)
    use_valid_ds = torch.utils.data.Subset(valid_ds, valid_ds_indices)
else: 
    # train data
    use_len = int(use_proportion * len(train_ds))
    remain_len = len(train_ds) - use_len
    use_train_ds, remain_ds = random_split(train_ds, [use_len, remain_len])

    # valid data
    use_len = int(use_proportion * len(valid_ds))
    remain_len = len(valid_ds) - use_len
    use_valid_ds, remain_ds = random_split(valid_ds, [use_len, remain_len])

    # NOTE: we don't need to save the cut-small subset, because after cutting-small, 
    # the saved train and valid separations will reflect this
    DS_Tools.save_indices(os.path.join(model_save_dir, "train.use"), use_train_ds.indices)
    DS_Tools.save_indices(os.path.join(model_save_dir, "valid.use"), use_valid_ds.indices)

train_loader = DataLoader(train_ds, batch_size=BATCH_SIZE, shuffle=True, num_workers=LOADER_WORKER, collate_fn=ThisDataset.collate_fn)
train_num = len(train_loader.dataset)

valid_loader = DataLoader(valid_ds, batch_size=BATCH_SIZE, shuffle=False, num_workers=LOADER_WORKER, collate_fn=ThisDataset.collate_fn)
valid_num = len(valid_loader.dataset)

# %%
len(train_loader), len(valid_loader)
# Out:
# (6056, 813)

# %%
# Load sample data from train_loader
sample_data = next(iter(valid_loader))
xx_pad, seg = sample_data
print(xx_pad.shape)
# Out:
# torch.Size([128, 53, 64])

# %%
# Set the random seed for reproducibility
# random.seed(101)
# Generate six random indices
# random_indices = random.sample(range(len(xx_pad)), 6)
random_indices = list(range(6, 12))

# Plot the spectrograms and mark the corresponding seg
fig, axes = plt.subplots(2, 3, figsize=(12, 8))
axes = axes.flatten()

for i, idx in enumerate(random_indices):
    spectrogram = xx_pad[idx]
    
    ax = axes[i]
    img = ax.imshow(spectrogram.T, aspect='auto', origin="lower")
    # ax.axvline(x=segment, color='red', linestyle='--')
    # ax.axvline(x=segment[1], color='red', linestyle='--')
    ax.set_title(f'Spectrogram')
    ax.set_xlabel('Time')
    ax.set_ylabel('Frequency')
plt.tight_layout()
plt.colorbar(img,ax=axes)
plt.show()

# %% [markdown]
# ## Prepare model

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
recon_loss = nn.MSELoss(reduction='none')
masked_recon_loss = MaskedLoss(recon_loss)
model_loss = masked_recon_loss

model = TheLearner(enc_size_list=ENC_SIZE_LIST, dec_size_list=DEC_SIZE_LIST, num_layers=2)
# model = TheLearner(enc_size_list=ENC_SIZE_LIST, dec_size_list=DEC_SIZE_LIST, num_layers=1)
model.to(device)
optimizer = optim.Adam(model.parameters(), lr=1e-3)

model_str = str(model)
model_txt_path = os.path.join(model_save_dir, "model.txt")

with open(model_txt_path, "w") as f:
    f.write(model_str)

# %%
# # initialize model weights
# def init_weights(m):
#     if isinstance(m, nn.Linear):
#         torch.nn.init.orthogonal_(m.weight)
#         m.bias.data.fill_(0.01)
#     if isinstance(m, nn.LSTM): 
#         for name, p in m.named_parameters():
#             if "weight" in name: 
#                 nn.init.orthogonal_(p)
#             elif "bias" in name: 
#                 nn.init.constant_(p, 0)

# model.apply(init_weights)

# %%
model_parameters = filter(lambda p: p.requires_grad, model.parameters())
params = sum([np.prod(p.size()) for p in model_parameters])

# %%
params
# Out:
# 11440

# %% [markdown]
# ### Load model if READ

# %%
if READ: 
    valid_losses.read()
    train_losses.read()

    model_name = "{}.pt".format(stop_epoch)
    model_path = os.path.join(model_save_dir, model_name)
    state = torch.load(model_path)

    model.load_state_dict(state)
    model.to(device)

# %%
EPOCHS = 30
BASE = 0

# %%
def train(): 
    for epoch in range(BASE, BASE + EPOCHS):
        text_hist.print("Epoch {}".format(epoch))

        model.train()
        train_loss = 0.
        train_num = len(train_loader)    # train_loader
        for idx, (x, x_lens) in enumerate(train_loader):
            optimizer.zero_grad()
            y = x 
            
            x_mask = generate_mask_from_lengths_mat(x_lens, device=device)
            
            x = x.to(device)
            y = y.to(device)

            recon_x, attn_weight = model(x, x_lens, x_mask)

            loss = model_loss.get_loss(recon_x, y, x_mask)

            train_loss += loss.item()

            loss.backward()
            
            # torch.nn.utils.clip_grad_norm_(model.parameters(), clip_value)
            # 这个函数计算的是全局梯度范数
            # torch.nn.utils.clip_grad_norm(parameters=model.parameters(), max_norm=5, norm_type=2)
            torch.nn.utils.clip_grad_norm_(parameters=model.parameters(), max_norm=5, norm_type=2)
            # parameters: an iterable of Variables that will have gradients normalized
            # max_norm: max norm of the gradients(阈值设定)
            # norm_type: type of the used p-norm. Can be'inf'for infinity norm(定义范数类型)

            optimizer.step()

            if idx % 100 == 0:
                text_hist.print(f"Training loss {loss: .3f} in Step {idx}")

        train_losses.append(train_loss / train_num)
        text_hist.print(f"※※※Training loss {train_loss / train_num: .3f}※※※")

        last_model_name = "{}.pt".format(epoch)
        torch.save(model.state_dict(), os.path.join(model_save_dir, last_model_name))
        text_hist.print("Training timepoint saved")

        model.eval()
        valid_loss = 0.
        valid_num = len(valid_loader)
        for idx, (x, x_lens) in enumerate(valid_loader):
            y = x    # extract MFCC-only data
            x_mask = generate_mask_from_lengths_mat(x_lens, device=device)
            
            x = x.to(device)
            y = y.to(device)

            recon_x, attn_weight = model(x, x_lens, x_mask)

            loss = model_loss.get_loss(recon_x, y, x_mask)

            valid_loss += loss.item()

            if idx % 50 == 0:
                text_hist.print(f"Valid loss {loss: .3f} in Step {idx}")

        valid_losses.append(valid_loss / valid_num)

        text_hist.print(f"※※※Valid loss {valid_loss / valid_num: .3f}※※※")

# %%
if __name__ == "__main__": 
    train()
# Out:
# Epoch 0
# Training loss  1.466 in Step 0
# Training loss  0.976 in Step 100
# Training loss  0.915 in Step 200
# Training loss  0.905 in Step 300
# Training loss  0.868 in Step 400
# Training loss  0.838 in Step 500
# Training loss  0.794 in Step 600
# Training loss  0.769 in Step 700
# Training loss  0.762 in Step 800
# Training loss  0.710 in Step 900
# Training loss  0.724 in Step 1000
# Training loss  0.739 in Step 1100
# Training loss  0.692 in Step 1200
# Training loss  0.680 in Step 1300
# Training loss  0.657 in Step 1400
# Training loss  0.679 in Step 1500
# Training loss  0.687 in Step 1600
# Training loss  0.637 in Step 1700
# Training loss  0.606 in Step 1800
# Training loss  0.580 in Step 1900
# Training loss  0.608 in Step 2000
# Training loss  0.588 in Step 2100
# Training loss  0.632 in Step 2200
# Training loss  0.564 in Step 2300
# Training loss  0.596 in Step 2400
# Training loss  0.587 in Step 2500
# Training loss  0.593 in Step 2600
# Training loss  0.585 in Step 2700
# Training loss  0.582 in Step 2800
# Training loss  0.558 in Step 2900
# Training loss  0.541 in Step 3000
# Training loss  0.578 in Step 3100
# Training loss  0.565 in Step 3200
# Training loss  0.576 in Step 3300
# Training loss  0.585 in Step 3400
# Training loss  0.569 in Step 3500
# Training loss  0.535 in Step 3600
# Training loss  0.517 in Step 3700
# Training loss  0.519 in Step 3800
# Training loss  0.578 in Step 3900
# Training loss  0.515 in Step 4000
# Training loss  0.548 in Step 4100
# Training loss  0.525 in Step 4200
# Training loss  0.524 in Step 4300
# Training loss  0.551 in Step 4400
# Training loss  0.493 in Step 4500
# Training loss  0.525 in Step 4600
# Training loss  0.507 in Step 4700
# Training loss  0.556 in Step 4800
# Training loss  0.482 in Step 4900
# Training loss  0.520 in Step 5000
# Training loss  0.504 in Step 5100
# Training loss  0.499 in Step 5200
# Training loss  0.481 in Step 5300
# Training loss  0.503 in Step 5400
# Training loss  0.475 in Step 5500
# Training loss  0.488 in Step 5600
# Training loss  0.477 in Step 5700
# Training loss  0.476 in Step 5800
# Training loss  0.519 in Step 5900
# Training loss  0.522 in Step 6000
# ※※※Training loss  0.610※※※
# Training timepoint saved
# Valid loss  0.552 in Step 0
# Valid loss  0.803 in Step 50
# Valid loss  0.664 in Step 100
# Valid loss  0.540 in Step 150
# Valid loss  0.449 in Step 200
# Valid loss  0.449 in Step 250
# Valid loss  0.437 in Step 300
# Valid loss  0.346 in Step 350
# Valid loss  0.692 in Step 400
# Valid loss  0.446 in Step 450
# Valid loss  0.586 in Step 500
# Valid loss  0.619 in Step 550
# Valid loss  0.413 in Step 600
# Valid loss  0.470 in Step 650
# Valid loss  0.975 in Step 700
# Valid loss  0.455 in Step 750
# Valid loss  0.473 in Step 800
# ※※※Valid loss  0.543※※※
# Epoch 1
# Training loss  0.497 in Step 0
# Training loss  0.437 in Step 100
# Training loss  0.508 in Step 200
# Training loss  0.500 in Step 300
# Training loss  0.486 in Step 400
# Training loss  0.461 in Step 500
# Training loss  0.524 in Step 600
# Training loss  0.478 in Step 700
# Training loss  0.473 in Step 800
# Training loss  0.473 in Step 900
# Training loss  0.460 in Step 1000
# Training loss  0.494 in Step 1100
# Training loss  0.502 in Step 1200
# Training loss  0.469 in Step 1300
# Training loss  0.500 in Step 1400
# Training loss  0.490 in Step 1500
# Training loss  0.457 in Step 1600
# Training loss  0.485 in Step 1700
# Training loss  0.466 in Step 1800
# Training loss  0.457 in Step 1900
# Training loss  0.497 in Step 2000
# Training loss  0.495 in Step 2100
# Training loss  0.458 in Step 2200
# Training loss  0.482 in Step 2300
# Training loss  0.492 in Step 2400
# Training loss  0.502 in Step 2500
# Training loss  0.454 in Step 2600
# Training loss  0.455 in Step 2700
# Training loss  0.455 in Step 2800
# Training loss  0.450 in Step 2900
# Training loss  0.486 in Step 3000
# Training loss  0.503 in Step 3100
# Training loss  0.423 in Step 3200
# Training loss  0.469 in Step 3300
# Training loss  0.496 in Step 3400
# Training loss  0.456 in Step 3500
# Training loss  0.460 in Step 3600
# Training loss  0.476 in Step 3700
# Training loss  0.453 in Step 3800
# Training loss  0.467 in Step 3900
# Training loss  0.471 in Step 4000
# Training loss  0.455 in Step 4100
# Training loss  0.425 in Step 4200
# Training loss  0.454 in Step 4300
# Training loss  0.474 in Step 4400
# Training loss  0.499 in Step 4500
# Training loss  0.483 in Step 4600
# Training loss  0.508 in Step 4700
# Training loss  0.463 in Step 4800
# Training loss  0.434 in Step 4900
# Training loss  0.460 in Step 5000
# Training loss  0.425 in Step 5100
# Training loss  0.443 in Step 5200
# Training loss  0.438 in Step 5300
# Training loss  0.479 in Step 5400
# Training loss  0.436 in Step 5500
# Training loss  0.432 in Step 5600
# Training loss  0.448 in Step 5700
# Training loss  0.455 in Step 5800
# Training loss  0.439 in Step 5900
# Training loss  0.451 in Step 6000
# ※※※Training loss  0.468※※※
# Training timepoint saved
# Valid loss  0.487 in Step 0
# Valid loss  0.769 in Step 50
# Valid loss  0.621 in Step 100
# Valid loss  0.463 in Step 150
# Valid loss  0.385 in Step 200
# Valid loss  0.383 in Step 250
# Valid loss  0.377 in Step 300
# Valid loss  0.281 in Step 350
# Valid loss  0.637 in Step 400
# Valid loss  0.377 in Step 450
# Valid loss  0.546 in Step 500
# Valid loss  0.581 in Step 550
# Valid loss  0.383 in Step 600
# Valid loss  0.421 in Step 650
# Valid loss  0.968 in Step 700
# Valid loss  0.424 in Step 750
# Valid loss  0.418 in Step 800
# ※※※Valid loss  0.491※※※
# Epoch 2
# Training loss  0.458 in Step 0
# Training loss  0.464 in Step 100
# Training loss  0.449 in Step 200
# Training loss  0.399 in Step 300
# Training loss  0.454 in Step 400
# Training loss  0.459 in Step 500
# Training loss  0.472 in Step 600
# Training loss  0.467 in Step 700
# Training loss  0.464 in Step 800
# Training loss  0.472 in Step 900
# Training loss  0.444 in Step 1000
# Training loss  0.426 in Step 1100
# Training loss  0.437 in Step 1200
# Training loss  0.486 in Step 1300
# Training loss  0.397 in Step 1400
# Training loss  0.477 in Step 1500
# Training loss  0.414 in Step 1600
# Training loss  0.451 in Step 1700
# Training loss  0.435 in Step 1800
# Training loss  0.437 in Step 1900
# Training loss  0.436 in Step 2000
# Training loss  0.428 in Step 2100
# Training loss  0.391 in Step 2200
# Training loss  0.474 in Step 2300
# Training loss  0.423 in Step 2400
# Training loss  0.479 in Step 2500
# Training loss  0.418 in Step 2600
# Training loss  0.479 in Step 2700
# Training loss  0.444 in Step 2800
# Training loss  0.468 in Step 2900
# Training loss  0.458 in Step 3000
# Training loss  0.435 in Step 3100
# Training loss  0.366 in Step 3200
# Training loss  0.414 in Step 3300
# Training loss  0.441 in Step 3400
# Training loss  0.451 in Step 3500
# Training loss  0.443 in Step 3600
# Training loss  0.390 in Step 3700
# Training loss  0.454 in Step 3800
# Training loss  0.409 in Step 3900
# Training loss  0.427 in Step 4000
# Training loss  0.432 in Step 4100
# Training loss  0.403 in Step 4200
# Training loss  0.423 in Step 4300
# Training loss  0.435 in Step 4400
# Training loss  0.407 in Step 4500
# Training loss  0.388 in Step 4600
# Training loss  0.472 in Step 4700
# Training loss  0.423 in Step 4800
# Training loss  0.446 in Step 4900
# Training loss  0.396 in Step 5000
# Training loss  0.416 in Step 5100
# Training loss  0.393 in Step 5200
# Training loss  0.471 in Step 5300
# Training loss  0.435 in Step 5400
# Training loss  0.386 in Step 5500
# Training loss  0.455 in Step 5600
# Training loss  0.450 in Step 5700
# Training loss  0.392 in Step 5800
# Training loss  0.503 in Step 5900
# Training loss  0.390 in Step 6000
# ※※※Training loss  0.431※※※
# Training timepoint saved
# Valid loss  0.453 in Step 0
# Valid loss  0.753 in Step 50
# Valid loss  0.606 in Step 100
# Valid loss  0.444 in Step 150
# Valid loss  0.346 in Step 200
# Valid loss  0.342 in Step 250
# Valid loss  0.339 in Step 300
# Valid loss  0.226 in Step 350
# Valid loss  0.617 in Step 400
# Valid loss  0.344 in Step 450
# Valid loss  0.521 in Step 500
# Valid loss  0.556 in Step 550
# Valid loss  0.365 in Step 600
# Valid loss  0.388 in Step 650
# Valid loss  0.964 in Step 700
# Valid loss  0.401 in Step 750
# Valid loss  0.409 in Step 800
# ※※※Valid loss  0.465※※※
# Epoch 3
# Training loss  0.441 in Step 0
# Training loss  0.433 in Step 100
# Training loss  0.432 in Step 200
# Training loss  0.412 in Step 300
# Training loss  0.378 in Step 400
# Training loss  0.375 in Step 500
# Training loss  0.396 in Step 600
# Training loss  0.406 in Step 700
# Training loss  0.400 in Step 800
# Training loss  0.416 in Step 900
# Training loss  0.404 in Step 1000
# Training loss  0.445 in Step 1100
# Training loss  0.388 in Step 1200
# Training loss  0.401 in Step 1300
# Training loss  0.410 in Step 1400
# Training loss  0.340 in Step 1500
# Training loss  0.444 in Step 1600
# Training loss  0.423 in Step 1700
# Training loss  0.388 in Step 1800
# Training loss  0.386 in Step 1900
# Training loss  0.415 in Step 2000
# Training loss  0.404 in Step 2100
# Training loss  0.403 in Step 2200
# Training loss  0.392 in Step 2300
# Training loss  0.400 in Step 2400
# Training loss  0.408 in Step 2500
# Training loss  0.359 in Step 2600
# Training loss  0.385 in Step 2700
# Training loss  0.399 in Step 2800
# Training loss  0.409 in Step 2900
# Training loss  0.383 in Step 3000
# Training loss  0.383 in Step 3100
# Training loss  0.402 in Step 3200
# Training loss  0.417 in Step 3300
# Training loss  0.378 in Step 3400
# Training loss  0.390 in Step 3500
# Training loss  0.398 in Step 3600
# Training loss  0.358 in Step 3700
# Training loss  0.387 in Step 3800
# Training loss  0.371 in Step 3900
# Training loss  0.403 in Step 4000
# Training loss  0.380 in Step 4100
# Training loss  0.307 in Step 4200
# Training loss  0.373 in Step 4300
# Training loss  0.416 in Step 4400
# Training loss  0.352 in Step 4500
# Training loss  0.358 in Step 4600
# Training loss  0.335 in Step 4700
# Training loss  0.338 in Step 4800
# Training loss  0.347 in Step 4900
# Training loss  0.360 in Step 5000
# Training loss  0.340 in Step 5100
# Training loss  0.348 in Step 5200
# Training loss  0.372 in Step 5300
# Training loss  0.306 in Step 5400
# Training loss  0.377 in Step 5500
# Training loss  0.383 in Step 5600
# Training loss  0.373 in Step 5700
# Training loss  0.329 in Step 5800
# Training loss  0.385 in Step 5900
# Training loss  0.368 in Step 6000
# ※※※Training loss  0.385※※※
# Training timepoint saved
# Valid loss  0.364 in Step 0
# Valid loss  0.719 in Step 50
# Valid loss  0.524 in Step 100
# Valid loss  0.362 in Step 150
# Valid loss  0.258 in Step 200
# Valid loss  0.276 in Step 250
# Valid loss  0.263 in Step 300
# Valid loss  0.168 in Step 350
# Valid loss  0.564 in Step 400
# Valid loss  0.312 in Step 450
# Valid loss  0.494 in Step 500
# Valid loss  0.528 in Step 550
# Valid loss  0.321 in Step 600
# Valid loss  0.316 in Step 650
# Valid loss  0.961 in Step 700
# Valid loss  0.348 in Step 750
# Valid loss  0.330 in Step 800
# ※※※Valid loss  0.405※※※
# Epoch 4
# Training loss  0.399 in Step 0
# Training loss  0.381 in Step 100
# Training loss  0.354 in Step 200
# Training loss  0.332 in Step 300
# Training loss  0.323 in Step 400
# Training loss  0.377 in Step 500
# Training loss  0.338 in Step 600
# Training loss  0.368 in Step 700
# Training loss  0.377 in Step 800
# Training loss  0.375 in Step 900
# Training loss  0.364 in Step 1000
# Training loss  0.345 in Step 1100
# Training loss  0.349 in Step 1200
# Training loss  0.359 in Step 1300
# Training loss  0.301 in Step 1400
# Training loss  0.365 in Step 1500
# Training loss  0.324 in Step 1600
# Training loss  0.353 in Step 1700
# Training loss  0.360 in Step 1800
# Training loss  0.361 in Step 1900
# Training loss  0.336 in Step 2000
# Training loss  0.358 in Step 2100
# Training loss  0.375 in Step 2200
# Training loss  0.324 in Step 2300
# Training loss  0.359 in Step 2400
# Training loss  0.357 in Step 2500
# Training loss  0.373 in Step 2600
# Training loss  0.390 in Step 2700
# Training loss  0.383 in Step 2800
# Training loss  0.323 in Step 2900
# Training loss  0.340 in Step 3000
# Training loss  0.318 in Step 3100
# Training loss  0.435 in Step 3200
# Training loss  0.308 in Step 3300
# Training loss  0.323 in Step 3400
# Training loss  0.330 in Step 3500
# Training loss  0.336 in Step 3600
# Training loss  0.336 in Step 3700
# Training loss  0.333 in Step 3800
# Training loss  0.358 in Step 3900
# Training loss  0.289 in Step 4000
# Training loss  0.371 in Step 4100
# Training loss  0.318 in Step 4200
# Training loss  0.317 in Step 4300
# Training loss  0.333 in Step 4400
# Training loss  0.343 in Step 4500
# Training loss  0.378 in Step 4600
# Training loss  0.347 in Step 4700
# Training loss  0.341 in Step 4800
# Training loss  0.319 in Step 4900
# Training loss  0.334 in Step 5000
# Training loss  0.319 in Step 5100
# Training loss  0.323 in Step 5200
# Training loss  0.328 in Step 5300
# Training loss  0.345 in Step 5400
# Training loss  0.373 in Step 5500
# Training loss  0.284 in Step 5600
# Training loss  0.385 in Step 5700
# Training loss  0.335 in Step 5800
# Training loss  0.340 in Step 5900
# Training loss  0.345 in Step 6000
# ※※※Training loss  0.343※※※
# Training timepoint saved
# Valid loss  0.339 in Step 0
# Valid loss  0.710 in Step 50
# Valid loss  0.512 in Step 100
# Valid loss  0.345 in Step 150
# Valid loss  0.234 in Step 200
# Valid loss  0.260 in Step 250
# Valid loss  0.239 in Step 300
# Valid loss  0.143 in Step 350
# Valid loss  0.545 in Step 400
# Valid loss  0.283 in Step 450
# Valid loss  0.479 in Step 500
# Valid loss  0.489 in Step 550
# Valid loss  0.302 in Step 600
# Valid loss  0.307 in Step 650
# Valid loss  0.960 in Step 700
# Valid loss  0.315 in Step 750
# Valid loss  0.289 in Step 800
# ※※※Valid loss  0.384※※※
# Epoch 5
# Training loss  0.342 in Step 0
# Training loss  0.314 in Step 100
# Training loss  0.308 in Step 200
# Training loss  0.321 in Step 300
# Training loss  0.317 in Step 400
# Training loss  0.332 in Step 500
# Training loss  0.291 in Step 600
# Training loss  0.375 in Step 700
# Training loss  0.333 in Step 800
# Training loss  0.323 in Step 900
# Training loss  0.319 in Step 1000
# Training loss  0.346 in Step 1100
# Training loss  0.331 in Step 1200
# Training loss  0.348 in Step 1300
# Training loss  0.326 in Step 1400
# Training loss  0.311 in Step 1500
# Training loss  0.345 in Step 1600
# Training loss  0.325 in Step 1700
# Training loss  0.365 in Step 1800
# Training loss  0.319 in Step 1900
# Training loss  0.327 in Step 2000
# Training loss  0.305 in Step 2100
# Training loss  0.344 in Step 2200
# Training loss  0.356 in Step 2300
# Training loss  0.319 in Step 2400
# Training loss  0.316 in Step 2500
# Training loss  0.299 in Step 2600
# Training loss  0.302 in Step 2700
# Training loss  0.297 in Step 2800
# Training loss  0.348 in Step 2900
# Training loss  0.292 in Step 3000
# Training loss  0.270 in Step 3100
# Training loss  0.348 in Step 3200
# Training loss  0.307 in Step 3300
# Training loss  0.303 in Step 3400
# Training loss  0.322 in Step 3500
# Training loss  0.381 in Step 3600
# Training loss  0.292 in Step 3700
# Training loss  0.328 in Step 3800
# Training loss  0.300 in Step 3900
# Training loss  0.337 in Step 4000
# Training loss  0.338 in Step 4100
# Training loss  0.312 in Step 4200
# Training loss  0.333 in Step 4300
# Training loss  0.351 in Step 4400
# Training loss  0.292 in Step 4500
# Training loss  0.323 in Step 4600
# Training loss  0.242 in Step 4700
# Training loss  0.287 in Step 4800
# Training loss  0.347 in Step 4900
# Training loss  0.309 in Step 5000
# Training loss  0.325 in Step 5100
# Training loss  0.330 in Step 5200
# Training loss  0.357 in Step 5300
# Training loss  0.368 in Step 5400
# Training loss  0.323 in Step 5500
# Training loss  0.296 in Step 5600
# Training loss  0.287 in Step 5700
# Training loss  0.363 in Step 5800
# Training loss  0.314 in Step 5900
# Training loss  0.316 in Step 6000
# ※※※Training loss  0.323※※※
# Training timepoint saved
# Valid loss  0.330 in Step 0
# Valid loss  0.707 in Step 50
# Valid loss  0.508 in Step 100
# Valid loss  0.336 in Step 150
# Valid loss  0.210 in Step 200
# Valid loss  0.251 in Step 250
# Valid loss  0.224 in Step 300
# Valid loss  0.139 in Step 350
# Valid loss  0.537 in Step 400
# Valid loss  0.278 in Step 450
# Valid loss  0.474 in Step 500
# Valid loss  0.471 in Step 550
# Valid loss  0.286 in Step 600
# Valid loss  0.290 in Step 650
# Valid loss  0.963 in Step 700
# Valid loss  0.313 in Step 750
# Valid loss  0.281 in Step 800
# ※※※Valid loss  0.375※※※
# Epoch 6
# Training loss  0.302 in Step 0
# Training loss  0.321 in Step 100
# Training loss  0.307 in Step 200
# Training loss  0.303 in Step 300
# Training loss  0.329 in Step 400
# Training loss  0.294 in Step 500
# Training loss  0.290 in Step 600
# Training loss  0.323 in Step 700
# Training loss  0.304 in Step 800
# Training loss  0.287 in Step 900
# Training loss  0.340 in Step 1000
# Training loss  0.318 in Step 1100
# Training loss  0.312 in Step 1200
# Training loss  0.308 in Step 1300
# Training loss  0.268 in Step 1400
# Training loss  0.342 in Step 1500
# Training loss  0.303 in Step 1600
# Training loss  0.318 in Step 1700
# Training loss  0.320 in Step 1800
# Training loss  0.346 in Step 1900
# Training loss  0.303 in Step 2000
# Training loss  0.304 in Step 2100
# Training loss  0.290 in Step 2200
# Training loss  0.315 in Step 2300
# Training loss  0.318 in Step 2400
# Training loss  0.276 in Step 2500
# Training loss  0.328 in Step 2600
# Training loss  0.311 in Step 2700
# Training loss  0.321 in Step 2800
# Training loss  0.305 in Step 2900
# Training loss  0.294 in Step 3000
# Training loss  0.346 in Step 3100
# Training loss  0.334 in Step 3200
# Training loss  0.299 in Step 3300
# Training loss  0.327 in Step 3400
# Training loss  0.358 in Step 3500
# Training loss  0.366 in Step 3600
# Training loss  0.289 in Step 3700
# Training loss  0.303 in Step 3800
# Training loss  0.339 in Step 3900
# Training loss  0.316 in Step 4000
# Training loss  0.325 in Step 4100
# Training loss  0.297 in Step 4200
# Training loss  0.271 in Step 4300
# Training loss  0.333 in Step 4400
# Training loss  0.321 in Step 4500
# Training loss  0.275 in Step 4600
# Training loss  0.281 in Step 4700
# Training loss  0.312 in Step 4800
# Training loss  0.291 in Step 4900
# Training loss  0.283 in Step 5000
# Training loss  0.286 in Step 5100
# Training loss  0.328 in Step 5200
# Training loss  0.301 in Step 5300
# Training loss  0.278 in Step 5400
# Training loss  0.326 in Step 5500
# Training loss  0.378 in Step 5600
# Training loss  0.279 in Step 5700
# Training loss  0.261 in Step 5800
# Training loss  0.345 in Step 5900
# Training loss  0.275 in Step 6000
# ※※※Training loss  0.313※※※
# Training timepoint saved
# Valid loss  0.326 in Step 0
# Valid loss  0.699 in Step 50
# Valid loss  0.513 in Step 100
# Valid loss  0.345 in Step 150
# Valid loss  0.209 in Step 200
# Valid loss  0.248 in Step 250
# Valid loss  0.236 in Step 300
# Valid loss  0.133 in Step 350
# Valid loss  0.534 in Step 400
# Valid loss  0.270 in Step 450
# Valid loss  0.469 in Step 500
# Valid loss  0.450 in Step 550
# Valid loss  0.281 in Step 600
# Valid loss  0.299 in Step 650
# Valid loss  0.960 in Step 700
# Valid loss  0.300 in Step 750
# Valid loss  0.270 in Step 800
# ※※※Valid loss  0.370※※※
# Epoch 7
# Training loss  0.349 in Step 0
# Training loss  0.294 in Step 100
# Training loss  0.286 in Step 200
# Training loss  0.317 in Step 300
# Training loss  0.352 in Step 400
# Training loss  0.326 in Step 500
# Training loss  0.307 in Step 600
# Training loss  0.289 in Step 700
# Training loss  0.302 in Step 800
# Training loss  0.308 in Step 900
# Training loss  0.320 in Step 1000
# Training loss  0.323 in Step 1100
# Training loss  0.335 in Step 1200
# Training loss  0.327 in Step 1300
# Training loss  0.303 in Step 1400
# Training loss  0.273 in Step 1500
# Training loss  0.322 in Step 1600
# Training loss  0.290 in Step 1700
# Training loss  0.291 in Step 1800
# Training loss  0.311 in Step 1900
# Training loss  0.303 in Step 2000
# Training loss  0.333 in Step 2100
# Training loss  0.269 in Step 2200
# Training loss  0.302 in Step 2300
# Training loss  0.293 in Step 2400
# Training loss  0.242 in Step 2500
# Training loss  0.300 in Step 2600
# Training loss  0.312 in Step 2700
# Training loss  0.265 in Step 2800
# Training loss  0.312 in Step 2900
# Training loss  0.244 in Step 3000
# Training loss  0.284 in Step 3100
# Training loss  0.311 in Step 3200
# Training loss  0.310 in Step 3300
# Training loss  0.324 in Step 3400
# Training loss  0.314 in Step 3500
# Training loss  0.288 in Step 3600
# Training loss  0.292 in Step 3700
# Training loss  0.274 in Step 3800
# Training loss  0.276 in Step 3900
# Training loss  0.316 in Step 4000
# Training loss  0.307 in Step 4100
# Training loss  0.278 in Step 4200
# Training loss  0.300 in Step 4300
# Training loss  0.294 in Step 4400
# Training loss  0.348 in Step 4500
# Training loss  0.324 in Step 4600
# Training loss  0.280 in Step 4700
# Training loss  0.339 in Step 4800
# Training loss  0.300 in Step 4900
# Training loss  0.287 in Step 5000
# Training loss  0.334 in Step 5100
# Training loss  0.285 in Step 5200
# Training loss  0.294 in Step 5300
# Training loss  0.288 in Step 5400
# Training loss  0.266 in Step 5500
# Training loss  0.338 in Step 5600
# Training loss  0.304 in Step 5700
# Training loss  0.321 in Step 5800
# Training loss  0.332 in Step 5900
# Training loss  0.341 in Step 6000
# ※※※Training loss  0.306※※※
# Training timepoint saved
# Valid loss  0.309 in Step 0
# Valid loss  0.691 in Step 50
# Valid loss  0.494 in Step 100
# Valid loss  0.317 in Step 150
# Valid loss  0.188 in Step 200
# Valid loss  0.228 in Step 250
# Valid loss  0.206 in Step 300
# Valid loss  0.118 in Step 350
# Valid loss  0.520 in Step 400
# Valid loss  0.254 in Step 450
# Valid loss  0.457 in Step 500
# Valid loss  0.437 in Step 550
# Valid loss  0.265 in Step 600
# Valid loss  0.274 in Step 650
# Valid loss  0.954 in Step 700
# Valid loss  0.285 in Step 750
# Valid loss  0.253 in Step 800
# ※※※Valid loss  0.354※※※
# Epoch 8
# Training loss  0.337 in Step 0
# Training loss  0.298 in Step 100
# Training loss  0.292 in Step 200
# Training loss  0.309 in Step 300
# Training loss  0.282 in Step 400
# Training loss  0.310 in Step 500
# Training loss  0.290 in Step 600
# Training loss  0.357 in Step 700
# Training loss  0.258 in Step 800
# Training loss  0.294 in Step 900
# Training loss  0.280 in Step 1000
# Training loss  0.314 in Step 1100
# Training loss  0.387 in Step 1200
# Training loss  0.291 in Step 1300
# Training loss  0.303 in Step 1400
# Training loss  0.344 in Step 1500
# Training loss  0.317 in Step 1600
# Training loss  0.277 in Step 1700
# Training loss  0.283 in Step 1800
# Training loss  0.295 in Step 1900
# Training loss  0.268 in Step 2000
# Training loss  0.321 in Step 2100
# Training loss  0.306 in Step 2200
# Training loss  0.318 in Step 2300
# Training loss  0.287 in Step 2400
# Training loss  0.290 in Step 2500
# Training loss  0.318 in Step 2600
# Training loss  0.289 in Step 2700
# Training loss  0.323 in Step 2800
# Training loss  0.359 in Step 2900
# Training loss  0.286 in Step 3000
# Training loss  0.317 in Step 3100
# Training loss  0.281 in Step 3200
# Training loss  0.299 in Step 3300
# Training loss  0.268 in Step 3400
# Training loss  0.313 in Step 3500
# Training loss  0.284 in Step 3600
# Training loss  0.272 in Step 3700
# Training loss  0.296 in Step 3800
# Training loss  0.309 in Step 3900
# Training loss  0.303 in Step 4000
# Training loss  0.324 in Step 4100
# Training loss  0.305 in Step 4200
# Training loss  0.301 in Step 4300
# Training loss  0.328 in Step 4400
# Training loss  0.264 in Step 4500
# Training loss  0.284 in Step 4600
# Training loss  0.295 in Step 4700
# Training loss  0.313 in Step 4800
# Training loss  0.313 in Step 4900
# Training loss  0.282 in Step 5000
# Training loss  0.292 in Step 5100
# Training loss  0.314 in Step 5200
# Training loss  0.273 in Step 5300
# Training loss  0.290 in Step 5400
# Training loss  0.264 in Step 5500
# Training loss  0.318 in Step 5600
# Training loss  0.314 in Step 5700
# Training loss  0.284 in Step 5800
# Training loss  0.245 in Step 5900
# Training loss  0.318 in Step 6000
# ※※※Training loss  0.300※※※
# Training timepoint saved
# Valid loss  0.308 in Step 0
# Valid loss  0.688 in Step 50
# Valid loss  0.498 in Step 100
# Valid loss  0.316 in Step 150
# Valid loss  0.189 in Step 200
# Valid loss  0.226 in Step 250
# Valid loss  0.206 in Step 300
# Valid loss  0.118 in Step 350
# Valid loss  0.520 in Step 400
# Valid loss  0.254 in Step 450
# Valid loss  0.457 in Step 500
# Valid loss  0.434 in Step 550
# Valid loss  0.264 in Step 600
# Valid loss  0.276 in Step 650
# Valid loss  0.990 in Step 700
# Valid loss  0.281 in Step 750
# Valid loss  0.250 in Step 800
# ※※※Valid loss  0.353※※※
# Epoch 9
# Training loss  0.339 in Step 0
# Training loss  0.353 in Step 100
# Training loss  0.283 in Step 200
# Training loss  0.314 in Step 300
# Training loss  0.287 in Step 400
# Training loss  0.269 in Step 500
# Training loss  0.318 in Step 600
# Training loss  0.305 in Step 700
# Training loss  0.323 in Step 800
# Training loss  0.306 in Step 900
# Training loss  0.339 in Step 1000
# Training loss  0.308 in Step 1100
# Training loss  0.281 in Step 1200
# Training loss  0.291 in Step 1300
# Training loss  0.303 in Step 1400
# Training loss  0.349 in Step 1500
# Training loss  0.278 in Step 1600
# Training loss  0.249 in Step 1700
# Training loss  0.310 in Step 1800
# Training loss  0.293 in Step 1900
# Training loss  0.262 in Step 2000
# Training loss  0.280 in Step 2100
# Training loss  0.277 in Step 2200
# Training loss  0.274 in Step 2300
# Training loss  0.287 in Step 2400
# Training loss  0.262 in Step 2500
# Training loss  0.341 in Step 2600
# Training loss  0.324 in Step 2700
# Training loss  0.296 in Step 2800
# Training loss  0.304 in Step 2900
# Training loss  0.275 in Step 3000
# Training loss  0.295 in Step 3100
# Training loss  0.276 in Step 3200
# Training loss  0.281 in Step 3300
# Training loss  0.322 in Step 3400
# Training loss  0.284 in Step 3500
# Training loss  0.298 in Step 3600
# Training loss  0.320 in Step 3700
# Training loss  0.312 in Step 3800
# Training loss  0.299 in Step 3900
# Training loss  0.308 in Step 4000
# Training loss  0.303 in Step 4100
# Training loss  0.318 in Step 4200
# Training loss  0.296 in Step 4300
# Training loss  0.321 in Step 4400
# Training loss  0.343 in Step 4500
# Training loss  0.267 in Step 4600
# Training loss  0.245 in Step 4700
# Training loss  0.342 in Step 4800
# Training loss  0.299 in Step 4900
# Training loss  0.275 in Step 5000
# Training loss  0.288 in Step 5100
# Training loss  0.329 in Step 5200
# Training loss  0.299 in Step 5300
# Training loss  0.332 in Step 5400
# Training loss  0.310 in Step 5500
# Training loss  0.288 in Step 5600
# Training loss  0.284 in Step 5700
# Training loss  0.261 in Step 5800
# Training loss  0.302 in Step 5900
# Training loss  0.293 in Step 6000
# ※※※Training loss  0.297※※※
# Training timepoint saved
# Valid loss  0.314 in Step 0
# Valid loss  0.688 in Step 50
# Valid loss  0.504 in Step 100
# Valid loss  0.320 in Step 150
# Valid loss  0.191 in Step 200
# Valid loss  0.227 in Step 250
# Valid loss  0.211 in Step 300
# Valid loss  0.117 in Step 350
# Valid loss  0.522 in Step 400
# Valid loss  0.258 in Step 450
# Valid loss  0.456 in Step 500
# Valid loss  0.433 in Step 550
# Valid loss  0.266 in Step 600
# Valid loss  0.276 in Step 650
# Valid loss  0.961 in Step 700
# Valid loss  0.281 in Step 750
# Valid loss  0.252 in Step 800
# ※※※Valid loss  0.355※※※
# Epoch 10
# Training loss  0.336 in Step 0
# Training loss  0.301 in Step 100
# Training loss  0.285 in Step 200
# Training loss  0.287 in Step 300
# Training loss  0.302 in Step 400
# Training loss  0.303 in Step 500
# Training loss  0.263 in Step 600
# Training loss  0.310 in Step 700
# Training loss  0.314 in Step 800
# Training loss  0.285 in Step 900
# Training loss  0.260 in Step 1000
# Training loss  0.288 in Step 1100
# Training loss  0.278 in Step 1200
# Training loss  0.297 in Step 1300
# Training loss  0.335 in Step 1400
# Training loss  0.304 in Step 1500
# Training loss  0.277 in Step 1600
# Training loss  0.277 in Step 1700
# Training loss  0.265 in Step 1800
# Training loss  0.226 in Step 1900
# Training loss  0.321 in Step 2000
# Training loss  0.325 in Step 2100
# Training loss  0.299 in Step 2200
# Training loss  0.373 in Step 2300
# Training loss  0.303 in Step 2400
# Training loss  0.337 in Step 2500
# Training loss  0.249 in Step 2600
# Training loss  0.270 in Step 2700
# Training loss  0.276 in Step 2800
# Training loss  0.318 in Step 2900
# Training loss  0.283 in Step 3000
# Training loss  0.310 in Step 3100
# Training loss  0.298 in Step 3200
# Training loss  0.281 in Step 3300
# Training loss  0.275 in Step 3400
# Training loss  0.308 in Step 3500
# Training loss  0.298 in Step 3600
# Training loss  0.323 in Step 3700
# Training loss  0.301 in Step 3800
# Training loss  0.283 in Step 3900
# Training loss  0.283 in Step 4000
# Training loss  0.296 in Step 4100
# Training loss  0.235 in Step 4200
# Training loss  0.323 in Step 4300
# Training loss  0.285 in Step 4400
# Training loss  0.278 in Step 4500
# Training loss  0.296 in Step 4600
# Training loss  0.317 in Step 4700
# Training loss  0.266 in Step 4800
# Training loss  0.306 in Step 4900
# Training loss  0.283 in Step 5000
# Training loss  0.245 in Step 5100
# Training loss  0.316 in Step 5200
# Training loss  0.263 in Step 5300
# Training loss  0.300 in Step 5400
# Training loss  0.319 in Step 5500
# Training loss  0.328 in Step 5600
# Training loss  0.252 in Step 5700
# Training loss  0.273 in Step 5800
# Training loss  0.296 in Step 5900
# Training loss  0.257 in Step 6000
# ※※※Training loss  0.294※※※
# Training timepoint saved
# Valid loss  0.304 in Step 0
# Valid loss  0.687 in Step 50
# Valid loss  0.491 in Step 100
# Valid loss  0.312 in Step 150
# Valid loss  0.177 in Step 200
# Valid loss  0.218 in Step 250
# Valid loss  0.192 in Step 300
# Valid loss  0.111 in Step 350
# Valid loss  0.516 in Step 400
# Valid loss  0.245 in Step 450
# Valid loss  0.451 in Step 500
# Valid loss  0.422 in Step 550
# Valid loss  0.259 in Step 600
# Valid loss  0.271 in Step 650
# Valid loss  0.972 in Step 700
# Valid loss  0.273 in Step 750
# Valid loss  0.243 in Step 800
# ※※※Valid loss  0.346※※※
# Epoch 11
# Training loss  0.296 in Step 0
# Training loss  0.247 in Step 100
# Training loss  0.312 in Step 200
# Training loss  0.331 in Step 300
# Training loss  0.277 in Step 400
# Training loss  0.304 in Step 500
# Training loss  0.287 in Step 600
# Training loss  0.281 in Step 700
# Training loss  0.344 in Step 800
# Training loss  0.261 in Step 900
# Training loss  0.282 in Step 1000
# Training loss  0.308 in Step 1100
# Training loss  0.299 in Step 1200
# Training loss  0.245 in Step 1300
# Training loss  0.317 in Step 1400
# Training loss  0.244 in Step 1500
# Training loss  0.286 in Step 1600
# Training loss  0.273 in Step 1700
# Training loss  0.322 in Step 1800
# Training loss  0.251 in Step 1900
# Training loss  0.301 in Step 2000
# Training loss  0.286 in Step 2100
# Training loss  0.253 in Step 2200
# Training loss  0.271 in Step 2300
# Training loss  0.291 in Step 2400
# Training loss  0.264 in Step 2500
# Training loss  0.256 in Step 2600
# Training loss  0.268 in Step 2700
# Training loss  0.312 in Step 2800
# Training loss  0.288 in Step 2900
# Training loss  0.295 in Step 3000
# Training loss  0.330 in Step 3100
# Training loss  0.319 in Step 3200
# Training loss  0.314 in Step 3300
# Training loss  0.304 in Step 3400
# Training loss  0.337 in Step 3500
# Training loss  0.268 in Step 3600
# Training loss  0.308 in Step 3700
# Training loss  0.281 in Step 3800
# Training loss  0.288 in Step 3900
# Training loss  0.311 in Step 4000
# Training loss  0.304 in Step 4100
# Training loss  0.305 in Step 4200
# Training loss  0.276 in Step 4300
# Training loss  0.311 in Step 4400
# Training loss  0.282 in Step 4500
# Training loss  0.298 in Step 4600
# Training loss  0.313 in Step 4700
# Training loss  0.256 in Step 4800
# Training loss  0.298 in Step 4900
# Training loss  0.289 in Step 5000
# Training loss  0.285 in Step 5100
# Training loss  0.324 in Step 5200
# Training loss  0.313 in Step 5300
# Training loss  0.306 in Step 5400
# Training loss  0.297 in Step 5500
# Training loss  0.273 in Step 5600
# Training loss  0.281 in Step 5700
# Training loss  0.264 in Step 5800
# Training loss  0.297 in Step 5900
# Training loss  0.302 in Step 6000
# ※※※Training loss  0.290※※※
# Training timepoint saved
# Valid loss  0.299 in Step 0
# Valid loss  0.683 in Step 50
# Valid loss  0.492 in Step 100
# Valid loss  0.310 in Step 150
# Valid loss  0.183 in Step 200
# Valid loss  0.215 in Step 250
# Valid loss  0.195 in Step 300
# Valid loss  0.109 in Step 350
# Valid loss  0.511 in Step 400
# Valid loss  0.244 in Step 450
# Valid loss  0.448 in Step 500
# Valid loss  0.422 in Step 550
# Valid loss  0.262 in Step 600
# Valid loss  0.277 in Step 650
# Valid loss  0.951 in Step 700
# Valid loss  0.271 in Step 750
# Valid loss  0.248 in Step 800
# ※※※Valid loss  0.344※※※
# Epoch 12
# Training loss  0.329 in Step 0
# Training loss  0.303 in Step 100
# Training loss  0.269 in Step 200
# Training loss  0.312 in Step 300
# Training loss  0.311 in Step 400
# Training loss  0.269 in Step 500
# Training loss  0.266 in Step 600
# Training loss  0.307 in Step 700
# Training loss  0.290 in Step 800
# Training loss  0.244 in Step 900
# Training loss  0.300 in Step 1000
# Training loss  0.304 in Step 1100
# Training loss  0.302 in Step 1200
# Training loss  0.325 in Step 1300
# Training loss  0.257 in Step 1400
# Training loss  0.270 in Step 1500
# Training loss  0.310 in Step 1600
# Training loss  0.270 in Step 1700
# Training loss  0.270 in Step 1800
# Training loss  0.281 in Step 1900
# Training loss  0.329 in Step 2000
# Training loss  0.262 in Step 2100
# Training loss  0.291 in Step 2200
# Training loss  0.252 in Step 2300
# Training loss  0.310 in Step 2400
# Training loss  0.265 in Step 2500
# Training loss  0.329 in Step 2600
# Training loss  0.326 in Step 2700
# Training loss  0.260 in Step 2800
# Training loss  0.282 in Step 2900
# Training loss  0.292 in Step 3000
# Training loss  0.310 in Step 3100
# Training loss  0.316 in Step 3200
# Training loss  0.310 in Step 3300
# Training loss  0.268 in Step 3400
# Training loss  0.232 in Step 3500
# Training loss  0.261 in Step 3600
# Training loss  0.280 in Step 3700
# Training loss  0.295 in Step 3800
# Training loss  0.271 in Step 3900
# Training loss  0.292 in Step 4000
# Training loss  0.328 in Step 4100
# Training loss  0.278 in Step 4200
# Training loss  0.304 in Step 4300
# Training loss  0.305 in Step 4400
# Training loss  0.287 in Step 4500
# Training loss  0.293 in Step 4600
# Training loss  0.310 in Step 4700
# Training loss  0.264 in Step 4800
# Training loss  0.298 in Step 4900
# Training loss  0.260 in Step 5000
# Training loss  0.327 in Step 5100
# Training loss  0.256 in Step 5200
# Training loss  0.306 in Step 5300
# Training loss  0.235 in Step 5400
# Training loss  0.251 in Step 5500
# Training loss  0.305 in Step 5600
# Training loss  0.275 in Step 5700
# Training loss  0.323 in Step 5800
# Training loss  0.254 in Step 5900
# Training loss  0.269 in Step 6000
# ※※※Training loss  0.285※※※
# Training timepoint saved
# Valid loss  0.297 in Step 0
# Valid loss  0.679 in Step 50
# Valid loss  0.486 in Step 100
# Valid loss  0.309 in Step 150
# Valid loss  0.168 in Step 200
# Valid loss  0.213 in Step 250
# Valid loss  0.190 in Step 300
# Valid loss  0.106 in Step 350
# Valid loss  0.511 in Step 400
# Valid loss  0.239 in Step 450
# Valid loss  0.445 in Step 500
# Valid loss  0.427 in Step 550
# Valid loss  0.257 in Step 600
# Valid loss  0.266 in Step 650
# Valid loss  0.948 in Step 700
# Valid loss  0.265 in Step 750
# Valid loss  0.239 in Step 800
# ※※※Valid loss  0.340※※※
# Epoch 13
# Training loss  0.267 in Step 0
# Training loss  0.270 in Step 100
# Training loss  0.287 in Step 200
# Training loss  0.281 in Step 300
# Training loss  0.289 in Step 400
# Training loss  0.282 in Step 500
# Training loss  0.336 in Step 600
# Training loss  0.318 in Step 700
# Training loss  0.270 in Step 800
# Training loss  0.311 in Step 900
# Training loss  0.295 in Step 1000
# Training loss  0.331 in Step 1100
# Training loss  0.276 in Step 1200
# Training loss  0.255 in Step 1300
# Training loss  0.236 in Step 1400
# Training loss  0.322 in Step 1500
# Training loss  0.292 in Step 1600
# Training loss  0.286 in Step 1700
# Training loss  0.290 in Step 1800
# Training loss  0.255 in Step 1900
# Training loss  0.262 in Step 2000
# Training loss  0.303 in Step 2100
# Training loss  0.282 in Step 2200
# Training loss  0.311 in Step 2300
# Training loss  0.244 in Step 2400
# Training loss  0.264 in Step 2500
# Training loss  0.281 in Step 2600
# Training loss  0.289 in Step 2700
# Training loss  0.322 in Step 2800
# Training loss  0.263 in Step 2900
# Training loss  0.321 in Step 3000
# Training loss  0.285 in Step 3100
# Training loss  0.316 in Step 3200
# Training loss  0.273 in Step 3300
# Training loss  0.262 in Step 3400
# Training loss  0.302 in Step 3500
# Training loss  0.264 in Step 3600
# Training loss  0.251 in Step 3700
# Training loss  0.295 in Step 3800
# Training loss  0.294 in Step 3900
# Training loss  0.347 in Step 4000
# Training loss  0.283 in Step 4100
# Training loss  0.303 in Step 4200
# Training loss  0.283 in Step 4300
# Training loss  0.273 in Step 4400
# Training loss  0.271 in Step 4500
# Training loss  0.273 in Step 4600
# Training loss  0.302 in Step 4700
# Training loss  0.290 in Step 4800
# Training loss  0.306 in Step 4900
# Training loss  0.269 in Step 5000
# Training loss  0.317 in Step 5100
# Training loss  0.272 in Step 5200
# Training loss  0.284 in Step 5300
# Training loss  0.258 in Step 5400
# Training loss  0.270 in Step 5500
# Training loss  0.278 in Step 5600
# Training loss  0.289 in Step 5700
# Training loss  0.273 in Step 5800
# Training loss  0.304 in Step 5900
# Training loss  0.291 in Step 6000
# ※※※Training loss  0.282※※※
# Training timepoint saved
# Valid loss  0.293 in Step 0
# Valid loss  0.676 in Step 50
# Valid loss  0.483 in Step 100
# Valid loss  0.304 in Step 150
# Valid loss  0.166 in Step 200
# Valid loss  0.209 in Step 250
# Valid loss  0.187 in Step 300
# Valid loss  0.104 in Step 350
# Valid loss  0.509 in Step 400
# Valid loss  0.236 in Step 450
# Valid loss  0.441 in Step 500
# Valid loss  0.413 in Step 550
# Valid loss  0.252 in Step 600
# Valid loss  0.262 in Step 650
# Valid loss  0.949 in Step 700
# Valid loss  0.259 in Step 750
# Valid loss  0.232 in Step 800
# ※※※Valid loss  0.335※※※
# Epoch 14
# Training loss  0.289 in Step 0
# Training loss  0.245 in Step 100
# Training loss  0.265 in Step 200
# Training loss  0.262 in Step 300
# Training loss  0.272 in Step 400
# Training loss  0.257 in Step 500
# Training loss  0.276 in Step 600
# Training loss  0.275 in Step 700
# Training loss  0.325 in Step 800
# Training loss  0.283 in Step 900
# Training loss  0.282 in Step 1000
# Training loss  0.281 in Step 1100
# Training loss  0.294 in Step 1200
# Training loss  0.229 in Step 1300
# Training loss  0.286 in Step 1400
# Training loss  0.263 in Step 1500
# Training loss  0.249 in Step 1600
# Training loss  0.268 in Step 1700
# Training loss  0.325 in Step 1800
# Training loss  0.308 in Step 1900
# Training loss  0.294 in Step 2000
# Training loss  0.316 in Step 2100
# Training loss  0.353 in Step 2200
# Training loss  0.287 in Step 2300
# Training loss  0.288 in Step 2400
# Training loss  0.280 in Step 2500
# Training loss  0.284 in Step 2600
# Training loss  0.258 in Step 2700
# Training loss  0.259 in Step 2800
# Training loss  0.277 in Step 2900
# Training loss  0.236 in Step 3000
# Training loss  0.284 in Step 3100
# Training loss  0.286 in Step 3200
# Training loss  0.264 in Step 3300
# Training loss  0.289 in Step 3400
# Training loss  0.280 in Step 3500
# Training loss  0.317 in Step 3600
# Training loss  0.326 in Step 3700
# Training loss  0.366 in Step 3800
# Training loss  0.266 in Step 3900
# Training loss  0.242 in Step 4000
# Training loss  0.308 in Step 4100
# Training loss  0.234 in Step 4200
# Training loss  0.285 in Step 4300
# Training loss  0.285 in Step 4400
# Training loss  0.288 in Step 4500
# Training loss  0.249 in Step 4600
# Training loss  0.287 in Step 4700
# Training loss  0.270 in Step 4800
# Training loss  0.285 in Step 4900
# Training loss  0.300 in Step 5000
# Training loss  0.316 in Step 5100
# Training loss  0.295 in Step 5200
# Training loss  0.260 in Step 5300
# Training loss  0.286 in Step 5400
# Training loss  0.284 in Step 5500
# Training loss  0.272 in Step 5600
# Training loss  0.294 in Step 5700
# Training loss  0.313 in Step 5800
# Training loss  0.252 in Step 5900
# Training loss  0.281 in Step 6000
# ※※※Training loss  0.280※※※
# Training timepoint saved
# Valid loss  0.290 in Step 0
# Valid loss  0.674 in Step 50
# Valid loss  0.481 in Step 100
# Valid loss  0.303 in Step 150
# Valid loss  0.167 in Step 200
# Valid loss  0.209 in Step 250
# Valid loss  0.188 in Step 300
# Valid loss  0.104 in Step 350
# Valid loss  0.508 in Step 400
# Valid loss  0.236 in Step 450
# Valid loss  0.440 in Step 500
# Valid loss  0.407 in Step 550
# Valid loss  0.249 in Step 600
# Valid loss  0.261 in Step 650
# Valid loss  0.946 in Step 700
# Valid loss  0.258 in Step 750
# Valid loss  0.232 in Step 800
# ※※※Valid loss  0.334※※※
# Epoch 15
# Training loss  0.223 in Step 0
# Training loss  0.271 in Step 100
# Training loss  0.292 in Step 200
# Training loss  0.333 in Step 300
# Training loss  0.312 in Step 400
# Training loss  0.266 in Step 500
# Training loss  0.292 in Step 600
# Training loss  0.268 in Step 700
# Training loss  0.292 in Step 800
# Training loss  0.277 in Step 900
# Training loss  0.283 in Step 1000
# Training loss  0.259 in Step 1100
# Training loss  0.257 in Step 1200
# Training loss  0.289 in Step 1300
# Training loss  0.267 in Step 1400
# Training loss  0.317 in Step 1500
# Training loss  0.261 in Step 1600
# Training loss  0.322 in Step 1700
# Training loss  0.273 in Step 1800
# Training loss  0.272 in Step 1900
# Training loss  0.260 in Step 2000
# Training loss  0.260 in Step 2100
# Training loss  0.289 in Step 2200
# Training loss  0.288 in Step 2300
# Training loss  0.273 in Step 2400
# Training loss  0.335 in Step 2500
# Training loss  0.271 in Step 2600
# Training loss  0.337 in Step 2700
# Training loss  0.274 in Step 2800
# Training loss  0.267 in Step 2900
# Training loss  0.260 in Step 3000
# Training loss  0.249 in Step 3100
# Training loss  0.298 in Step 3200
# Training loss  0.237 in Step 3300
# Training loss  0.295 in Step 3400
# Training loss  0.303 in Step 3500
# Training loss  0.312 in Step 3600
# Training loss  0.266 in Step 3700
# Training loss  0.321 in Step 3800
# Training loss  0.286 in Step 3900
# Training loss  0.302 in Step 4000
# Training loss  0.277 in Step 4100
# Training loss  0.286 in Step 4200
# Training loss  0.278 in Step 4300
# Training loss  0.264 in Step 4400
# Training loss  0.293 in Step 4500
# Training loss  0.283 in Step 4600
# Training loss  0.254 in Step 4700
# Training loss  0.272 in Step 4800
# Training loss  0.260 in Step 4900
# Training loss  0.271 in Step 5000
# Training loss  0.297 in Step 5100
# Training loss  0.265 in Step 5200
# Training loss  0.274 in Step 5300
# Training loss  0.272 in Step 5400
# Training loss  0.264 in Step 5500
# Training loss  0.272 in Step 5600
# Training loss  0.286 in Step 5700
# Training loss  0.256 in Step 5800
# Training loss  0.278 in Step 5900
# Training loss  0.253 in Step 6000
# ※※※Training loss  0.278※※※
# Training timepoint saved
# Valid loss  0.292 in Step 0
# Valid loss  0.672 in Step 50
# Valid loss  0.481 in Step 100
# Valid loss  0.305 in Step 150
# Valid loss  0.166 in Step 200
# Valid loss  0.208 in Step 250
# Valid loss  0.186 in Step 300
# Valid loss  0.104 in Step 350
# Valid loss  0.506 in Step 400
# Valid loss  0.236 in Step 450
# Valid loss  0.441 in Step 500
# Valid loss  0.408 in Step 550
# Valid loss  0.248 in Step 600
# Valid loss  0.261 in Step 650
# Valid loss  0.945 in Step 700
# Valid loss  0.258 in Step 750
# Valid loss  0.234 in Step 800
# ※※※Valid loss  0.334※※※
# Epoch 16
# Training loss  0.288 in Step 0
# Training loss  0.301 in Step 100
# Training loss  0.240 in Step 200
# Training loss  0.299 in Step 300
# Training loss  0.258 in Step 400
# Training loss  0.275 in Step 500
# Training loss  0.259 in Step 600
# Training loss  0.291 in Step 700
# Training loss  0.282 in Step 800
# Training loss  0.273 in Step 900
# Training loss  0.245 in Step 1000
# Training loss  0.263 in Step 1100
# Training loss  0.284 in Step 1200
# Training loss  0.289 in Step 1300
# Training loss  0.302 in Step 1400
# Training loss  0.268 in Step 1500
# Training loss  0.313 in Step 1600
# Training loss  0.304 in Step 1700
# Training loss  0.279 in Step 1800
# Training loss  0.297 in Step 1900
# Training loss  0.263 in Step 2000
# Training loss  0.276 in Step 2100
# Training loss  0.274 in Step 2200
# Training loss  0.264 in Step 2300
# Training loss  0.288 in Step 2400
# Training loss  0.273 in Step 2500
# Training loss  0.265 in Step 2600
# Training loss  0.232 in Step 2700
# Training loss  0.304 in Step 2800
# Training loss  0.268 in Step 2900
# Training loss  0.242 in Step 3000
# Training loss  0.295 in Step 3100
# Training loss  0.240 in Step 3200
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[23], line 2
#       1 if __name__ == "__main__":
# ----> 2     train()
#
# Cell In[22], line 17, in train()
#      14 x = x.to(device)
#      15 y = y.to(device)
# ---> 17 recon_x, attn_weight = model(x, x_lens, x_mask)
#      19 loss = model_loss.get_loss(recon_x, y, x_mask)
#      21 train_loss += loss.item()
#
# File ~/anaconda3/envs/wavln/lib/python3.11/site-packages/torch/nn/modules/module.py:1518, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1516     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1517 else:
# -> 1518     return self._call_impl(*args, **kwargs)
#
# File ~/anaconda3/envs/wavln/lib/python3.11/site-packages/torch/nn/modules/module.py:1527, in Module._call_impl(self, *args, **kwargs)
#    1522 # If we don't have any hooks, we want to skip the rest of the logic in
#    1523 # this function, and just call forward.
#    1524 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1525         or _global_backward_pre_hooks or _global_backward_hooks
#    1526         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1527     return forward_call(*args, **kwargs)
#    1529 try:
#    1530     result = None
#
# File ~/Projects/wavln/script/model_model.py:780, in SimplerPhxLearnerInit.forward(self, inputs, input_lens, in_mask)
#     777 dec_hid, init_in = self.decoder.inits(batch_size=batch_size, device=self.device)
#     779 enc_out = self.encoder(inputs, input_lens, in_mask)
# --> 780 dec_out, attn_w = self.decoder(enc_out, in_mask, init_in, dec_hid)
#     781 return dec_out, attn_w
#
# File ~/anaconda3/envs/wavln/lib/python3.11/site-packages/torch/nn/modules/module.py:1518, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1516     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1517 else:
# -> 1518     return self._call_impl(*args, **kwargs)
#
# File ~/anaconda3/envs/wavln/lib/python3.11/site-packages/torch/nn/modules/module.py:1527, in Module._call_impl(self, *args, **kwargs)
#    1522 # If we don't have any hooks, we want to skip the rest of the logic in
#    1523 # this function, and just call forward.
#    1524 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1525         or _global_backward_pre_hooks or _global_backward_hooks
#    1526         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1527     return forward_call(*args, **kwargs)
#    1529 try:
#    1530     result = None
#
# File ~/Projects/wavln/script/model_model.py:396, in InitRALDecoder.forward(self, hid_r, in_mask, init_in, hidden)
#     394 dec_x, hidden = self.rnn(dec_in_token, hidden)
#     395 # dec_x = self.lin_2(dec_x)
# --> 396 dec_x, attention_weight = self.attention(dec_x, hid_r, hid_r, in_mask.unsqueeze(1))    # unsqueeze mask here for broadcast
#     397 dec_x = self.lin_3(dec_x)
#     398 # dec_x = self.act(dec_x)
#
# File ~/anaconda3/envs/wavln/lib/python3.11/site-packages/torch/nn/modules/module.py:1518, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1516     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1517 else:
# -> 1518     return self._call_impl(*args, **kwargs)
#
# File ~/anaconda3/envs/wavln/lib/python3.11/site-packages/torch/nn/modules/module.py:1527, in Module._call_impl(self, *args, **kwargs)
#    1522 # If we don't have any hooks, we want to skip the rest of the logic in
#    1523 # this function, and just call forward.
#    1524 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1525         or _global_backward_pre_hooks or _global_backward_hooks
#    1526         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1527     return forward_call(*args, **kwargs)
#    1529 try:
#    1530     result = None
#
# File ~/Projects/wavln/script/model_attention.py:23, in ScaledDotProductAttention.forward(self, q, k, v, mask)
#      14 """
#      15 q: Query tensor of shape (batch_size, num_queries, d_k)
#      16 k: Key tensor of shape (batch_size, num_keys, d_k)
#    (...)
#      20 Returns: Output tensor of shape (batch_size, num_queries, d_v)
#      21 """
#      22 q = self.w_q(q)
# ---> 23 k = self.w_k(k)
#      24 v = self.w_v(v)
#      26 # Step 1: Compute the dot product between queries and keys
#
# File ~/anaconda3/envs/wavln/lib/python3.11/site-packages/torch/nn/modules/module.py:1518, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1516     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1517 else:
# -> 1518     return self._call_impl(*args, **kwargs)
#
# File ~/anaconda3/envs/wavln/lib/python3.11/site-packages/torch/nn/modules/module.py:1521, in Module._call_impl(self, *args, **kwargs)
#    1520 def _call_impl(self, *args, **kwargs):
# -> 1521     forward_call = (self._slow_forward if torch._C._get_tracing_state() else self.forward)
#    1522     # If we don't have any hooks, we want to skip the rest of the logic in
#    1523     # this function, and just call forward.
#    1524     if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1525             or _global_backward_pre_hooks or _global_backward_hooks
#    1526             or _global_forward_hooks or _global_forward_pre_hooks):
#
# KeyboardInterrupt:

# %%
### Save
train_losses.save()

valid_losses.save()

text_hist.save()

# %%
plt.plot(train_losses.get(), label='Train')
plt.plot(valid_losses.get(), label='Valid')
plt.title("Learning Curve Loss")
plt.legend()
plt.savefig(os.path.join(model_save_dir, "train.png"))

# %% [markdown]
# ## Conclusion
# This model should converge to loss around 0.49x.
