# %% [markdown]
# # Sequence Learning - Direct - English
# Version 1: In this version we make the model "simple": make the encoder RNN into normal RNN first and try to see the result.
# Version 2: Learning is not very much. Following Dr Coupe's advice we try simpler model structure.
# Version 3: A simple trial training with Mel spectrogram instead of MFCC.
# Version 4: try to enlarge the hidden dimensions so that we might still make sense of the hidden representation.
# Version 5: restore to MFCC, keep 8-dimensional, direct feedin.

# %%
import torch
import torchaudio
from torch import nn
import torch.nn.functional as F
from torch.nn.utils.rnn import pad_sequence, pack_sequence
from torch import optim
from torch.utils.data import Dataset, DataLoader, random_split
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import pickle
from datetime import datetime

# %%
from model import PhxLearner, SimplerPhxLearner
from my_dataset import DS_Tools
from dataset import SeqDataset, MFCCTransform
from paths import *
from my_utils import *
from recorder import *
from loss import *
from padding import generate_mask_from_lengths_mat, mask_it

# %% [markdown]
# ### Dirs

# %%
model_save_dir = model_eng_save_dir
# random_data:phone_seg_random_path
# anno_data: phone_seg_anno_path

# random_log_path = phone_seg_random_log_path + "log.csv"
random_log_path = word_seg_anno_log_path
random_path = word_seg_anno_path
anno_log_path = phone_seg_anno_path

# %% [markdown]
# ### Constants

# %%
BATCH_SIZE = 128

INPUT_DIM = 39
OUTPUT_DIM = 39

INTER_DIM_0 = 32
INTER_DIM_1 = 16
INTER_DIM_2 = 4

ENC_SIZE_LIST = [INPUT_DIM, INTER_DIM_0, INTER_DIM_1, INTER_DIM_2]
DEC_SIZE_LIST = [OUTPUT_DIM, INTER_DIM_0, INTER_DIM_1, INTER_DIM_2]

DROPOUT = 0.7

REC_SAMPLE_RATE = 16000
N_FFT = 400
N_MELS = 64

LOADER_WORKER = 16
# LOADER_WORKER = 0

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
recon_loss = nn.MSELoss(reduction='none')
masked_recon_loss = MaskedLoss(recon_loss)
model_loss = masked_recon_loss

model = SimplerPhxLearner(enc_size_list=ENC_SIZE_LIST, dec_size_list=DEC_SIZE_LIST, num_layers=1)
model.to(device)
optimizer = optim.Adam(model.parameters(), lr=1e-3)

# %%
# # initialize model weights
# def init_weights(m):
#     if isinstance(m, nn.Linear):
#         torch.nn.init.orthogonal_(m.weight)
#         m.bias.data.fill_(0.01)
#     if isinstance(m, nn.LSTM): 
#         for name, p in m.named_parameters():
#             if "weight" in name: 
#                 nn.init.orthogonal_(p)
#             elif "bias" in name: 
#                 nn.init.constant_(p, 0)

# model.apply(init_weights)

# %%
model_parameters = filter(lambda p: p.requires_grad, model.parameters())
params = sum([np.prod(p.size()) for p in model_parameters])

# %%
params
# Out:
# 4691

# %%
# Just for keeping records of training hists. 
# ts = "0918192113"
stop_epoch = "149"
ts = str(get_timestamp())
save_txt_name = "train_txt_{}.hst".format(ts)
save_trainhist_name = "train_hist_{}.hst".format(ts)

save_valhist_name = "val_hist_{}.hst".format(ts)

# %%
train_losses = LossRecorder(model_save_dir + save_trainhist_name)

valid_losses = LossRecorder(model_save_dir + save_valhist_name)

text_hist = HistRecorder(model_save_dir + save_txt_name)

# %%
READ = False
# READ = True

# %%
if READ: 
    valid_losses.read()
    train_losses.read()

    model_raw_name = "PT_{}_{}_full".format(ts, stop_epoch)
    model_name = model_raw_name + ".pt"
    model_path = os.path.join(model_save_dir, model_name)
    state = torch.load(model_path)

    model.load_state_dict(state)
    model.to(device)

# %%
mytrans = MFCCTransform(sample_rate=REC_SAMPLE_RATE, n_fft=N_FFT)
ds = SeqDataset(random_path, os.path.join(random_log_path, "log.csv"), transform=mytrans)

test = False
if test: 
    use_len = int(0.1 * len(ds))
    remain_len = len(ds) - use_len

    # Randomly split the dataset into train and validation sets
    ds, remain_ds = random_split(ds, [use_len, remain_len])


if READ: 
    valid_ds_indices = DS_Tools.read_indices(os.path.join(model_save_dir, "valid_ds_{}.pkl".format(ts)))
    all_indices = list(range(len(ds)))
    train_ds_indices = list(set(all_indices).difference(set(valid_ds_indices)))

    train_ds = torch.utils.data.Subset(ds, train_ds_indices)
    valid_ds = torch.utils.data.Subset(ds, valid_ds_indices)
else: 
    train_len = int(0.8 * len(ds))
    valid_len = len(ds) - train_len

    # Randomly split the dataset into train and validation sets
    train_ds, valid_ds = random_split(ds, [train_len, valid_len])
    DS_Tools.save_indices(os.path.join(model_save_dir, "valid_ds_{}.pkl".format(ts)), valid_ds.indices)

train_loader = DataLoader(train_ds, batch_size=BATCH_SIZE, shuffle=True, num_workers=LOADER_WORKER, collate_fn=SeqDataset.collate_fn)
train_num = len(train_loader.dataset)

valid_loader = DataLoader(valid_ds, batch_size=BATCH_SIZE, shuffle=False, num_workers=LOADER_WORKER, collate_fn=SeqDataset.collate_fn)
valid_num = len(valid_loader.dataset)

# %%
len(train_loader)
# Out:
# 1776

# %%
EPOCHS = 300
BASE = 0

# %%
def train(): 
    for epoch in range(BASE, BASE + EPOCHS):
        text_hist.print("Epoch {}".format(epoch))

        model.train()
        train_loss = 0.
        train_num = len(train_loader)    # train_loader
        for idx, (x, x_lens) in enumerate(train_loader):
            optimizer.zero_grad()
            y = x 
            
            x_mask = generate_mask_from_lengths_mat(x_lens, device=device)
            
            x = x.to(device)
            y = y.to(device)

            recon_x, attn_weight = model(x, x_lens, x_mask)

            loss = model_loss.get_loss(recon_x, y, x_mask)

            train_loss += loss.item()

            loss.backward()
            
            # torch.nn.utils.clip_grad_norm_(model.parameters(), clip_value)
            # 这个函数计算的是全局梯度范数
            # torch.nn.utils.clip_grad_norm(parameters=model.parameters(), max_norm=5, norm_type=2)
            torch.nn.utils.clip_grad_norm_(parameters=model.parameters(), max_norm=5, norm_type=2)
            # parameters: an iterable of Variables that will have gradients normalized
            # max_norm: max norm of the gradients(阈值设定)
            # norm_type: type of the used p-norm. Can be'inf'for infinity norm(定义范数类型)

            optimizer.step()

            if idx % 100 == 0:
                text_hist.print(f"Training loss {loss: .3f} in Step {idx}")

        train_losses.append(train_loss / train_num)
        text_hist.print(f"※※※Training loss {train_loss / train_num: .3f}※※※")

        last_model_name = "PT_{}_{}_full.pt".format(ts, epoch)
        torch.save(model.state_dict(), os.path.join(model_save_dir, last_model_name))
        text_hist.print("Training timepoint saved")

        model.eval()
        valid_loss = 0.
        valid_num = len(valid_loader)
        for idx, (x, x_lens) in enumerate(valid_loader):
            y = x    # extract MFCC-only data
            x_mask = generate_mask_from_lengths_mat(x_lens, device=device)
            
            x = x.to(device)
            y = y.to(device)

            recon_x, attn_weight = model(x, x_lens, x_mask)

            loss = model_loss.get_loss(recon_x, y, x_mask)

            valid_loss += loss.item()

            if idx % 10 == 0:
                text_hist.print(f"Valid loss {loss: .3f} in Step {idx}")

        valid_losses.append(valid_loss / valid_num)

        text_hist.print(f"※※※Valid loss {valid_loss / valid_num: .3f}※※※")

# %%
if __name__ == "__main__": 
    train()
# Out:
# Epoch 0
# Training loss  1.155 in Step 0
# Training loss  1.046 in Step 100
# Training loss  1.009 in Step 200
# Training loss  1.000 in Step 300
# Training loss  1.000 in Step 400
# Training loss  1.000 in Step 500
# Training loss  1.000 in Step 600
# Training loss  1.000 in Step 700
# Training loss  1.000 in Step 800
# Training loss  1.000 in Step 900
# Training loss  1.000 in Step 1000
# Training loss  0.999 in Step 1100
# Training loss  0.999 in Step 1200
# Training loss  0.999 in Step 1300
# Training loss  0.998 in Step 1400
# Training loss  0.998 in Step 1500
# Training loss  0.999 in Step 1600
# Training loss  0.999 in Step 1700
# ※※※Training loss  1.006※※※
# Training timepoint saved
# Valid loss  1.000 in Step 0
# Valid loss  1.000 in Step 10
# Valid loss  0.998 in Step 20
# Valid loss  1.000 in Step 30
# Valid loss  1.000 in Step 40
# Valid loss  0.999 in Step 50
# Valid loss  1.000 in Step 60
# Valid loss  1.000 in Step 70
# Valid loss  1.000 in Step 80
# Valid loss  1.000 in Step 90
# Valid loss  1.000 in Step 100
# Valid loss  0.999 in Step 110
# Valid loss  0.999 in Step 120
# Valid loss  0.999 in Step 130
# Valid loss  1.000 in Step 140
# Valid loss  1.000 in Step 150
# Valid loss  1.000 in Step 160
# Valid loss  1.000 in Step 170
# Valid loss  1.000 in Step 180
# Valid loss  1.000 in Step 190
# Valid loss  1.000 in Step 200
# Valid loss  1.000 in Step 210
# Valid loss  0.999 in Step 220
# Valid loss  0.999 in Step 230
# Valid loss  1.000 in Step 240
# Valid loss  1.000 in Step 250
# Valid loss  1.000 in Step 260
# Valid loss  1.000 in Step 270
# Valid loss  1.000 in Step 280
# Valid loss  1.000 in Step 290
# Valid loss  1.000 in Step 300
# Valid loss  1.000 in Step 310
# Valid loss  1.000 in Step 320
# Valid loss  1.000 in Step 330
# Valid loss  0.999 in Step 340
# Valid loss  1.000 in Step 350
# Valid loss  1.000 in Step 360
# Valid loss  1.000 in Step 370
# Valid loss  1.000 in Step 380
# Valid loss  1.000 in Step 390
# Valid loss  1.000 in Step 400
# Valid loss  1.000 in Step 410
# Valid loss  1.000 in Step 420
# Valid loss  1.000 in Step 430
# Valid loss  0.999 in Step 440
# ※※※Valid loss  1.000※※※
# Epoch 1
# Training loss  0.998 in Step 0
# Training loss  0.998 in Step 100
# Training loss  0.998 in Step 200
# Training loss  0.998 in Step 300
# Training loss  0.997 in Step 400
# Training loss  0.998 in Step 500
# Training loss  0.996 in Step 600
# Training loss  0.995 in Step 700
# Training loss  0.997 in Step 800
# Training loss  0.995 in Step 900
# Training loss  0.994 in Step 1000
# Training loss  0.996 in Step 1100
# Training loss  0.995 in Step 1200
# Training loss  0.995 in Step 1300
# Training loss  0.996 in Step 1400
# Training loss  0.996 in Step 1500
# Training loss  0.994 in Step 1600
# Training loss  0.993 in Step 1700
# ※※※Training loss  0.996※※※
# Training timepoint saved
# Valid loss  0.999 in Step 0
# Valid loss  0.999 in Step 10
# Valid loss  0.997 in Step 20
# Valid loss  0.998 in Step 30
# Valid loss  0.999 in Step 40
# Valid loss  0.998 in Step 50
# Valid loss  0.999 in Step 60
# Valid loss  0.999 in Step 70
# Valid loss  0.999 in Step 80
# Valid loss  0.999 in Step 90
# Valid loss  0.999 in Step 100
# Valid loss  0.999 in Step 110
# Valid loss  0.998 in Step 120
# Valid loss  0.998 in Step 130
# Valid loss  0.999 in Step 140
# Valid loss  0.998 in Step 150
# Valid loss  0.999 in Step 160
# Valid loss  0.999 in Step 170
# Valid loss  0.998 in Step 180
# Valid loss  0.999 in Step 190
# Valid loss  0.999 in Step 200
# Valid loss  0.999 in Step 210
# Valid loss  0.998 in Step 220
# Valid loss  0.998 in Step 230
# Valid loss  0.999 in Step 240
# Valid loss  0.999 in Step 250
# Valid loss  0.999 in Step 260
# Valid loss  0.999 in Step 270
# Valid loss  0.999 in Step 280
# Valid loss  0.999 in Step 290
# Valid loss  0.999 in Step 300
# Valid loss  0.999 in Step 310
# Valid loss  0.999 in Step 320
# Valid loss  0.998 in Step 330
# Valid loss  0.998 in Step 340
# Valid loss  0.999 in Step 350
# Valid loss  0.999 in Step 360
# Valid loss  0.999 in Step 370
# Valid loss  0.999 in Step 380
# Valid loss  0.999 in Step 390
# Valid loss  0.999 in Step 400
# Valid loss  0.998 in Step 410
# Valid loss  0.999 in Step 420
# Valid loss  0.999 in Step 430
# Valid loss  0.998 in Step 440
# ※※※Valid loss  0.999※※※
# Epoch 2
# Training loss  0.994 in Step 0
# Training loss  0.995 in Step 100
# Training loss  0.995 in Step 200
# Training loss  0.996 in Step 300
# Training loss  0.995 in Step 400
# Training loss  0.993 in Step 500
# Training loss  0.994 in Step 600
# Training loss  0.994 in Step 700
# Training loss  0.992 in Step 800
# Training loss  0.993 in Step 900
# Training loss  0.995 in Step 1000
# Training loss  0.993 in Step 1100
# Training loss  0.994 in Step 1200
# Training loss  0.993 in Step 1300
# Training loss  0.992 in Step 1400
# Training loss  0.993 in Step 1500
# Training loss  0.993 in Step 1600
# Training loss  0.993 in Step 1700
# ※※※Training loss  0.994※※※
# Training timepoint saved
# Valid loss  0.998 in Step 0
# Valid loss  0.999 in Step 10
# Valid loss  0.997 in Step 20
# Valid loss  0.998 in Step 30
# Valid loss  0.999 in Step 40
# Valid loss  0.998 in Step 50
# Valid loss  0.999 in Step 60
# Valid loss  0.999 in Step 70
# Valid loss  0.998 in Step 80
# Valid loss  0.999 in Step 90
# Valid loss  0.999 in Step 100
# Valid loss  0.998 in Step 110
# Valid loss  0.998 in Step 120
# Valid loss  0.997 in Step 130
# Valid loss  0.998 in Step 140
# Valid loss  0.998 in Step 150
# Valid loss  0.998 in Step 160
# Valid loss  0.999 in Step 170
# Valid loss  0.998 in Step 180
# Valid loss  0.998 in Step 190
# Valid loss  0.999 in Step 200
# Valid loss  0.999 in Step 210
# Valid loss  0.998 in Step 220
# Valid loss  0.998 in Step 230
# Valid loss  0.999 in Step 240
# Valid loss  0.999 in Step 250
# Valid loss  0.998 in Step 260
# Valid loss  0.999 in Step 270
# Valid loss  0.999 in Step 280
# Valid loss  0.999 in Step 290
# Valid loss  0.999 in Step 300
# Valid loss  0.999 in Step 310
# Valid loss  0.999 in Step 320
# Valid loss  0.998 in Step 330
# Valid loss  0.998 in Step 340
# Valid loss  0.998 in Step 350
# Valid loss  0.999 in Step 360
# Valid loss  0.999 in Step 370
# Valid loss  0.998 in Step 380
# Valid loss  0.999 in Step 390
# Valid loss  0.999 in Step 400
# Valid loss  0.998 in Step 410
# Valid loss  0.998 in Step 420
# Valid loss  0.999 in Step 430
# Valid loss  0.998 in Step 440
# ※※※Valid loss  0.998※※※
# Epoch 3
# Training loss  0.993 in Step 0
# Training loss  0.994 in Step 100
# Training loss  0.993 in Step 200
# Training loss  0.992 in Step 300
# Training loss  0.993 in Step 400
# Training loss  0.994 in Step 500
# Training loss  0.992 in Step 600
# Training loss  0.993 in Step 700
# Training loss  0.993 in Step 800
# Training loss  0.993 in Step 900
# Training loss  0.993 in Step 1000
# Training loss  0.993 in Step 1100
# Training loss  0.993 in Step 1200
# Training loss  0.993 in Step 1300
# Training loss  0.991 in Step 1400
# Training loss  0.993 in Step 1500
# Training loss  0.993 in Step 1600
# Training loss  0.992 in Step 1700
# ※※※Training loss  0.993※※※
# Training timepoint saved
# Valid loss  0.998 in Step 0
# Valid loss  0.998 in Step 10
# Valid loss  0.996 in Step 20
# Valid loss  0.998 in Step 30
# Valid loss  0.998 in Step 40
# Valid loss  0.997 in Step 50
# Valid loss  0.998 in Step 60
# Valid loss  0.999 in Step 70
# Valid loss  0.998 in Step 80
# Valid loss  0.999 in Step 90
# Valid loss  0.999 in Step 100
# Valid loss  0.998 in Step 110
# Valid loss  0.998 in Step 120
# Valid loss  0.997 in Step 130
# Valid loss  0.998 in Step 140
# Valid loss  0.998 in Step 150
# Valid loss  0.998 in Step 160
# Valid loss  0.998 in Step 170
# Valid loss  0.998 in Step 180
# Valid loss  0.998 in Step 190
# Valid loss  0.998 in Step 200
# Valid loss  0.999 in Step 210
# Valid loss  0.998 in Step 220
# Valid loss  0.998 in Step 230
# Valid loss  0.999 in Step 240
# Valid loss  0.998 in Step 250
# Valid loss  0.998 in Step 260
# Valid loss  0.998 in Step 270
# Valid loss  0.999 in Step 280
# Valid loss  0.999 in Step 290
# Valid loss  0.998 in Step 300
# Valid loss  0.999 in Step 310
# Valid loss  0.999 in Step 320
# Valid loss  0.998 in Step 330
# Valid loss  0.998 in Step 340
# Valid loss  0.998 in Step 350
# Valid loss  0.999 in Step 360
# Valid loss  0.999 in Step 370
# Valid loss  0.998 in Step 380
# Valid loss  0.999 in Step 390
# Valid loss  0.998 in Step 400
# Valid loss  0.998 in Step 410
# Valid loss  0.998 in Step 420
# Valid loss  0.999 in Step 430
# Valid loss  0.998 in Step 440
# ※※※Valid loss  0.998※※※
# Epoch 4
# Training loss  0.992 in Step 0
# Training loss  0.994 in Step 100
# Training loss  0.993 in Step 200
# Training loss  0.992 in Step 300
# Training loss  0.991 in Step 400
# Training loss  0.992 in Step 500
# Training loss  0.992 in Step 600
# Training loss  0.992 in Step 700
# Training loss  0.992 in Step 800
# Training loss  0.993 in Step 900
# Training loss  0.992 in Step 1000
# Training loss  0.992 in Step 1100
# Training loss  0.992 in Step 1200
# Training loss  0.993 in Step 1300
# Training loss  0.991 in Step 1400
# Training loss  0.992 in Step 1500
# Training loss  0.992 in Step 1600
# Training loss  0.991 in Step 1700
# ※※※Training loss  0.992※※※
# Training timepoint saved
# Valid loss  0.998 in Step 0
# Valid loss  0.998 in Step 10
# Valid loss  0.996 in Step 20
# Valid loss  0.998 in Step 30
# Valid loss  0.998 in Step 40
# Valid loss  0.997 in Step 50
# Valid loss  0.998 in Step 60
# Valid loss  0.998 in Step 70
# Valid loss  0.998 in Step 80
# Valid loss  0.998 in Step 90
# Valid loss  0.999 in Step 100
# Valid loss  0.997 in Step 110
# Valid loss  0.998 in Step 120
# Valid loss  0.997 in Step 130
# Valid loss  0.998 in Step 140
# Valid loss  0.997 in Step 150
# Valid loss  0.998 in Step 160
# Valid loss  0.998 in Step 170
# Valid loss  0.998 in Step 180
# Valid loss  0.998 in Step 190
# Valid loss  0.998 in Step 200
# Valid loss  0.998 in Step 210
# Valid loss  0.997 in Step 220
# Valid loss  0.998 in Step 230
# Valid loss  0.998 in Step 240
# Valid loss  0.998 in Step 250
# Valid loss  0.997 in Step 260
# Valid loss  0.998 in Step 270
# Valid loss  0.998 in Step 280
# Valid loss  0.998 in Step 290
# Valid loss  0.998 in Step 300
# Valid loss  0.998 in Step 310
# Valid loss  0.998 in Step 320
# Valid loss  0.998 in Step 330
# Valid loss  0.997 in Step 340
# Valid loss  0.998 in Step 350
# Valid loss  0.998 in Step 360
# Valid loss  0.999 in Step 370
# Valid loss  0.998 in Step 380
# Valid loss  0.998 in Step 390
# Valid loss  0.998 in Step 400
# Valid loss  0.998 in Step 410
# Valid loss  0.998 in Step 420
# Valid loss  0.998 in Step 430
# Valid loss  0.997 in Step 440
# ※※※Valid loss  0.998※※※
# Epoch 5
# Training loss  0.991 in Step 0
# Training loss  0.990 in Step 100
# Training loss  0.989 in Step 200
# Training loss  0.989 in Step 300
# Training loss  0.991 in Step 400
# Training loss  0.991 in Step 500
# Training loss  0.992 in Step 600
# Training loss  0.989 in Step 700
# Training loss  0.992 in Step 800
# Training loss  0.992 in Step 900
# Training loss  0.990 in Step 1000
# Training loss  0.992 in Step 1100
# Training loss  0.992 in Step 1200
# Training loss  0.990 in Step 1300
# Training loss  0.989 in Step 1400
# Training loss  0.990 in Step 1500
# Training loss  0.991 in Step 1600
# Training loss  0.990 in Step 1700
# ※※※Training loss  0.991※※※
# Training timepoint saved
# Valid loss  0.997 in Step 0
# Valid loss  0.998 in Step 10
# Valid loss  0.996 in Step 20
# Valid loss  0.997 in Step 30
# Valid loss  0.998 in Step 40
# Valid loss  0.996 in Step 50
# Valid loss  0.998 in Step 60
# Valid loss  0.998 in Step 70
# Valid loss  0.998 in Step 80
# Valid loss  0.998 in Step 90
# Valid loss  0.999 in Step 100
# Valid loss  0.998 in Step 110
# Valid loss  0.997 in Step 120
# Valid loss  0.996 in Step 130
# Valid loss  0.997 in Step 140
# Valid loss  0.997 in Step 150
# Valid loss  0.998 in Step 160
# Valid loss  0.998 in Step 170
# Valid loss  0.997 in Step 180
# Valid loss  0.997 in Step 190
# Valid loss  0.997 in Step 200
# Valid loss  0.998 in Step 210
# Valid loss  0.997 in Step 220
# Valid loss  0.997 in Step 230
# Valid loss  0.998 in Step 240
# Valid loss  0.998 in Step 250
# Valid loss  0.997 in Step 260
# Valid loss  0.997 in Step 270
# Valid loss  0.998 in Step 280
# Valid loss  0.998 in Step 290
# Valid loss  0.998 in Step 300
# Valid loss  0.998 in Step 310
# Valid loss  0.998 in Step 320
# Valid loss  0.998 in Step 330
# Valid loss  0.997 in Step 340
# Valid loss  0.997 in Step 350
# Valid loss  0.998 in Step 360
# Valid loss  0.998 in Step 370
# Valid loss  0.998 in Step 380
# Valid loss  0.998 in Step 390
# Valid loss  0.998 in Step 400
# Valid loss  0.998 in Step 410
# Valid loss  0.998 in Step 420
# Valid loss  0.998 in Step 430
# Valid loss  0.997 in Step 440
# ※※※Valid loss  0.998※※※
# Epoch 6
# Training loss  0.992 in Step 0
# Training loss  0.991 in Step 100
# Training loss  0.991 in Step 200
# Training loss  0.991 in Step 300
# Training loss  0.990 in Step 400
# Training loss  0.990 in Step 500
# Training loss  0.992 in Step 600
# Training loss  0.990 in Step 700
# Training loss  0.990 in Step 800
# Training loss  0.991 in Step 900
# Training loss  0.991 in Step 1000
# Training loss  0.990 in Step 1100
# Training loss  0.991 in Step 1200
# Training loss  0.990 in Step 1300
# Training loss  0.991 in Step 1400
# Training loss  0.990 in Step 1500
# Training loss  0.989 in Step 1600
# Training loss  0.990 in Step 1700
# ※※※Training loss  0.990※※※
# Training timepoint saved
# Valid loss  0.997 in Step 0
# Valid loss  0.997 in Step 10
# Valid loss  0.995 in Step 20
# Valid loss  0.997 in Step 30
# Valid loss  0.997 in Step 40
# Valid loss  0.996 in Step 50
# Valid loss  0.997 in Step 60
# Valid loss  0.997 in Step 70
# Valid loss  0.997 in Step 80
# Valid loss  0.998 in Step 90
# Valid loss  0.998 in Step 100
# Valid loss  0.997 in Step 110
# Valid loss  0.997 in Step 120
# Valid loss  0.996 in Step 130
# Valid loss  0.997 in Step 140
# Valid loss  0.996 in Step 150
# Valid loss  0.997 in Step 160
# Valid loss  0.998 in Step 170
# Valid loss  0.997 in Step 180
# Valid loss  0.997 in Step 190
# Valid loss  0.997 in Step 200
# Valid loss  0.997 in Step 210
# Valid loss  0.996 in Step 220
# Valid loss  0.997 in Step 230
# Valid loss  0.998 in Step 240
# Valid loss  0.997 in Step 250
# Valid loss  0.996 in Step 260
# Valid loss  0.997 in Step 270
# Valid loss  0.998 in Step 280
# Valid loss  0.997 in Step 290
# Valid loss  0.997 in Step 300
# Valid loss  0.997 in Step 310
# Valid loss  0.997 in Step 320
# Valid loss  0.997 in Step 330
# Valid loss  0.997 in Step 340
# Valid loss  0.997 in Step 350
# Valid loss  0.997 in Step 360
# Valid loss  0.998 in Step 370
# Valid loss  0.997 in Step 380
# Valid loss  0.998 in Step 390
# Valid loss  0.997 in Step 400
# Valid loss  0.997 in Step 410
# Valid loss  0.997 in Step 420
# Valid loss  0.997 in Step 430
# Valid loss  0.997 in Step 440
# ※※※Valid loss  0.997※※※
# Epoch 7
# Training loss  0.992 in Step 0
# Training loss  0.990 in Step 100
# Training loss  0.990 in Step 200
# Training loss  0.989 in Step 300
# Training loss  0.989 in Step 400
# Training loss  0.990 in Step 500
# Training loss  0.991 in Step 600
# Training loss  0.990 in Step 700
# Training loss  0.991 in Step 800
# Training loss  0.990 in Step 900
# Training loss  0.990 in Step 1000
# Training loss  0.991 in Step 1100
# Training loss  0.989 in Step 1200
# Training loss  0.992 in Step 1300
# Training loss  0.989 in Step 1400
# Training loss  0.992 in Step 1500
# Training loss  0.989 in Step 1600
# Training loss  0.990 in Step 1700
# ※※※Training loss  0.990※※※
# Training timepoint saved
# Valid loss  0.997 in Step 0
# Valid loss  0.997 in Step 10
# Valid loss  0.995 in Step 20
# Valid loss  0.997 in Step 30
# Valid loss  0.997 in Step 40
# Valid loss  0.996 in Step 50
# Valid loss  0.997 in Step 60
# Valid loss  0.997 in Step 70
# Valid loss  0.997 in Step 80
# Valid loss  0.997 in Step 90
# Valid loss  0.998 in Step 100
# Valid loss  0.997 in Step 110
# Valid loss  0.997 in Step 120
# Valid loss  0.996 in Step 130
# Valid loss  0.997 in Step 140
# Valid loss  0.996 in Step 150
# Valid loss  0.997 in Step 160
# Valid loss  0.997 in Step 170
# Valid loss  0.997 in Step 180
# Valid loss  0.997 in Step 190
# Valid loss  0.997 in Step 200
# Valid loss  0.997 in Step 210
# Valid loss  0.996 in Step 220
# Valid loss  0.996 in Step 230
# Valid loss  0.997 in Step 240
# Valid loss  0.997 in Step 250
# Valid loss  0.996 in Step 260
# Valid loss  0.997 in Step 270
# Valid loss  0.998 in Step 280
# Valid loss  0.997 in Step 290
# Valid loss  0.997 in Step 300
# Valid loss  0.996 in Step 310
# Valid loss  0.997 in Step 320
# Valid loss  0.997 in Step 330
# Valid loss  0.996 in Step 340
# Valid loss  0.997 in Step 350
# Valid loss  0.997 in Step 360
# Valid loss  0.997 in Step 370
# Valid loss  0.997 in Step 380
# Valid loss  0.997 in Step 390
# Valid loss  0.997 in Step 400
# Valid loss  0.997 in Step 410
# Valid loss  0.997 in Step 420
# Valid loss  0.997 in Step 430
# Valid loss  0.997 in Step 440
# ※※※Valid loss  0.997※※※
# Epoch 8
# Training loss  0.989 in Step 0
# Training loss  0.991 in Step 100
# Training loss  0.991 in Step 200
# Training loss  0.991 in Step 300
# Training loss  0.991 in Step 400
# Training loss  0.990 in Step 500
# Training loss  0.991 in Step 600
# Training loss  0.989 in Step 700
# Training loss  0.989 in Step 800
# Training loss  0.990 in Step 900
# Training loss  0.990 in Step 1000
# Training loss  0.990 in Step 1100
# Training loss  0.988 in Step 1200
# Training loss  0.989 in Step 1300
# Training loss  0.991 in Step 1400
# Training loss  0.987 in Step 1500
# Training loss  0.989 in Step 1600
# Training loss  0.989 in Step 1700
# ※※※Training loss  0.990※※※
# Training timepoint saved
# Valid loss  0.996 in Step 0
# Valid loss  0.996 in Step 10
# Valid loss  0.994 in Step 20
# Valid loss  0.996 in Step 30
# Valid loss  0.997 in Step 40
# Valid loss  0.995 in Step 50
# Valid loss  0.997 in Step 60
# Valid loss  0.996 in Step 70
# Valid loss  0.996 in Step 80
# Valid loss  0.997 in Step 90
# Valid loss  0.998 in Step 100
# Valid loss  0.996 in Step 110
# Valid loss  0.996 in Step 120
# Valid loss  0.995 in Step 130
# Valid loss  0.996 in Step 140
# Valid loss  0.995 in Step 150
# Valid loss  0.996 in Step 160
# Valid loss  0.997 in Step 170
# Valid loss  0.996 in Step 180
# Valid loss  0.996 in Step 190
# Valid loss  0.996 in Step 200
# Valid loss  0.996 in Step 210
# Valid loss  0.995 in Step 220
# Valid loss  0.996 in Step 230
# Valid loss  0.996 in Step 240
# Valid loss  0.996 in Step 250
# Valid loss  0.995 in Step 260
# Valid loss  0.996 in Step 270
# Valid loss  0.997 in Step 280
# Valid loss  0.997 in Step 290
# Valid loss  0.997 in Step 300
# Valid loss  0.996 in Step 310
# Valid loss  0.996 in Step 320
# Valid loss  0.996 in Step 330
# Valid loss  0.996 in Step 340
# Valid loss  0.996 in Step 350
# Valid loss  0.996 in Step 360
# Valid loss  0.997 in Step 370
# Valid loss  0.996 in Step 380
# Valid loss  0.997 in Step 390
# Valid loss  0.996 in Step 400
# Valid loss  0.996 in Step 410
# Valid loss  0.996 in Step 420
# Valid loss  0.996 in Step 430
# Valid loss  0.996 in Step 440
# ※※※Valid loss  0.996※※※
# Epoch 9
# Training loss  0.990 in Step 0
# Training loss  0.990 in Step 100
# Training loss  0.990 in Step 200
# Training loss  0.990 in Step 300
# Training loss  0.989 in Step 400
# Training loss  0.988 in Step 500
# Training loss  0.989 in Step 600
# Training loss  0.990 in Step 700
# Training loss  0.989 in Step 800
# Training loss  0.990 in Step 900
# Training loss  0.990 in Step 1000
# Training loss  0.988 in Step 1100
# Training loss  0.989 in Step 1200
# Training loss  0.990 in Step 1300
# Training loss  0.989 in Step 1400
# Training loss  0.987 in Step 1500
# Training loss  0.988 in Step 1600
# Training loss  0.986 in Step 1700
# ※※※Training loss  0.989※※※
# Training timepoint saved
# Valid loss  0.995 in Step 0
# Valid loss  0.995 in Step 10
# Valid loss  0.994 in Step 20
# Valid loss  0.995 in Step 30
# Valid loss  0.996 in Step 40
# Valid loss  0.995 in Step 50
# Valid loss  0.996 in Step 60
# Valid loss  0.996 in Step 70
# Valid loss  0.996 in Step 80
# Valid loss  0.996 in Step 90
# Valid loss  0.997 in Step 100
# Valid loss  0.995 in Step 110
# Valid loss  0.995 in Step 120
# Valid loss  0.994 in Step 130
# Valid loss  0.995 in Step 140
# Valid loss  0.994 in Step 150
# Valid loss  0.996 in Step 160
# Valid loss  0.996 in Step 170
# Valid loss  0.995 in Step 180
# Valid loss  0.995 in Step 190
# Valid loss  0.996 in Step 200
# Valid loss  0.996 in Step 210
# Valid loss  0.994 in Step 220
# Valid loss  0.995 in Step 230
# Valid loss  0.996 in Step 240
# Valid loss  0.995 in Step 250
# Valid loss  0.995 in Step 260
# Valid loss  0.995 in Step 270
# Valid loss  0.996 in Step 280
# Valid loss  0.996 in Step 290
# Valid loss  0.996 in Step 300
# Valid loss  0.995 in Step 310
# Valid loss  0.996 in Step 320
# Valid loss  0.995 in Step 330
# Valid loss  0.995 in Step 340
# Valid loss  0.995 in Step 350
# Valid loss  0.995 in Step 360
# Valid loss  0.996 in Step 370
# Valid loss  0.996 in Step 380
# Valid loss  0.996 in Step 390
# Valid loss  0.996 in Step 400
# Valid loss  0.995 in Step 410
# Valid loss  0.996 in Step 420
# Valid loss  0.996 in Step 430
# Valid loss  0.995 in Step 440
# ※※※Valid loss  0.995※※※
# Epoch 10
# Training loss  0.987 in Step 0
# Training loss  0.988 in Step 100
# Training loss  0.987 in Step 200
# Training loss  0.986 in Step 300
# Training loss  0.989 in Step 400
# Training loss  0.991 in Step 500
# Training loss  0.988 in Step 600
# Training loss  0.990 in Step 700
# Training loss  0.987 in Step 800
# Training loss  0.989 in Step 900
# Training loss  0.989 in Step 1000
# Training loss  0.989 in Step 1100
# Training loss  0.988 in Step 1200
# Training loss  0.988 in Step 1300
# Training loss  0.990 in Step 1400
# Training loss  0.988 in Step 1500
# Training loss  0.990 in Step 1600
# Training loss  0.991 in Step 1700
# ※※※Training loss  0.989※※※
# Training timepoint saved
# Valid loss  0.994 in Step 0
# Valid loss  0.994 in Step 10
# Valid loss  0.993 in Step 20
# Valid loss  0.994 in Step 30
# Valid loss  0.995 in Step 40
# Valid loss  0.994 in Step 50
# Valid loss  0.994 in Step 60
# Valid loss  0.994 in Step 70
# Valid loss  0.995 in Step 80
# Valid loss  0.995 in Step 90
# Valid loss  0.996 in Step 100
# Valid loss  0.994 in Step 110
# Valid loss  0.994 in Step 120
# Valid loss  0.993 in Step 130
# Valid loss  0.994 in Step 140
# Valid loss  0.993 in Step 150
# Valid loss  0.995 in Step 160
# Valid loss  0.995 in Step 170
# Valid loss  0.994 in Step 180
# Valid loss  0.994 in Step 190
# Valid loss  0.995 in Step 200
# Valid loss  0.994 in Step 210
# Valid loss  0.993 in Step 220
# Valid loss  0.994 in Step 230
# Valid loss  0.995 in Step 240
# Valid loss  0.995 in Step 250
# Valid loss  0.994 in Step 260
# Valid loss  0.994 in Step 270
# Valid loss  0.995 in Step 280
# Valid loss  0.994 in Step 290
# Valid loss  0.995 in Step 300
# Valid loss  0.994 in Step 310
# Valid loss  0.995 in Step 320
# Valid loss  0.994 in Step 330
# Valid loss  0.994 in Step 340
# Valid loss  0.994 in Step 350
# Valid loss  0.995 in Step 360
# Valid loss  0.995 in Step 370
# Valid loss  0.994 in Step 380
# Valid loss  0.995 in Step 390
# Valid loss  0.994 in Step 400
# Valid loss  0.995 in Step 410
# Valid loss  0.995 in Step 420
# Valid loss  0.994 in Step 430
# Valid loss  0.994 in Step 440
# ※※※Valid loss  0.994※※※
# Epoch 11
# Training loss  0.988 in Step 0
# Training loss  0.988 in Step 100
# Training loss  0.989 in Step 200
# Training loss  0.989 in Step 300
# Training loss  0.989 in Step 400
# Training loss  0.987 in Step 500
# Training loss  0.988 in Step 600
# Training loss  0.989 in Step 700
# Training loss  0.986 in Step 800
# Training loss  0.987 in Step 900
# Training loss  0.986 in Step 1000
# Training loss  0.989 in Step 1100
# Training loss  0.987 in Step 1200
# Training loss  0.987 in Step 1300
# Training loss  0.989 in Step 1400
# Training loss  0.988 in Step 1500
# Training loss  0.988 in Step 1600
# Training loss  0.985 in Step 1700
# ※※※Training loss  0.988※※※
# Training timepoint saved
# Valid loss  0.994 in Step 0
# Valid loss  0.993 in Step 10
# Valid loss  0.992 in Step 20
# Valid loss  0.993 in Step 30
# Valid loss  0.994 in Step 40
# Valid loss  0.993 in Step 50
# Valid loss  0.994 in Step 60
# Valid loss  0.994 in Step 70
# Valid loss  0.994 in Step 80
# Valid loss  0.995 in Step 90
# Valid loss  0.995 in Step 100
# Valid loss  0.994 in Step 110
# Valid loss  0.993 in Step 120
# Valid loss  0.993 in Step 130
# Valid loss  0.993 in Step 140
# Valid loss  0.993 in Step 150
# Valid loss  0.994 in Step 160
# Valid loss  0.994 in Step 170
# Valid loss  0.994 in Step 180
# Valid loss  0.994 in Step 190
# Valid loss  0.994 in Step 200
# Valid loss  0.994 in Step 210
# Valid loss  0.992 in Step 220
# Valid loss  0.993 in Step 230
# Valid loss  0.994 in Step 240
# Valid loss  0.994 in Step 250
# Valid loss  0.994 in Step 260
# Valid loss  0.993 in Step 270
# Valid loss  0.994 in Step 280
# Valid loss  0.994 in Step 290
# Valid loss  0.994 in Step 300
# Valid loss  0.993 in Step 310
# Valid loss  0.994 in Step 320
# Valid loss  0.993 in Step 330
# Valid loss  0.993 in Step 340
# Valid loss  0.993 in Step 350
# Valid loss  0.994 in Step 360
# Valid loss  0.994 in Step 370
# Valid loss  0.994 in Step 380
# Valid loss  0.994 in Step 390
# Valid loss  0.994 in Step 400
# Valid loss  0.994 in Step 410
# Valid loss  0.994 in Step 420
# Valid loss  0.994 in Step 430
# Valid loss  0.993 in Step 440
# ※※※Valid loss  0.994※※※
# Epoch 12
# Training loss  0.987 in Step 0
# Training loss  0.988 in Step 100
# Training loss  0.986 in Step 200
# Training loss  0.990 in Step 300
# Training loss  0.987 in Step 400
# Training loss  0.986 in Step 500
# Training loss  0.987 in Step 600
# Training loss  0.989 in Step 700
# Training loss  0.987 in Step 800
# Training loss  0.988 in Step 900
# Training loss  0.989 in Step 1000
# Training loss  0.988 in Step 1100
# Training loss  0.986 in Step 1200
# Training loss  0.987 in Step 1300
# Training loss  0.989 in Step 1400
# Training loss  0.987 in Step 1500
# Training loss  0.989 in Step 1600
# Training loss  0.987 in Step 1700
# ※※※Training loss  0.987※※※
# Training timepoint saved
# Valid loss  0.994 in Step 0
# Valid loss  0.994 in Step 10
# Valid loss  0.992 in Step 20
# Valid loss  0.993 in Step 30
# Valid loss  0.994 in Step 40
# Valid loss  0.993 in Step 50
# Valid loss  0.994 in Step 60
# Valid loss  0.994 in Step 70
# Valid loss  0.994 in Step 80
# Valid loss  0.994 in Step 90
# Valid loss  0.995 in Step 100
# Valid loss  0.994 in Step 110
# Valid loss  0.993 in Step 120
# Valid loss  0.992 in Step 130
# Valid loss  0.994 in Step 140
# Valid loss  0.993 in Step 150
# Valid loss  0.994 in Step 160
# Valid loss  0.995 in Step 170
# Valid loss  0.994 in Step 180
# Valid loss  0.994 in Step 190
# Valid loss  0.995 in Step 200
# Valid loss  0.993 in Step 210
# Valid loss  0.993 in Step 220
# Valid loss  0.993 in Step 230
# Valid loss  0.994 in Step 240
# Valid loss  0.994 in Step 250
# Valid loss  0.994 in Step 260
# Valid loss  0.993 in Step 270
# Valid loss  0.994 in Step 280
# Valid loss  0.994 in Step 290
# Valid loss  0.995 in Step 300
# Valid loss  0.993 in Step 310
# Valid loss  0.995 in Step 320
# Valid loss  0.993 in Step 330
# Valid loss  0.993 in Step 340
# Valid loss  0.994 in Step 350
# Valid loss  0.994 in Step 360
# Valid loss  0.994 in Step 370
# Valid loss  0.993 in Step 380
# Valid loss  0.994 in Step 390
# Valid loss  0.993 in Step 400
# Valid loss  0.994 in Step 410
# Valid loss  0.995 in Step 420
# Valid loss  0.994 in Step 430
# Valid loss  0.993 in Step 440
# ※※※Valid loss  0.994※※※
# Epoch 13
# Training loss  0.987 in Step 0
# Training loss  0.987 in Step 100
# Training loss  0.985 in Step 200
# Training loss  0.989 in Step 300
# Training loss  0.985 in Step 400
# Training loss  0.987 in Step 500
# Training loss  0.987 in Step 600
# Training loss  0.986 in Step 700
# Training loss  0.985 in Step 800
# Training loss  0.987 in Step 900
# Training loss  0.987 in Step 1000
# Training loss  0.985 in Step 1100
# Training loss  0.987 in Step 1200
# Training loss  0.984 in Step 1300
# Training loss  0.989 in Step 1400
# Training loss  0.987 in Step 1500
# Training loss  0.987 in Step 1600
# Training loss  0.984 in Step 1700
# ※※※Training loss  0.987※※※
# Training timepoint saved
# Valid loss  0.993 in Step 0
# Valid loss  0.993 in Step 10
# Valid loss  0.992 in Step 20
# Valid loss  0.992 in Step 30
# Valid loss  0.993 in Step 40
# Valid loss  0.992 in Step 50
# Valid loss  0.994 in Step 60
# Valid loss  0.993 in Step 70
# Valid loss  0.994 in Step 80
# Valid loss  0.994 in Step 90
# Valid loss  0.995 in Step 100
# Valid loss  0.993 in Step 110
# Valid loss  0.993 in Step 120
# Valid loss  0.992 in Step 130
# Valid loss  0.993 in Step 140
# Valid loss  0.992 in Step 150
# Valid loss  0.994 in Step 160
# Valid loss  0.994 in Step 170
# Valid loss  0.993 in Step 180
# Valid loss  0.993 in Step 190
# Valid loss  0.994 in Step 200
# Valid loss  0.993 in Step 210
# Valid loss  0.993 in Step 220
# Valid loss  0.992 in Step 230
# Valid loss  0.993 in Step 240
# Valid loss  0.994 in Step 250
# Valid loss  0.994 in Step 260
# Valid loss  0.992 in Step 270
# Valid loss  0.994 in Step 280
# Valid loss  0.994 in Step 290
# Valid loss  0.994 in Step 300
# Valid loss  0.993 in Step 310
# Valid loss  0.994 in Step 320
# Valid loss  0.992 in Step 330
# Valid loss  0.993 in Step 340
# Valid loss  0.993 in Step 350
# Valid loss  0.994 in Step 360
# Valid loss  0.993 in Step 370
# Valid loss  0.993 in Step 380
# Valid loss  0.994 in Step 390
# Valid loss  0.993 in Step 400
# Valid loss  0.993 in Step 410
# Valid loss  0.994 in Step 420
# Valid loss  0.994 in Step 430
# Valid loss  0.992 in Step 440
# ※※※Valid loss  0.993※※※
# Epoch 14
# Training loss  0.986 in Step 0
# Training loss  0.988 in Step 100
# Training loss  0.985 in Step 200
# Training loss  0.987 in Step 300
# Training loss  0.987 in Step 400
# Training loss  0.986 in Step 500
# Training loss  0.987 in Step 600
# Training loss  0.986 in Step 700
# Training loss  0.984 in Step 800
# Training loss  0.986 in Step 900
# Training loss  0.986 in Step 1000
# Training loss  0.986 in Step 1100
# Training loss  0.988 in Step 1200
# Training loss  0.985 in Step 1300
# Training loss  0.985 in Step 1400
# Training loss  0.987 in Step 1500
# Training loss  0.985 in Step 1600
# Training loss  0.988 in Step 1700
# ※※※Training loss  0.986※※※
# Training timepoint saved
# Valid loss  0.994 in Step 0
# Valid loss  0.993 in Step 10
# Valid loss  0.991 in Step 20
# Valid loss  0.992 in Step 30
# Valid loss  0.993 in Step 40
# Valid loss  0.992 in Step 50
# Valid loss  0.993 in Step 60
# Valid loss  0.994 in Step 70
# Valid loss  0.994 in Step 80
# Valid loss  0.994 in Step 90
# Valid loss  0.995 in Step 100
# Valid loss  0.993 in Step 110
# Valid loss  0.993 in Step 120
# Valid loss  0.992 in Step 130
# Valid loss  0.993 in Step 140
# Valid loss  0.992 in Step 150
# Valid loss  0.994 in Step 160
# Valid loss  0.994 in Step 170
# Valid loss  0.993 in Step 180
# Valid loss  0.993 in Step 190
# Valid loss  0.994 in Step 200
# Valid loss  0.993 in Step 210
# Valid loss  0.993 in Step 220
# Valid loss  0.992 in Step 230
# Valid loss  0.993 in Step 240
# Valid loss  0.994 in Step 250
# Valid loss  0.994 in Step 260
# Valid loss  0.992 in Step 270
# Valid loss  0.994 in Step 280
# Valid loss  0.993 in Step 290
# Valid loss  0.994 in Step 300
# Valid loss  0.993 in Step 310
# Valid loss  0.994 in Step 320
# Valid loss  0.992 in Step 330
# Valid loss  0.992 in Step 340
# Valid loss  0.993 in Step 350
# Valid loss  0.994 in Step 360
# Valid loss  0.994 in Step 370
# Valid loss  0.993 in Step 380
# Valid loss  0.994 in Step 390
# Valid loss  0.993 in Step 400
# Valid loss  0.994 in Step 410
# Valid loss  0.994 in Step 420
# Valid loss  0.994 in Step 430
# Valid loss  0.992 in Step 440
# ※※※Valid loss  0.993※※※
# Epoch 15
# Training loss  0.986 in Step 0
# Training loss  0.983 in Step 100
# Training loss  0.989 in Step 200
# Training loss  0.988 in Step 300
# Training loss  0.987 in Step 400
# Training loss  0.984 in Step 500
# Training loss  0.987 in Step 600
# Training loss  0.986 in Step 700
# Training loss  0.984 in Step 800
# Training loss  0.984 in Step 900
# Training loss  0.988 in Step 1000
# Training loss  0.988 in Step 1100
# Training loss  0.986 in Step 1200
# Training loss  0.984 in Step 1300
# Training loss  0.986 in Step 1400
# Training loss  0.986 in Step 1500
# Training loss  0.984 in Step 1600
# Training loss  0.983 in Step 1700
# ※※※Training loss  0.986※※※
# Training timepoint saved
# Valid loss  0.994 in Step 0
# Valid loss  0.994 in Step 10
# Valid loss  0.991 in Step 20
# Valid loss  0.993 in Step 30
# Valid loss  0.993 in Step 40
# Valid loss  0.992 in Step 50
# Valid loss  0.994 in Step 60
# Valid loss  0.994 in Step 70
# Valid loss  0.994 in Step 80
# Valid loss  0.994 in Step 90
# Valid loss  0.995 in Step 100
# Valid loss  0.993 in Step 110
# Valid loss  0.993 in Step 120
# Valid loss  0.991 in Step 130
# Valid loss  0.993 in Step 140
# Valid loss  0.992 in Step 150
# Valid loss  0.994 in Step 160
# Valid loss  0.994 in Step 170
# Valid loss  0.993 in Step 180
# Valid loss  0.993 in Step 190
# Valid loss  0.994 in Step 200
# Valid loss  0.993 in Step 210
# Valid loss  0.993 in Step 220
# Valid loss  0.993 in Step 230
# Valid loss  0.993 in Step 240
# Valid loss  0.994 in Step 250
# Valid loss  0.994 in Step 260
# Valid loss  0.993 in Step 270
# Valid loss  0.994 in Step 280
# Valid loss  0.994 in Step 290
# Valid loss  0.994 in Step 300
# Valid loss  0.993 in Step 310
# Valid loss  0.994 in Step 320
# Valid loss  0.992 in Step 330
# Valid loss  0.992 in Step 340
# Valid loss  0.993 in Step 350
# Valid loss  0.994 in Step 360
# Valid loss  0.993 in Step 370
# Valid loss  0.993 in Step 380
# Valid loss  0.994 in Step 390
# Valid loss  0.993 in Step 400
# Valid loss  0.994 in Step 410
# Valid loss  0.995 in Step 420
# Valid loss  0.994 in Step 430
# Valid loss  0.993 in Step 440
# ※※※Valid loss  0.993※※※
# Epoch 16
# Training loss  0.987 in Step 0
# Training loss  0.983 in Step 100
# Training loss  0.986 in Step 200
# Training loss  0.985 in Step 300
# Training loss  0.986 in Step 400
# Training loss  0.985 in Step 500
# Training loss  0.985 in Step 600
# Training loss  0.987 in Step 700
# Training loss  0.987 in Step 800
# Training loss  0.985 in Step 900
# Training loss  0.984 in Step 1000
# Training loss  0.986 in Step 1100
# Training loss  0.986 in Step 1200
# Training loss  0.987 in Step 1300
# Training loss  0.985 in Step 1400
# Training loss  0.986 in Step 1500
# Training loss  0.985 in Step 1600
# Training loss  0.986 in Step 1700
# ※※※Training loss  0.986※※※
# Training timepoint saved
# Valid loss  0.994 in Step 0
# Valid loss  0.994 in Step 10
# Valid loss  0.992 in Step 20
# Valid loss  0.993 in Step 30
# Valid loss  0.993 in Step 40
# Valid loss  0.992 in Step 50
# Valid loss  0.994 in Step 60
# Valid loss  0.994 in Step 70
# Valid loss  0.994 in Step 80
# Valid loss  0.994 in Step 90
# Valid loss  0.995 in Step 100
# Valid loss  0.994 in Step 110
# Valid loss  0.993 in Step 120
# Valid loss  0.992 in Step 130
# Valid loss  0.993 in Step 140
# Valid loss  0.992 in Step 150
# Valid loss  0.994 in Step 160
# Valid loss  0.995 in Step 170
# Valid loss  0.993 in Step 180
# Valid loss  0.993 in Step 190
# Valid loss  0.994 in Step 200
# Valid loss  0.993 in Step 210
# Valid loss  0.993 in Step 220
# Valid loss  0.993 in Step 230
# Valid loss  0.994 in Step 240
# Valid loss  0.994 in Step 250
# Valid loss  0.994 in Step 260
# Valid loss  0.993 in Step 270
# Valid loss  0.994 in Step 280
# Valid loss  0.994 in Step 290
# Valid loss  0.995 in Step 300
# Valid loss  0.993 in Step 310
# Valid loss  0.994 in Step 320
# Valid loss  0.993 in Step 330
# Valid loss  0.992 in Step 340
# Valid loss  0.993 in Step 350
# Valid loss  0.994 in Step 360
# Valid loss  0.994 in Step 370
# Valid loss  0.993 in Step 380
# Valid loss  0.994 in Step 390
# Valid loss  0.993 in Step 400
# Valid loss  0.994 in Step 410
# Valid loss  0.995 in Step 420
# Valid loss  0.994 in Step 430
# Valid loss  0.993 in Step 440
# ※※※Valid loss  0.994※※※
# Epoch 17
# Training loss  0.985 in Step 0
# Training loss  0.986 in Step 100
# Training loss  0.986 in Step 200
# Training loss  0.985 in Step 300
# Training loss  0.986 in Step 400
# Training loss  0.987 in Step 500
# Training loss  0.986 in Step 600
# Training loss  0.987 in Step 700
# Training loss  0.985 in Step 800
# Training loss  0.985 in Step 900
# Training loss  0.987 in Step 1000
# Training loss  0.984 in Step 1100
# Training loss  0.984 in Step 1200
# Training loss  0.986 in Step 1300
# Training loss  0.983 in Step 1400
# Training loss  0.986 in Step 1500
# Training loss  0.985 in Step 1600
# Training loss  0.988 in Step 1700
# ※※※Training loss  0.985※※※
# Training timepoint saved
# Valid loss  0.993 in Step 0
# Valid loss  0.994 in Step 10
# Valid loss  0.991 in Step 20
# Valid loss  0.993 in Step 30
# Valid loss  0.994 in Step 40
# Valid loss  0.992 in Step 50
# Valid loss  0.994 in Step 60
# Valid loss  0.993 in Step 70
# Valid loss  0.993 in Step 80
# Valid loss  0.994 in Step 90
# Valid loss  0.995 in Step 100
# Valid loss  0.994 in Step 110
# Valid loss  0.993 in Step 120
# Valid loss  0.991 in Step 130
# Valid loss  0.993 in Step 140
# Valid loss  0.992 in Step 150
# Valid loss  0.994 in Step 160
# Valid loss  0.994 in Step 170
# Valid loss  0.993 in Step 180
# Valid loss  0.993 in Step 190
# Valid loss  0.994 in Step 200
# Valid loss  0.993 in Step 210
# Valid loss  0.992 in Step 220
# Valid loss  0.992 in Step 230
# Valid loss  0.993 in Step 240
# Valid loss  0.993 in Step 250
# Valid loss  0.993 in Step 260
# Valid loss  0.993 in Step 270
# Valid loss  0.994 in Step 280
# Valid loss  0.993 in Step 290
# Valid loss  0.994 in Step 300
# Valid loss  0.993 in Step 310
# Valid loss  0.994 in Step 320
# Valid loss  0.992 in Step 330
# Valid loss  0.993 in Step 340
# Valid loss  0.993 in Step 350
# Valid loss  0.994 in Step 360
# Valid loss  0.994 in Step 370
# Valid loss  0.992 in Step 380
# Valid loss  0.994 in Step 390
# Valid loss  0.993 in Step 400
# Valid loss  0.993 in Step 410
# Valid loss  0.994 in Step 420
# Valid loss  0.994 in Step 430
# Valid loss  0.993 in Step 440
# ※※※Valid loss  0.993※※※
# Epoch 18
# Training loss  0.985 in Step 0
# Training loss  0.989 in Step 100
# Training loss  0.985 in Step 200
# Training loss  0.987 in Step 300
# Training loss  0.985 in Step 400
# Training loss  0.984 in Step 500
# Training loss  0.985 in Step 600
# Training loss  0.986 in Step 700
# Training loss  0.985 in Step 800
# Training loss  0.985 in Step 900
# Training loss  0.985 in Step 1000
# Training loss  0.985 in Step 1100
# Training loss  0.986 in Step 1200
# Training loss  0.986 in Step 1300
# Training loss  0.987 in Step 1400
# Training loss  0.985 in Step 1500
# Training loss  0.985 in Step 1600
# Training loss  0.985 in Step 1700
# ※※※Training loss  0.985※※※
# Training timepoint saved
# Valid loss  0.994 in Step 0
# Valid loss  0.994 in Step 10
# Valid loss  0.991 in Step 20
# Valid loss  0.993 in Step 30
# Valid loss  0.994 in Step 40
# Valid loss  0.992 in Step 50
# Valid loss  0.994 in Step 60
# Valid loss  0.994 in Step 70
# Valid loss  0.994 in Step 80
# Valid loss  0.994 in Step 90
# Valid loss  0.995 in Step 100
# Valid loss  0.994 in Step 110
# Valid loss  0.993 in Step 120
# Valid loss  0.992 in Step 130
# Valid loss  0.993 in Step 140
# Valid loss  0.992 in Step 150
# Valid loss  0.994 in Step 160
# Valid loss  0.995 in Step 170
# Valid loss  0.993 in Step 180
# Valid loss  0.993 in Step 190
# Valid loss  0.994 in Step 200
# Valid loss  0.993 in Step 210
# Valid loss  0.993 in Step 220
# Valid loss  0.992 in Step 230
# Valid loss  0.994 in Step 240
# Valid loss  0.994 in Step 250
# Valid loss  0.994 in Step 260
# Valid loss  0.992 in Step 270
# Valid loss  0.994 in Step 280
# Valid loss  0.994 in Step 290
# Valid loss  0.994 in Step 300
# Valid loss  0.993 in Step 310
# Valid loss  0.994 in Step 320
# Valid loss  0.992 in Step 330
# Valid loss  0.993 in Step 340
# Valid loss  0.993 in Step 350
# Valid loss  0.994 in Step 360
# Valid loss  0.994 in Step 370
# Valid loss  0.993 in Step 380
# Valid loss  0.994 in Step 390
# Valid loss  0.993 in Step 400
# Valid loss  0.994 in Step 410
# Valid loss  0.995 in Step 420
# Valid loss  0.994 in Step 430
# Valid loss  0.993 in Step 440
# ※※※Valid loss  0.994※※※
# Epoch 19
# Training loss  0.983 in Step 0
# Training loss  0.986 in Step 100
# Training loss  0.985 in Step 200
# Training loss  0.985 in Step 300
# Training loss  0.984 in Step 400
# Training loss  0.985 in Step 500
# Training loss  0.985 in Step 600
# Training loss  0.985 in Step 700
# Training loss  0.982 in Step 800
# Training loss  0.986 in Step 900
# Training loss  0.986 in Step 1000
# Training loss  0.985 in Step 1100
# Training loss  0.986 in Step 1200
# Training loss  0.983 in Step 1300
# Training loss  0.984 in Step 1400
# Training loss  0.985 in Step 1500
# Training loss  0.982 in Step 1600
# Training loss  0.984 in Step 1700
# ※※※Training loss  0.985※※※
# Training timepoint saved
# Valid loss  0.995 in Step 0
# Valid loss  0.994 in Step 10
# Valid loss  0.992 in Step 20
# Valid loss  0.993 in Step 30
# Valid loss  0.994 in Step 40
# Valid loss  0.993 in Step 50
# Valid loss  0.994 in Step 60
# Valid loss  0.994 in Step 70
# Valid loss  0.994 in Step 80
# Valid loss  0.994 in Step 90
# Valid loss  0.996 in Step 100
# Valid loss  0.994 in Step 110
# Valid loss  0.994 in Step 120
# Valid loss  0.992 in Step 130
# Valid loss  0.994 in Step 140
# Valid loss  0.992 in Step 150
# Valid loss  0.995 in Step 160
# Valid loss  0.995 in Step 170
# Valid loss  0.994 in Step 180
# Valid loss  0.994 in Step 190
# Valid loss  0.995 in Step 200
# Valid loss  0.994 in Step 210
# Valid loss  0.993 in Step 220
# Valid loss  0.992 in Step 230
# Valid loss  0.994 in Step 240
# Valid loss  0.995 in Step 250
# Valid loss  0.994 in Step 260
# Valid loss  0.992 in Step 270
# Valid loss  0.995 in Step 280
# Valid loss  0.994 in Step 290
# Valid loss  0.995 in Step 300
# Valid loss  0.994 in Step 310
# Valid loss  0.995 in Step 320
# Valid loss  0.993 in Step 330
# Valid loss  0.994 in Step 340
# Valid loss  0.993 in Step 350
# Valid loss  0.995 in Step 360
# Valid loss  0.995 in Step 370
# Valid loss  0.993 in Step 380
# Valid loss  0.995 in Step 390
# Valid loss  0.993 in Step 400
# Valid loss  0.994 in Step 410
# Valid loss  0.995 in Step 420
# Valid loss  0.994 in Step 430
# Valid loss  0.993 in Step 440
# ※※※Valid loss  0.994※※※
# Epoch 20
# Training loss  0.985 in Step 0
# Training loss  0.984 in Step 100
# Training loss  0.983 in Step 200
# Training loss  0.984 in Step 300
# Training loss  0.985 in Step 400
# Training loss  0.986 in Step 500
# Training loss  0.986 in Step 600
# Training loss  0.984 in Step 700
# Training loss  0.986 in Step 800
# Training loss  0.983 in Step 900
# Training loss  0.993 in Step 1000
# Training loss  0.990 in Step 1100
# Training loss  0.985 in Step 1200
# Training loss  0.984 in Step 1300
# Training loss  0.987 in Step 1400
# Training loss  0.984 in Step 1500
# Training loss  0.986 in Step 1600
# Training loss  0.986 in Step 1700
# ※※※Training loss  0.986※※※
# Training timepoint saved
# Valid loss  0.995 in Step 0
# Valid loss  0.994 in Step 10
# Valid loss  0.992 in Step 20
# Valid loss  0.993 in Step 30
# Valid loss  0.995 in Step 40
# Valid loss  0.993 in Step 50
# Valid loss  0.995 in Step 60
# Valid loss  0.995 in Step 70
# Valid loss  0.994 in Step 80
# Valid loss  0.995 in Step 90
# Valid loss  0.996 in Step 100
# Valid loss  0.994 in Step 110
# Valid loss  0.994 in Step 120
# Valid loss  0.992 in Step 130
# Valid loss  0.994 in Step 140
# Valid loss  0.992 in Step 150
# Valid loss  0.995 in Step 160
# Valid loss  0.996 in Step 170
# Valid loss  0.994 in Step 180
# Valid loss  0.994 in Step 190
# Valid loss  0.994 in Step 200
# Valid loss  0.993 in Step 210
# Valid loss  0.993 in Step 220
# Valid loss  0.992 in Step 230
# Valid loss  0.994 in Step 240
# Valid loss  0.995 in Step 250
# Valid loss  0.994 in Step 260
# Valid loss  0.992 in Step 270
# Valid loss  0.995 in Step 280
# Valid loss  0.995 in Step 290
# Valid loss  0.995 in Step 300
# Valid loss  0.994 in Step 310
# Valid loss  0.995 in Step 320
# Valid loss  0.993 in Step 330
# Valid loss  0.994 in Step 340
# Valid loss  0.993 in Step 350
# Valid loss  0.995 in Step 360
# Valid loss  0.995 in Step 370
# Valid loss  0.994 in Step 380
# Valid loss  0.995 in Step 390
# Valid loss  0.994 in Step 400
# Valid loss  0.994 in Step 410
# Valid loss  0.995 in Step 420
# Valid loss  0.994 in Step 430
# Valid loss  0.993 in Step 440
# ※※※Valid loss  0.994※※※
# Epoch 21
# Training loss  0.985 in Step 0
# Training loss  0.985 in Step 100
# Training loss  0.983 in Step 200
# Training loss  0.986 in Step 300
# Training loss  0.984 in Step 400
# Training loss  0.985 in Step 500
# Training loss  0.985 in Step 600
# Training loss  0.984 in Step 700
# Training loss  0.985 in Step 800
# Training loss  0.986 in Step 900
# Training loss  0.985 in Step 1000
# Training loss  0.985 in Step 1100
# Training loss  0.987 in Step 1200
# Training loss  0.988 in Step 1300
# Training loss  0.986 in Step 1400
# Training loss  0.985 in Step 1500
# Training loss  0.986 in Step 1600
# Training loss  0.984 in Step 1700
# ※※※Training loss  0.985※※※
# Training timepoint saved
# Valid loss  0.994 in Step 0
# Valid loss  0.994 in Step 10
# Valid loss  0.991 in Step 20
# Valid loss  0.993 in Step 30
# Valid loss  0.994 in Step 40
# Valid loss  0.992 in Step 50
# Valid loss  0.994 in Step 60
# Valid loss  0.994 in Step 70
# Valid loss  0.994 in Step 80
# Valid loss  0.995 in Step 90
# Valid loss  0.996 in Step 100
# Valid loss  0.994 in Step 110
# Valid loss  0.993 in Step 120
# Valid loss  0.992 in Step 130
# Valid loss  0.994 in Step 140
# Valid loss  0.992 in Step 150
# Valid loss  0.995 in Step 160
# Valid loss  0.995 in Step 170
# Valid loss  0.993 in Step 180
# Valid loss  0.994 in Step 190
# Valid loss  0.994 in Step 200
# Valid loss  0.993 in Step 210
# Valid loss  0.993 in Step 220
# Valid loss  0.992 in Step 230
# Valid loss  0.994 in Step 240
# Valid loss  0.994 in Step 250
# Valid loss  0.994 in Step 260
# Valid loss  0.992 in Step 270
# Valid loss  0.995 in Step 280
# Valid loss  0.994 in Step 290
# Valid loss  0.995 in Step 300
# Valid loss  0.994 in Step 310
# Valid loss  0.995 in Step 320
# Valid loss  0.992 in Step 330
# Valid loss  0.993 in Step 340
# Valid loss  0.993 in Step 350
# Valid loss  0.994 in Step 360
# Valid loss  0.994 in Step 370
# Valid loss  0.993 in Step 380
# Valid loss  0.995 in Step 390
# Valid loss  0.993 in Step 400
# Valid loss  0.994 in Step 410
# Valid loss  0.994 in Step 420
# Valid loss  0.994 in Step 430
# Valid loss  0.993 in Step 440
# ※※※Valid loss  0.994※※※
# Epoch 22
# Training loss  0.986 in Step 0
# Training loss  0.985 in Step 100
# Training loss  0.986 in Step 200
# Training loss  0.983 in Step 300
# Training loss  0.985 in Step 400
# Training loss  0.985 in Step 500
# Training loss  0.984 in Step 600
# Training loss  0.985 in Step 700
# Training loss  0.987 in Step 800
# Training loss  0.983 in Step 900
# Training loss  0.983 in Step 1000
# Training loss  0.983 in Step 1100
# Training loss  0.986 in Step 1200
# Training loss  0.987 in Step 1300
# Training loss  0.983 in Step 1400
# Training loss  0.984 in Step 1500
# Training loss  0.983 in Step 1600
# Training loss  0.985 in Step 1700
# ※※※Training loss  0.985※※※
# Training timepoint saved
# Valid loss  0.995 in Step 0
# Valid loss  0.994 in Step 10
# Valid loss  0.992 in Step 20
# Valid loss  0.993 in Step 30
# Valid loss  0.994 in Step 40
# Valid loss  0.993 in Step 50
# Valid loss  0.994 in Step 60
# Valid loss  0.994 in Step 70
# Valid loss  0.995 in Step 80
# Valid loss  0.995 in Step 90
# Valid loss  0.996 in Step 100
# Valid loss  0.994 in Step 110
# Valid loss  0.993 in Step 120
# Valid loss  0.992 in Step 130
# Valid loss  0.994 in Step 140
# Valid loss  0.992 in Step 150
# Valid loss  0.995 in Step 160
# Valid loss  0.995 in Step 170
# Valid loss  0.994 in Step 180
# Valid loss  0.994 in Step 190
# Valid loss  0.994 in Step 200
# Valid loss  0.993 in Step 210
# Valid loss  0.993 in Step 220
# Valid loss  0.992 in Step 230
# Valid loss  0.994 in Step 240
# Valid loss  0.995 in Step 250
# Valid loss  0.994 in Step 260
# Valid loss  0.992 in Step 270
# Valid loss  0.995 in Step 280
# Valid loss  0.994 in Step 290
# Valid loss  0.995 in Step 300
# Valid loss  0.994 in Step 310
# Valid loss  0.995 in Step 320
# Valid loss  0.993 in Step 330
# Valid loss  0.993 in Step 340
# Valid loss  0.993 in Step 350
# Valid loss  0.995 in Step 360
# Valid loss  0.995 in Step 370
# Valid loss  0.994 in Step 380
# Valid loss  0.995 in Step 390
# Valid loss  0.994 in Step 400
# Valid loss  0.994 in Step 410
# Valid loss  0.995 in Step 420
# Valid loss  0.995 in Step 430
# Valid loss  0.993 in Step 440
# ※※※Valid loss  0.994※※※
# Epoch 23
# Training loss  0.984 in Step 0
# Training loss  0.983 in Step 100
# Training loss  0.986 in Step 200
# Training loss  0.989 in Step 300
# Training loss  0.984 in Step 400
# Training loss  0.985 in Step 500
# Training loss  0.983 in Step 600
# Training loss  0.985 in Step 700
# Training loss  0.985 in Step 800
# Training loss  0.985 in Step 900
# Training loss  0.984 in Step 1000
# Training loss  0.984 in Step 1100
# Training loss  0.984 in Step 1200
# Training loss  0.986 in Step 1300
# Training loss  0.985 in Step 1400
# Training loss  0.988 in Step 1500
# Training loss  0.983 in Step 1600
# Training loss  0.984 in Step 1700
# ※※※Training loss  0.985※※※
# Training timepoint saved
# Valid loss  0.995 in Step 0
# Valid loss  0.995 in Step 10
# Valid loss  0.992 in Step 20
# Valid loss  0.994 in Step 30
# Valid loss  0.996 in Step 40
# Valid loss  0.993 in Step 50
# Valid loss  0.995 in Step 60
# Valid loss  0.995 in Step 70
# Valid loss  0.995 in Step 80
# Valid loss  0.995 in Step 90
# Valid loss  0.997 in Step 100
# Valid loss  0.995 in Step 110
# Valid loss  0.994 in Step 120
# Valid loss  0.993 in Step 130
# Valid loss  0.994 in Step 140
# Valid loss  0.993 in Step 150
# Valid loss  0.996 in Step 160
# Valid loss  0.996 in Step 170
# Valid loss  0.995 in Step 180
# Valid loss  0.994 in Step 190
# Valid loss  0.994 in Step 200
# Valid loss  0.994 in Step 210
# Valid loss  0.994 in Step 220
# Valid loss  0.993 in Step 230
# Valid loss  0.995 in Step 240
# Valid loss  0.995 in Step 250
# ...
# Valid loss  0.991 in Step 190
# Valid loss  0.991 in Step 200
# Valid loss  0.993 in Step 210
# Valid loss  0.992 in Step 220
# Valid loss  0.992 in Step 230
# Valid loss  0.992 in Step 240
# Valid loss  0.994 in Step 250
# Valid loss  0.994 in Step 260
# Valid loss  0.991 in Step 270
# Valid loss  0.993 in Step 280
# Valid loss  0.994 in Step 290
# Valid loss  0.994 in Step 300
# Valid loss  0.994 in Step 310
# Valid loss  0.995 in Step 320
# Valid loss  0.994 in Step 330
# Valid loss  0.994 in Step 340
# Valid loss  0.993 in Step 350
# Valid loss  0.996 in Step 360
# Valid loss  0.995 in Step 370
# Valid loss  0.994 in Step 380
# Valid loss  0.996 in Step 390
# Valid loss  0.992 in Step 400
# Valid loss  0.993 in Step 410
# Valid loss  0.996 in Step 420
# Valid loss  0.994 in Step 430
# Valid loss  0.991 in Step 440
# ※※※Valid loss  0.993※※※
# Epoch 166
# Training loss  0.969 in Step 0
# Training loss  0.970 in Step 100
# Training loss  0.972 in Step 200
# Training loss  0.962 in Step 300
# Training loss  0.969 in Step 400
# Training loss  0.969 in Step 500
# Training loss  0.968 in Step 600
# Training loss  0.975 in Step 700
# Training loss  0.972 in Step 800
# Training loss  0.970 in Step 900
# Training loss  0.971 in Step 1000
# Training loss  0.965 in Step 1100
# Training loss  0.970 in Step 1200
# Training loss  0.973 in Step 1300
# Training loss  0.969 in Step 1400
# Training loss  0.968 in Step 1500
# Training loss  0.965 in Step 1600
# Training loss  0.968 in Step 1700
# ※※※Training loss  0.968※※※
# Training timepoint saved
# Valid loss  0.992 in Step 0
# Valid loss  0.993 in Step 10
# Valid loss  0.989 in Step 20
# Valid loss  0.990 in Step 30
# Valid loss  0.994 in Step 40
# Valid loss  0.990 in Step 50
# Valid loss  0.994 in Step 60
# Valid loss  0.992 in Step 70
# Valid loss  0.995 in Step 80
# Valid loss  0.993 in Step 90
# Valid loss  0.993 in Step 100
# Valid loss  0.992 in Step 110
# Valid loss  0.991 in Step 120
# Valid loss  0.990 in Step 130
# Valid loss  0.990 in Step 140
# Valid loss  0.987 in Step 150
# Valid loss  0.995 in Step 160
# Valid loss  0.994 in Step 170
# Valid loss  0.992 in Step 180
# Valid loss  0.990 in Step 190
# Valid loss  0.989 in Step 200
# Valid loss  0.992 in Step 210
# Valid loss  0.990 in Step 220
# Valid loss  0.990 in Step 230
# Valid loss  0.990 in Step 240
# Valid loss  0.993 in Step 250
# Valid loss  0.992 in Step 260
# Valid loss  0.990 in Step 270
# Valid loss  0.992 in Step 280
# Valid loss  0.992 in Step 290
# Valid loss  0.993 in Step 300
# Valid loss  0.993 in Step 310
# Valid loss  0.993 in Step 320
# Valid loss  0.992 in Step 330
# Valid loss  0.993 in Step 340
# Valid loss  0.991 in Step 350
# Valid loss  0.993 in Step 360
# Valid loss  0.993 in Step 370
# Valid loss  0.993 in Step 380
# Valid loss  0.993 in Step 390
# Valid loss  0.991 in Step 400
# Valid loss  0.992 in Step 410
# Valid loss  0.994 in Step 420
# Valid loss  0.992 in Step 430
# Valid loss  0.990 in Step 440
# ※※※Valid loss  0.992※※※
# Epoch 167
# Training loss  0.967 in Step 0
# Training loss  0.966 in Step 100
# Training loss  0.972 in Step 200
# Training loss  0.967 in Step 300
# Training loss  0.968 in Step 400
# Training loss  0.964 in Step 500
# Training loss  0.964 in Step 600
# Training loss  0.970 in Step 700
# Training loss  0.970 in Step 800
# Training loss  0.965 in Step 900
# Training loss  0.971 in Step 1000
# Training loss  0.969 in Step 1100
# Training loss  0.962 in Step 1200
# Training loss  0.968 in Step 1300
# Training loss  0.965 in Step 1400
# Training loss  0.968 in Step 1500
# Training loss  0.972 in Step 1600
# Training loss  0.971 in Step 1700
# ※※※Training loss  0.968※※※
# Training timepoint saved
# Valid loss  0.992 in Step 0
# Valid loss  0.994 in Step 10
# Valid loss  0.990 in Step 20
# Valid loss  0.991 in Step 30
# Valid loss  0.994 in Step 40
# Valid loss  0.990 in Step 50
# Valid loss  0.995 in Step 60
# Valid loss  0.993 in Step 70
# Valid loss  0.995 in Step 80
# Valid loss  0.993 in Step 90
# Valid loss  0.994 in Step 100
# Valid loss  0.992 in Step 110
# Valid loss  0.991 in Step 120
# Valid loss  0.991 in Step 130
# Valid loss  0.991 in Step 140
# Valid loss  0.987 in Step 150
# Valid loss  0.995 in Step 160
# Valid loss  0.995 in Step 170
# Valid loss  0.993 in Step 180
# Valid loss  0.991 in Step 190
# Valid loss  0.990 in Step 200
# Valid loss  0.992 in Step 210
# Valid loss  0.991 in Step 220
# Valid loss  0.991 in Step 230
# Valid loss  0.990 in Step 240
# Valid loss  0.993 in Step 250
# Valid loss  0.993 in Step 260
# Valid loss  0.991 in Step 270
# Valid loss  0.993 in Step 280
# Valid loss  0.992 in Step 290
# Valid loss  0.993 in Step 300
# Valid loss  0.994 in Step 310
# Valid loss  0.994 in Step 320
# Valid loss  0.992 in Step 330
# Valid loss  0.993 in Step 340
# Valid loss  0.991 in Step 350
# Valid loss  0.994 in Step 360
# Valid loss  0.993 in Step 370
# Valid loss  0.993 in Step 380
# Valid loss  0.994 in Step 390
# Valid loss  0.991 in Step 400
# Valid loss  0.992 in Step 410
# Valid loss  0.995 in Step 420
# Valid loss  0.992 in Step 430
# Valid loss  0.991 in Step 440
# ※※※Valid loss  0.992※※※
# Epoch 168
# Training loss  0.966 in Step 0
# Training loss  0.968 in Step 100
# Training loss  0.969 in Step 200
# Training loss  0.968 in Step 300
# Training loss  0.971 in Step 400
# Training loss  0.968 in Step 500
# Training loss  0.966 in Step 600
# Training loss  0.971 in Step 700
# Training loss  0.965 in Step 800
# Training loss  0.966 in Step 900
# Training loss  0.971 in Step 1000
# Training loss  0.970 in Step 1100
# Training loss  0.971 in Step 1200
# Training loss  0.967 in Step 1300
# Training loss  0.968 in Step 1400
# Training loss  0.970 in Step 1500
# Training loss  0.969 in Step 1600
# Training loss  0.968 in Step 1700
# ※※※Training loss  0.968※※※
# Training timepoint saved
# Valid loss  0.992 in Step 0
# Valid loss  0.994 in Step 10
# Valid loss  0.990 in Step 20
# Valid loss  0.990 in Step 30
# Valid loss  0.994 in Step 40
# Valid loss  0.990 in Step 50
# Valid loss  0.995 in Step 60
# Valid loss  0.993 in Step 70
# Valid loss  0.995 in Step 80
# Valid loss  0.993 in Step 90
# Valid loss  0.994 in Step 100
# Valid loss  0.992 in Step 110
# Valid loss  0.991 in Step 120
# Valid loss  0.991 in Step 130
# Valid loss  0.990 in Step 140
# Valid loss  0.987 in Step 150
# Valid loss  0.995 in Step 160
# Valid loss  0.995 in Step 170
# Valid loss  0.992 in Step 180
# Valid loss  0.990 in Step 190
# Valid loss  0.991 in Step 200
# Valid loss  0.992 in Step 210
# Valid loss  0.991 in Step 220
# Valid loss  0.991 in Step 230
# Valid loss  0.990 in Step 240
# Valid loss  0.993 in Step 250
# Valid loss  0.993 in Step 260
# Valid loss  0.990 in Step 270
# Valid loss  0.992 in Step 280
# Valid loss  0.992 in Step 290
# Valid loss  0.993 in Step 300
# Valid loss  0.993 in Step 310
# Valid loss  0.993 in Step 320
# Valid loss  0.992 in Step 330
# Valid loss  0.993 in Step 340
# Valid loss  0.991 in Step 350
# Valid loss  0.994 in Step 360
# Valid loss  0.993 in Step 370
# Valid loss  0.994 in Step 380
# Valid loss  0.994 in Step 390
# Valid loss  0.991 in Step 400
# Valid loss  0.992 in Step 410
# Valid loss  0.995 in Step 420
# Valid loss  0.993 in Step 430
# Valid loss  0.990 in Step 440
# ※※※Valid loss  0.992※※※
# Epoch 169
# Training loss  0.969 in Step 0
# Training loss  0.964 in Step 100
# Training loss  0.970 in Step 200
# Training loss  0.966 in Step 300
# Training loss  0.967 in Step 400
# Training loss  0.969 in Step 500
# Training loss  0.975 in Step 600
# Training loss  0.972 in Step 700
# Training loss  0.973 in Step 800
# Training loss  0.968 in Step 900
# Training loss  0.969 in Step 1000
# Training loss  0.969 in Step 1100
# Training loss  0.969 in Step 1200
# Training loss  0.971 in Step 1300
# Training loss  0.965 in Step 1400
# Training loss  0.970 in Step 1500
# Training loss  0.965 in Step 1600
# Training loss  0.966 in Step 1700
# ※※※Training loss  0.968※※※
# Training timepoint saved
# Valid loss  0.992 in Step 0
# Valid loss  0.994 in Step 10
# Valid loss  0.989 in Step 20
# Valid loss  0.990 in Step 30
# Valid loss  0.994 in Step 40
# Valid loss  0.990 in Step 50
# Valid loss  0.995 in Step 60
# Valid loss  0.993 in Step 70
# Valid loss  0.995 in Step 80
# Valid loss  0.993 in Step 90
# Valid loss  0.994 in Step 100
# Valid loss  0.992 in Step 110
# Valid loss  0.991 in Step 120
# Valid loss  0.991 in Step 130
# Valid loss  0.990 in Step 140
# Valid loss  0.987 in Step 150
# Valid loss  0.995 in Step 160
# Valid loss  0.995 in Step 170
# Valid loss  0.992 in Step 180
# Valid loss  0.990 in Step 190
# Valid loss  0.991 in Step 200
# Valid loss  0.992 in Step 210
# Valid loss  0.991 in Step 220
# Valid loss  0.990 in Step 230
# Valid loss  0.991 in Step 240
# Valid loss  0.993 in Step 250
# Valid loss  0.993 in Step 260
# Valid loss  0.990 in Step 270
# Valid loss  0.992 in Step 280
# Valid loss  0.992 in Step 290
# Valid loss  0.993 in Step 300
# Valid loss  0.993 in Step 310
# Valid loss  0.993 in Step 320
# Valid loss  0.992 in Step 330
# Valid loss  0.993 in Step 340
# Valid loss  0.991 in Step 350
# Valid loss  0.994 in Step 360
# Valid loss  0.993 in Step 370
# Valid loss  0.994 in Step 380
# Valid loss  0.994 in Step 390
# Valid loss  0.991 in Step 400
# Valid loss  0.992 in Step 410
# Valid loss  0.994 in Step 420
# Valid loss  0.993 in Step 430
# Valid loss  0.991 in Step 440
# ※※※Valid loss  0.992※※※
# Epoch 170
# Training loss  0.967 in Step 0
# Training loss  0.970 in Step 100
# Training loss  0.968 in Step 200
# Training loss  0.967 in Step 300
# Training loss  0.972 in Step 400
# Training loss  0.971 in Step 500
# Training loss  0.970 in Step 600
# Training loss  0.968 in Step 700
# Training loss  0.966 in Step 800
# Training loss  0.967 in Step 900
# Training loss  0.966 in Step 1000
# Training loss  0.969 in Step 1100
# Training loss  0.968 in Step 1200
# Training loss  0.970 in Step 1300
# Training loss  0.967 in Step 1400
# Training loss  0.971 in Step 1500
# Training loss  0.970 in Step 1600
# Training loss  0.965 in Step 1700
# ※※※Training loss  0.968※※※
# Training timepoint saved
# Valid loss  0.991 in Step 0
# Valid loss  0.993 in Step 10
# Valid loss  0.988 in Step 20
# Valid loss  0.990 in Step 30
# Valid loss  0.993 in Step 40
# Valid loss  0.989 in Step 50
# Valid loss  0.994 in Step 60
# Valid loss  0.992 in Step 70
# Valid loss  0.994 in Step 80
# Valid loss  0.992 in Step 90
# Valid loss  0.993 in Step 100
# Valid loss  0.992 in Step 110
# Valid loss  0.991 in Step 120
# Valid loss  0.990 in Step 130
# Valid loss  0.990 in Step 140
# Valid loss  0.986 in Step 150
# Valid loss  0.994 in Step 160
# Valid loss  0.994 in Step 170
# Valid loss  0.992 in Step 180
# Valid loss  0.989 in Step 190
# Valid loss  0.989 in Step 200
# Valid loss  0.991 in Step 210
# Valid loss  0.990 in Step 220
# Valid loss  0.990 in Step 230
# Valid loss  0.990 in Step 240
# Valid loss  0.992 in Step 250
# Valid loss  0.992 in Step 260
# Valid loss  0.989 in Step 270
# Valid loss  0.991 in Step 280
# Valid loss  0.991 in Step 290
# Valid loss  0.992 in Step 300
# Valid loss  0.992 in Step 310
# Valid loss  0.992 in Step 320
# Valid loss  0.991 in Step 330
# Valid loss  0.992 in Step 340
# Valid loss  0.990 in Step 350
# Valid loss  0.993 in Step 360
# Valid loss  0.993 in Step 370
# Valid loss  0.992 in Step 380
# Valid loss  0.993 in Step 390
# Valid loss  0.990 in Step 400
# Valid loss  0.991 in Step 410
# Valid loss  0.993 in Step 420
# Valid loss  0.992 in Step 430
# Valid loss  0.989 in Step 440
# ※※※Valid loss  0.991※※※
# Epoch 171
# Training loss  0.972 in Step 0
# Training loss  0.967 in Step 100
# Training loss  0.965 in Step 200
# Training loss  0.967 in Step 300
# Training loss  0.968 in Step 400
# Training loss  0.967 in Step 500
# Training loss  0.964 in Step 600
# Training loss  0.970 in Step 700
# Training loss  0.972 in Step 800
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /home/ldlmdl/Documents/wavln/scripts/SL_D_E_5.ipynb Cell 20 line 2
#       <a href='vscode-notebook-cell:/home/ldlmdl/Documents/wavln/scripts/SL_D_E_5.ipynb#X25sZmlsZQ%3D%3D?line=0'>1</a> if __name__ == "__main__":
# ----> <a href='vscode-notebook-cell:/home/ldlmdl/Documents/wavln/scripts/SL_D_E_5.ipynb#X25sZmlsZQ%3D%3D?line=1'>2</a>     train()
#
# /home/ldlmdl/Documents/wavln/scripts/SL_D_E_5.ipynb Cell 20 line 1
#      <a href='vscode-notebook-cell:/home/ldlmdl/Documents/wavln/scripts/SL_D_E_5.ipynb#X25sZmlsZQ%3D%3D?line=13'>14</a> x = x.to(device)
#      <a href='vscode-notebook-cell:/home/ldlmdl/Documents/wavln/scripts/SL_D_E_5.ipynb#X25sZmlsZQ%3D%3D?line=14'>15</a> y = y.to(device)
# ---> <a href='vscode-notebook-cell:/home/ldlmdl/Documents/wavln/scripts/SL_D_E_5.ipynb#X25sZmlsZQ%3D%3D?line=16'>17</a> recon_x, attn_weight = model(x, x_lens, x_mask)
#      <a href='vscode-notebook-cell:/home/ldlmdl/Documents/wavln/scripts/SL_D_E_5.ipynb#X25sZmlsZQ%3D%3D?line=18'>19</a> loss = model_loss.get_loss(recon_x, y, x_mask)
#      <a href='vscode-notebook-cell:/home/ldlmdl/Documents/wavln/scripts/SL_D_E_5.ipynb#X25sZmlsZQ%3D%3D?line=20'>21</a> train_loss += loss.item()
#
# File ~/anaconda3/envs/wavln/lib/python3.11/site-packages/torch/nn/modules/module.py:1501, in Module._call_impl(self, *args, **kwargs)
#    1496 # If we don't have any hooks, we want to skip the rest of the logic in
#    1497 # this function, and just call forward.
#    1498 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1499         or _global_backward_pre_hooks or _global_backward_hooks
#    1500         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1501     return forward_call(*args, **kwargs)
#    1502 # Do not call functions when jit is used
#    1503 full_backward_hooks, non_full_backward_hooks = [], []
#
# File ~/Documents/wavln/scripts/model.py:355, in SimplerPhxLearner.forward(self, inputs, input_lens, in_mask)
#     352 dec_hid, init_in = self.decoder.inits(batch_size=batch_size, device=self.device)
#     354 enc_out = self.encoder(inputs, input_lens, in_mask)
# --> 355 dec_out, attn_w = self.decoder(enc_out, in_mask, init_in, dec_hid)
#     357 return dec_out, attn_w
#
# File ~/anaconda3/envs/wavln/lib/python3.11/site-packages/torch/nn/modules/module.py:1501, in Module._call_impl(self, *args, **kwargs)
#    1496 # If we don't have any hooks, we want to skip the rest of the logic in
#    1497 # this function, and just call forward.
#    1498 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1499         or _global_backward_pre_hooks or _global_backward_hooks
#    1500         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1501     return forward_call(*args, **kwargs)
#    1502 # Do not call functions when jit is used
#    1503 full_backward_hooks, non_full_backward_hooks = [], []
#
# File ~/Documents/wavln/scripts/model.py:317, in RALDecoder.forward(self, hid_r, in_mask, init_in, hidden)
#     314 attention_weights = []
#     315 for t in range(length):
#     316     # dec_x = self.lin_1(dec_in_token)
# --> 317     dec_x, hidden = self.rnn(dec_in_token, hidden)
#     318     # dec_x = self.lin_2(dec_x)
#     319     dec_x, attention_weight = self.attention(dec_x, hid_r, hid_r, in_mask.unsqueeze(1))    # unsqueeze mask here for broadcast
#
# File ~/anaconda3/envs/wavln/lib/python3.11/site-packages/torch/nn/modules/module.py:1501, in Module._call_impl(self, *args, **kwargs)
#    1496 # If we don't have any hooks, we want to skip the rest of the logic in
#    1497 # this function, and just call forward.
#    1498 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1499         or _global_backward_pre_hooks or _global_backward_hooks
#    1500         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1501     return forward_call(*args, **kwargs)
#    1502 # Do not call functions when jit is used
#    1503 full_backward_hooks, non_full_backward_hooks = [], []
#
# File ~/anaconda3/envs/wavln/lib/python3.11/site-packages/torch/nn/modules/rnn.py:759, in LSTM.forward(self, input, hx)
#     753 @overload
#     754 @torch._jit_internal._overload_method  # noqa: F811
#     755 def forward(self, input: PackedSequence, hx: Optional[Tuple[Tensor, Tensor]] = None
#     756             ) -> Tuple[PackedSequence, Tuple[Tensor, Tensor]]:  # noqa: F811
#     757     pass
# --> 759 def forward(self, input, hx=None):  # noqa: F811
#     760     if not torch.jit.is_scripting():
#     761         if self._weights_have_changed():
#
# KeyboardInterrupt:

# %%
### Save
train_losses.save()

valid_losses.save()

text_hist.save()

# %%
plt.plot(train_losses.get(), label='Train')
plt.plot(valid_losses.get(), label='Valid')
plt.title("Learning Curve Loss")
plt.legend()

# %% [markdown]
# ## Conclusion
# This model should converge to loss around 0.49x.
