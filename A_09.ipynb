# %% [markdown]
# # New Run
# A_01: Copy from SL_D_E_4.ipynb. Fixed the problem as we have found in normalization. This time we normalize over the whole course.
#
#
# A_05: This time we resume using two linear layers, one before RNN and one after. IN this way we make the last linear layer of both encoder and decoder
# a pure linear layer without other components.
#
# A_07: This time we delete the attention part of the decoder and make it completely autoregressive. See how it performs.
#
# A_08: Restore the inclusion of attention mechanism, and set the first input to decoder to all zero.

# %% [markdown]
# # Sequence Learning - Direct - English
# Version 1: In this version we make the model "simple": make the encoder RNN into normal RNN first and try to see the result.
# Version 2: Learning is not very much. Following Dr Coupe's advice we try simpler model structure.
# Version 3: A simple trial training with Mel spectrogram instead of MFCC.
# Version 4: try to enlarge the hidden dimensions so that we might still make sense of the hidden representation.

# %%
import torch
import torchaudio
from torch import nn
import torch.nn.functional as F
from torch.nn.utils.rnn import pad_sequence, pack_sequence
from torch import optim
from torch.utils.data import Dataset, DataLoader, random_split
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import pickle
from datetime import datetime
import random
from torchinfo import summary

# %%
from model import TwoLinPhxLearner as TheLearner
from my_dataset import DS_Tools
from dataset import SeqDataset, MelTransform, Normalizer, DeNormalizer
from dataset import MelSpecTransformNoDB as TheTransform
from paths import *
from my_utils import *
from recorder import *
from loss import *
from padding import generate_mask_from_lengths_mat, mask_it

# %% [markdown]
# ### Dirs

# %%
model_save_dir = model_eng_save_dir
# random_data:phone_seg_random_path
# anno_data: phone_seg_anno_path

# random_log_path = phone_seg_random_log_path + "log.csv"
random_log_path = word_seg_anno_log_path
random_path = word_seg_anno_path
anno_log_path = phone_seg_anno_path

# %% [markdown]
# ### Constants

# %%
BATCH_SIZE = 128

INPUT_DIM = 64
OUTPUT_DIM = 64 

INTER_DIM_0 = 32
INTER_DIM_1 = 16
INTER_DIM_2 = 8

ENC_SIZE_LIST = [INPUT_DIM, INTER_DIM_0, INTER_DIM_1, INTER_DIM_2]
DEC_SIZE_LIST = [OUTPUT_DIM, INTER_DIM_0, INTER_DIM_1, INTER_DIM_2]

DROPOUT = 0.5

REC_SAMPLE_RATE = 16000
N_FFT = 400
N_MELS = 64

LOADER_WORKER = 16
# LOADER_WORKER = 0

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
recon_loss = nn.MSELoss(reduction='none')
masked_recon_loss = MaskedLoss(recon_loss)
model_loss = masked_recon_loss

model = TheLearner(enc_size_list=ENC_SIZE_LIST, dec_size_list=DEC_SIZE_LIST, num_layers=2)
model.to(device)
optimizer = optim.Adam(model.parameters(), lr=1e-3)

# %%
# # initialize model weights
# def init_weights(m):
#     if isinstance(m, nn.Linear):
#         torch.nn.init.orthogonal_(m.weight)
#         m.bias.data.fill_(0.01)
#     if isinstance(m, nn.LSTM): 
#         for name, p in m.named_parameters():
#             if "weight" in name: 
#                 nn.init.orthogonal_(p)
#             elif "bias" in name: 
#                 nn.init.constant_(p, 0)

# model.apply(init_weights)

# %%
model_parameters = filter(lambda p: p.requires_grad, model.parameters())
params = sum([np.prod(p.size()) for p in model_parameters])

# %%
params
# Out:
# 12384

# %%
# Just for keeping records of training hists. 
# ts = "0918192113"
stop_epoch = "149"
ts = str(get_timestamp())
save_txt_name = "train_txt_{}.hst".format(ts)
save_trainhist_name = "train_hist_{}.hst".format(ts)

save_valhist_name = "val_hist_{}.hst".format(ts)

# %%
train_losses = LossRecorder(model_save_dir + save_trainhist_name)

valid_losses = LossRecorder(model_save_dir + save_valhist_name)

text_hist = HistRecorder(model_save_dir + save_txt_name)

# %%
READ = False
# READ = True

# %%
if READ: 
    valid_losses.read()
    train_losses.read()

    model_raw_name = "PT_{}_{}_full".format(ts, stop_epoch)
    model_name = model_raw_name + ".pt"
    model_path = os.path.join(model_save_dir, model_name)
    state = torch.load(model_path)

    model.load_state_dict(state)
    model.to(device)

# %%
model
# Out:
# TwoLinPhxLearner(
#   (encoder): LRLEncoder(
#     (lin_1): LinearPack(
#       (linear): Linear(in_features=64, out_features=32, bias=True)
#       (relu): ReLU()
#       (dropout): Dropout(p=0.5, inplace=False)
#     )
#     (rnn): LSTM(32, 16, num_layers=2, batch_first=True)
#     (lin_2): Linear(in_features=16, out_features=8, bias=True)
#   )
#   (decoder): LRALDecoder(
#     (lin_1): LinearPack(
#       (linear): Linear(in_features=64, out_features=32, bias=True)
#       (relu): ReLU()
#       (dropout): Dropout(p=0.5, inplace=False)
#     )
#     (rnn): LSTM(32, 8, num_layers=2, batch_first=True)
#     (attention): ScaledDotProductAttention(
#       (w_q): Linear(in_features=8, out_features=8, bias=True)
#       (w_k): Linear(in_features=8, out_features=8, bias=True)
#       (w_v): Linear(in_features=8, out_features=8, bias=True)
#     )
#     (lin_3): Linear(in_features=8, out_features=64, bias=True)
#   )
# )

# %%
# mytrans = MelSpecTransform(sample_rate=REC_SAMPLE_RATE, n_fft=N_FFT, n_mels=N_MELS)
# mytrans = nn.Sequential(
#     MelTransform(sample_rate=REC_SAMPLE_RATE, n_fft=N_FFT, n_mels=N_MELS),
#     # torchaudio.transforms.AmplitudeToDB(stype="power", top_db=80), 
#     Normalizer(Normalizer.norm_strip_minmax)
# )
mytrans = TheTransform(sample_rate=REC_SAMPLE_RATE, n_fft=N_FFT, n_mels=N_MELS, normalizer=Normalizer.norm_mvn, denormalizer=DeNormalizer.norm_mvn)
ds = SeqDataset(random_path, os.path.join(random_log_path, "log.csv"), transform=mytrans)

test = False
if test: 
    use_len = int(0.1 * len(ds))
    remain_len = len(ds) - use_len

    # Randomly split the dataset into train and validation sets
    ds, remain_ds = random_split(ds, [use_len, remain_len])


if READ: 
    valid_ds_indices = DS_Tools.read_indices(os.path.join(model_save_dir, "valid_ds_{}.pkl".format(ts)))
    all_indices = list(range(len(ds)))
    train_ds_indices = list(set(all_indices).difference(set(valid_ds_indices)))

    train_ds = torch.utils.data.Subset(ds, train_ds_indices)
    valid_ds = torch.utils.data.Subset(ds, valid_ds_indices)
else: 
    train_len = int(0.8 * len(ds))
    valid_len = len(ds) - train_len

    # Randomly split the dataset into train and validation sets
    train_ds, valid_ds = random_split(ds, [train_len, valid_len])
    DS_Tools.save_indices(os.path.join(model_save_dir, "valid_ds_{}.pkl".format(ts)), valid_ds.indices)

train_loader = DataLoader(train_ds, batch_size=BATCH_SIZE, shuffle=True, num_workers=LOADER_WORKER, collate_fn=SeqDataset.collate_fn)
train_num = len(train_loader.dataset)

valid_loader = DataLoader(valid_ds, batch_size=BATCH_SIZE, shuffle=False, num_workers=LOADER_WORKER, collate_fn=SeqDataset.collate_fn)
valid_num = len(valid_loader.dataset)

# %%
len(train_loader)
# Out:
# 1776

# %%
# Load sample data from train_loader
sample_data = next(iter(valid_loader))
xx_pad, seg = sample_data
print(xx_pad.shape)
# Out:
# torch.Size([128, 74, 64])

# %%
# Set the random seed for reproducibility
# random.seed(101)
# Generate six random indices
random_indices = random.sample(range(len(xx_pad)), 6)
# random_indices = list(range(6, 12))

# Plot the spectrograms and mark the corresponding seg
fig, axes = plt.subplots(2, 3, figsize=(12, 8))
axes = axes.flatten()

for i, idx in enumerate(random_indices):
    spectrogram = xx_pad[idx]
    
    ax = axes[i]
    img = ax.imshow(spectrogram.T, aspect='auto', origin="lower")
    # ax.axvline(x=segment, color='red', linestyle='--')
    # ax.axvline(x=segment[1], color='red', linestyle='--')
    ax.set_title(f'Spectrogram')
    ax.set_xlabel('Time')
    ax.set_ylabel('Frequency')
plt.tight_layout()
plt.colorbar(img,ax=axes)
plt.show()

# %%
ts
# Out:
# '0122204715'

# %%
EPOCHS = 50
BASE = 0

# %%
def train(): 
    for epoch in range(BASE, BASE + EPOCHS):
        text_hist.print("Epoch {}".format(epoch))

        model.train()
        train_loss = 0.
        train_num = len(train_loader)    # train_loader
        for idx, (x, x_lens) in enumerate(train_loader):
            optimizer.zero_grad()
            y = x 
            
            x_mask = generate_mask_from_lengths_mat(x_lens, device=device)
            
            x = x.to(device)
            y = y.to(device)

            recon_x, attn_weight = model(x, x_lens, x_mask)

            loss = model_loss.get_loss(recon_x, y, x_mask)

            train_loss += loss.item()

            loss.backward()
            
            # torch.nn.utils.clip_grad_norm_(model.parameters(), clip_value)
            # 这个函数计算的是全局梯度范数
            # torch.nn.utils.clip_grad_norm(parameters=model.parameters(), max_norm=5, norm_type=2)
            torch.nn.utils.clip_grad_norm_(parameters=model.parameters(), max_norm=5, norm_type=2)
            # parameters: an iterable of Variables that will have gradients normalized
            # max_norm: max norm of the gradients(阈值设定)
            # norm_type: type of the used p-norm. Can be'inf'for infinity norm(定义范数类型)

            optimizer.step()

            if idx % 100 == 0:
                text_hist.print(f"Training loss {loss: .3f} in Step {idx}")

        train_losses.append(train_loss / train_num)
        text_hist.print(f"※※※Training loss {train_loss / train_num: .3f}※※※")

        last_model_name = "PT_{}_{}_full.pt".format(ts, epoch)
        torch.save(model.state_dict(), os.path.join(model_save_dir, last_model_name))
        text_hist.print("Training timepoint saved")

        model.eval()
        valid_loss = 0.
        valid_num = len(valid_loader)
        for idx, (x, x_lens) in enumerate(valid_loader):
            y = x    # extract MFCC-only data
            x_mask = generate_mask_from_lengths_mat(x_lens, device=device)
            
            x = x.to(device)
            y = y.to(device)

            recon_x, attn_weight = model(x, x_lens, x_mask)

            loss = model_loss.get_loss(recon_x, y, x_mask)

            valid_loss += loss.item()

            if idx % 50 == 0:
                text_hist.print(f"Valid loss {loss: .3f} in Step {idx}")

        valid_losses.append(valid_loss / valid_num)

        text_hist.print(f"※※※Valid loss {valid_loss / valid_num: .3f}※※※")

# %%
if __name__ == "__main__": 
    train()
# Out:
# Epoch 0
# Training loss  1.024 in Step 0
# Training loss  0.846 in Step 100
# Training loss  0.770 in Step 200
# Training loss  0.715 in Step 300
# Training loss  0.686 in Step 400
# Training loss  0.641 in Step 500
# Training loss  0.635 in Step 600
# Training loss  0.569 in Step 700
# Training loss  0.560 in Step 800
# Training loss  0.606 in Step 900
# Training loss  0.586 in Step 1000
# Training loss  0.584 in Step 1100
# Training loss  0.547 in Step 1200
# Training loss  0.581 in Step 1300
# Training loss  0.560 in Step 1400
# Training loss  0.549 in Step 1500
# Training loss  0.530 in Step 1600
# Training loss  0.524 in Step 1700
# ※※※Training loss  0.620※※※
# Training timepoint saved
# Valid loss  0.555 in Step 0
# Valid loss  0.497 in Step 50
# Valid loss  0.544 in Step 100
# Valid loss  0.519 in Step 150
# Valid loss  0.517 in Step 200
# Valid loss  0.510 in Step 250
# Valid loss  0.516 in Step 300
# Valid loss  0.503 in Step 350
# Valid loss  0.518 in Step 400
# ※※※Valid loss  0.521※※※
# Epoch 1
# Training loss  0.548 in Step 0
# Training loss  0.535 in Step 100
# Training loss  0.502 in Step 200
# Training loss  0.513 in Step 300
# Training loss  0.504 in Step 400
# Training loss  0.548 in Step 500
# Training loss  0.520 in Step 600
# Training loss  0.513 in Step 700
# Training loss  0.517 in Step 800
# Training loss  0.515 in Step 900
# Training loss  0.528 in Step 1000
# Training loss  0.550 in Step 1100
# Training loss  0.515 in Step 1200
# Training loss  0.514 in Step 1300
# Training loss  0.461 in Step 1400
# Training loss  0.505 in Step 1500
# Training loss  0.510 in Step 1600
# Training loss  0.507 in Step 1700
# ※※※Training loss  0.517※※※
# Training timepoint saved
# Valid loss  0.517 in Step 0
# Valid loss  0.467 in Step 50
# Valid loss  0.503 in Step 100
# Valid loss  0.497 in Step 150
# Valid loss  0.482 in Step 200
# Valid loss  0.482 in Step 250
# Valid loss  0.486 in Step 300
# Valid loss  0.467 in Step 350
# Valid loss  0.477 in Step 400
# ※※※Valid loss  0.485※※※
# Epoch 2
# Training loss  0.493 in Step 0
# Training loss  0.512 in Step 100
# Training loss  0.464 in Step 200
# Training loss  0.473 in Step 300
# Training loss  0.505 in Step 400
# Training loss  0.479 in Step 500
# Training loss  0.472 in Step 600
# Training loss  0.460 in Step 700
# Training loss  0.470 in Step 800
# Training loss  0.479 in Step 900
# Training loss  0.448 in Step 1000
# Training loss  0.434 in Step 1100
# Training loss  0.447 in Step 1200
# Training loss  0.434 in Step 1300
# Training loss  0.428 in Step 1400
# Training loss  0.469 in Step 1500
# Training loss  0.459 in Step 1600
# Training loss  0.422 in Step 1700
# ※※※Training loss  0.464※※※
# Training timepoint saved
# Valid loss  0.456 in Step 0
# Valid loss  0.419 in Step 50
# Valid loss  0.457 in Step 100
# Valid loss  0.440 in Step 150
# Valid loss  0.434 in Step 200
# Valid loss  0.431 in Step 250
# Valid loss  0.431 in Step 300
# Valid loss  0.415 in Step 350
# Valid loss  0.428 in Step 400
# ※※※Valid loss  0.435※※※
# Epoch 3
# Training loss  0.453 in Step 0
# Training loss  0.476 in Step 100
# Training loss  0.440 in Step 200
# Training loss  0.450 in Step 300
# Training loss  0.424 in Step 400
# Training loss  0.472 in Step 500
# Training loss  0.433 in Step 600
# Training loss  0.431 in Step 700
# Training loss  0.433 in Step 800
# Training loss  0.465 in Step 900
# Training loss  0.445 in Step 1000
# Training loss  0.425 in Step 1100
# Training loss  0.398 in Step 1200
# Training loss  0.466 in Step 1300
# Training loss  0.439 in Step 1400
# Training loss  0.486 in Step 1500
# Training loss  0.431 in Step 1600
# Training loss  0.441 in Step 1700
# ※※※Training loss  0.440※※※
# Training timepoint saved
# Valid loss  0.449 in Step 0
# Valid loss  0.413 in Step 50
# Valid loss  0.452 in Step 100
# Valid loss  0.428 in Step 150
# Valid loss  0.426 in Step 200
# Valid loss  0.428 in Step 250
# Valid loss  0.423 in Step 300
# Valid loss  0.407 in Step 350
# Valid loss  0.423 in Step 400
# ※※※Valid loss  0.429※※※
# Epoch 4
# Training loss  0.418 in Step 0
# Training loss  0.416 in Step 100
# Training loss  0.426 in Step 200
# Training loss  0.457 in Step 300
# Training loss  0.428 in Step 400
# Training loss  0.447 in Step 500
# Training loss  0.421 in Step 600
# Training loss  0.447 in Step 700
# Training loss  0.416 in Step 800
# Training loss  0.492 in Step 900
# Training loss  0.427 in Step 1000
# Training loss  0.442 in Step 1100
# Training loss  0.414 in Step 1200
# Training loss  0.418 in Step 1300
# Training loss  0.421 in Step 1400
# Training loss  0.424 in Step 1500
# Training loss  0.436 in Step 1600
# Training loss  0.421 in Step 1700
# ※※※Training loss  0.428※※※
# Training timepoint saved
# Valid loss  0.452 in Step 0
# Valid loss  0.416 in Step 50
# Valid loss  0.456 in Step 100
# Valid loss  0.426 in Step 150
# Valid loss  0.424 in Step 200
# Valid loss  0.432 in Step 250
# Valid loss  0.426 in Step 300
# Valid loss  0.413 in Step 350
# Valid loss  0.426 in Step 400
# ※※※Valid loss  0.433※※※
# Epoch 5
# Training loss  0.433 in Step 0
# Training loss  0.432 in Step 100
# Training loss  0.441 in Step 200
# Training loss  0.394 in Step 300
# Training loss  0.420 in Step 400
# Training loss  0.401 in Step 500
# Training loss  0.403 in Step 600
# Training loss  0.387 in Step 700
# Training loss  0.385 in Step 800
# Training loss  0.407 in Step 900
# Training loss  0.386 in Step 1000
# Training loss  0.386 in Step 1100
# Training loss  0.414 in Step 1200
# Training loss  0.382 in Step 1300
# Training loss  0.364 in Step 1400
# Training loss  0.380 in Step 1500
# Training loss  0.370 in Step 1600
# Training loss  0.393 in Step 1700
# ※※※Training loss  0.398※※※
# Training timepoint saved
# Valid loss  0.430 in Step 0
# Valid loss  0.395 in Step 50
# Valid loss  0.429 in Step 100
# Valid loss  0.395 in Step 150
# Valid loss  0.401 in Step 200
# Valid loss  0.404 in Step 250
# Valid loss  0.395 in Step 300
# Valid loss  0.382 in Step 350
# Valid loss  0.405 in Step 400
# ※※※Valid loss  0.405※※※
# Epoch 6
# Training loss  0.378 in Step 0
# Training loss  0.389 in Step 100
# Training loss  0.362 in Step 200
# Training loss  0.363 in Step 300
# Training loss  0.359 in Step 400
# Training loss  0.407 in Step 500
# Training loss  0.401 in Step 600
# Training loss  0.391 in Step 700
# Training loss  0.371 in Step 800
# Training loss  0.365 in Step 900
# Training loss  0.408 in Step 1000
# Training loss  0.384 in Step 1100
# Training loss  0.380 in Step 1200
# Training loss  0.398 in Step 1300
# Training loss  0.386 in Step 1400
# Training loss  0.392 in Step 1500
# Training loss  0.359 in Step 1600
# Training loss  0.359 in Step 1700
# ※※※Training loss  0.375※※※
# Training timepoint saved
# Valid loss  0.438 in Step 0
# Valid loss  0.407 in Step 50
# Valid loss  0.438 in Step 100
# Valid loss  0.405 in Step 150
# Valid loss  0.408 in Step 200
# Valid loss  0.417 in Step 250
# Valid loss  0.411 in Step 300
# Valid loss  0.392 in Step 350
# Valid loss  0.421 in Step 400
# ※※※Valid loss  0.416※※※
# Epoch 7
# Training loss  0.379 in Step 0
# Training loss  0.362 in Step 100
# Training loss  0.330 in Step 200
# Training loss  0.403 in Step 300
# Training loss  0.376 in Step 400
# Training loss  0.368 in Step 500
# Training loss  0.365 in Step 600
# Training loss  0.375 in Step 700
# Training loss  0.382 in Step 800
# Training loss  0.373 in Step 900
# Training loss  0.364 in Step 1000
# Training loss  0.344 in Step 1100
# Training loss  0.395 in Step 1200
# Training loss  0.359 in Step 1300
# Training loss  0.367 in Step 1400
# Training loss  0.368 in Step 1500
# Training loss  0.358 in Step 1600
# Training loss  0.388 in Step 1700
# ※※※Training loss  0.369※※※
# Training timepoint saved
# Valid loss  0.452 in Step 0
# Valid loss  0.424 in Step 50
# Valid loss  0.451 in Step 100
# Valid loss  0.422 in Step 150
# Valid loss  0.423 in Step 200
# Valid loss  0.431 in Step 250
# Valid loss  0.425 in Step 300
# Valid loss  0.406 in Step 350
# Valid loss  0.438 in Step 400
# ※※※Valid loss  0.430※※※
# Epoch 8
# Training loss  0.386 in Step 0
# Training loss  0.364 in Step 100
# Training loss  0.381 in Step 200
# Training loss  0.393 in Step 300
# Training loss  0.364 in Step 400
# Training loss  0.362 in Step 500
# Training loss  0.352 in Step 600
# Training loss  0.353 in Step 700
# Training loss  0.368 in Step 800
# Training loss  0.354 in Step 900
# Training loss  0.365 in Step 1000
# Training loss  0.374 in Step 1100
# Training loss  0.359 in Step 1200
# Training loss  0.358 in Step 1300
# Training loss  0.364 in Step 1400
# Training loss  0.375 in Step 1500
# Training loss  0.357 in Step 1600
# Training loss  0.364 in Step 1700
# ※※※Training loss  0.364※※※
# Training timepoint saved
# Valid loss  0.464 in Step 0
# Valid loss  0.438 in Step 50
# Valid loss  0.464 in Step 100
# Valid loss  0.435 in Step 150
# Valid loss  0.436 in Step 200
# Valid loss  0.446 in Step 250
# Valid loss  0.438 in Step 300
# Valid loss  0.419 in Step 350
# Valid loss  0.451 in Step 400
# ※※※Valid loss  0.443※※※
# Epoch 9
# Training loss  0.359 in Step 0
# Training loss  0.382 in Step 100
# Training loss  0.388 in Step 200
# Training loss  0.361 in Step 300
# Training loss  0.380 in Step 400
# Training loss  0.365 in Step 500
# Training loss  0.384 in Step 600
# Training loss  0.341 in Step 700
# Training loss  0.348 in Step 800
# Training loss  0.370 in Step 900
# Training loss  0.363 in Step 1000
# Training loss  0.380 in Step 1100
# Training loss  0.363 in Step 1200
# Training loss  0.372 in Step 1300
# Training loss  0.332 in Step 1400
# Training loss  0.386 in Step 1500
# Training loss  0.362 in Step 1600
# Training loss  0.351 in Step 1700
# ※※※Training loss  0.361※※※
# Training timepoint saved
# Valid loss  0.482 in Step 0
# Valid loss  0.457 in Step 50
# Valid loss  0.482 in Step 100
# Valid loss  0.451 in Step 150
# Valid loss  0.455 in Step 200
# Valid loss  0.466 in Step 250
# Valid loss  0.458 in Step 300
# Valid loss  0.440 in Step 350
# Valid loss  0.470 in Step 400
# ※※※Valid loss  0.462※※※
# Epoch 10
# Training loss  0.338 in Step 0
# Training loss  0.379 in Step 100
# Training loss  0.375 in Step 200
# Training loss  0.374 in Step 300
# Training loss  0.361 in Step 400
# Training loss  0.350 in Step 500
# Training loss  0.378 in Step 600
# Training loss  0.387 in Step 700
# Training loss  0.327 in Step 800
# Training loss  0.391 in Step 900
# Training loss  0.343 in Step 1000
# Training loss  0.321 in Step 1100
# Training loss  0.365 in Step 1200
# Training loss  0.362 in Step 1300
# Training loss  0.343 in Step 1400
# Training loss  0.342 in Step 1500
# Training loss  0.351 in Step 1600
# Training loss  0.348 in Step 1700
# ※※※Training loss  0.359※※※
# Training timepoint saved
# Valid loss  0.485 in Step 0
# Valid loss  0.461 in Step 50
# Valid loss  0.486 in Step 100
# Valid loss  0.454 in Step 150
# Valid loss  0.460 in Step 200
# Valid loss  0.471 in Step 250
# Valid loss  0.463 in Step 300
# Valid loss  0.444 in Step 350
# Valid loss  0.473 in Step 400
# ※※※Valid loss  0.466※※※
# Epoch 11
# Training loss  0.376 in Step 0
# Training loss  0.328 in Step 100
# Training loss  0.366 in Step 200
# Training loss  0.347 in Step 300
# Training loss  0.387 in Step 400
# Training loss  0.363 in Step 500
# Training loss  0.343 in Step 600
# Training loss  0.320 in Step 700
# Training loss  0.398 in Step 800
# Training loss  0.363 in Step 900
# Training loss  0.352 in Step 1000
# Training loss  0.351 in Step 1100
# Training loss  0.333 in Step 1200
# Training loss  0.351 in Step 1300
# Training loss  0.349 in Step 1400
# Training loss  0.373 in Step 1500
# Training loss  0.355 in Step 1600
# Training loss  0.320 in Step 1700
# ※※※Training loss  0.357※※※
# Training timepoint saved
# Valid loss  0.506 in Step 0
# Valid loss  0.485 in Step 50
# Valid loss  0.507 in Step 100
# Valid loss  0.479 in Step 150
# Valid loss  0.487 in Step 200
# Valid loss  0.492 in Step 250
# Valid loss  0.484 in Step 300
# Valid loss  0.469 in Step 350
# Valid loss  0.493 in Step 400
# ※※※Valid loss  0.488※※※
# Epoch 12
# Training loss  0.351 in Step 0
# Training loss  0.329 in Step 100
# Training loss  0.375 in Step 200
# Training loss  0.373 in Step 300
# Training loss  0.398 in Step 400
# Training loss  0.365 in Step 500
# Training loss  0.341 in Step 600
# Training loss  0.358 in Step 700
# Training loss  0.339 in Step 800
# Training loss  0.363 in Step 900
# Training loss  0.372 in Step 1000
# Training loss  0.360 in Step 1100
# Training loss  0.350 in Step 1200
# Training loss  0.368 in Step 1300
# Training loss  0.377 in Step 1400
# Training loss  0.361 in Step 1500
# Training loss  0.344 in Step 1600
# Training loss  0.348 in Step 1700
# ※※※Training loss  0.355※※※
# Training timepoint saved
# Valid loss  0.500 in Step 0
# Valid loss  0.479 in Step 50
# Valid loss  0.501 in Step 100
# Valid loss  0.470 in Step 150
# Valid loss  0.480 in Step 200
# Valid loss  0.489 in Step 250
# Valid loss  0.480 in Step 300
# Valid loss  0.465 in Step 350
# Valid loss  0.491 in Step 400
# ※※※Valid loss  0.483※※※
# Epoch 13
# Training loss  0.361 in Step 0
# Training loss  0.355 in Step 100
# Training loss  0.355 in Step 200
# Training loss  0.338 in Step 300
# Training loss  0.370 in Step 400
# Training loss  0.353 in Step 500
# Training loss  0.388 in Step 600
# Training loss  0.367 in Step 700
# Training loss  0.406 in Step 800
# Training loss  0.365 in Step 900
# Training loss  0.341 in Step 1000
# Training loss  0.351 in Step 1100
# Training loss  0.352 in Step 1200
# Training loss  0.341 in Step 1300
# Training loss  0.357 in Step 1400
# Training loss  0.362 in Step 1500
# Training loss  0.390 in Step 1600
# Training loss  0.332 in Step 1700
# ※※※Training loss  0.354※※※
# Training timepoint saved
# Valid loss  0.528 in Step 0
# Valid loss  0.508 in Step 50
# Valid loss  0.529 in Step 100
# Valid loss  0.499 in Step 150
# Valid loss  0.510 in Step 200
# Valid loss  0.516 in Step 250
# Valid loss  0.508 in Step 300
# Valid loss  0.495 in Step 350
# Valid loss  0.518 in Step 400
# ※※※Valid loss  0.512※※※
# Epoch 14
# Training loss  0.358 in Step 0
# Training loss  0.383 in Step 100
# Training loss  0.365 in Step 200
# Training loss  0.351 in Step 300
# Training loss  0.365 in Step 400
# Training loss  0.318 in Step 500
# Training loss  0.354 in Step 600
# Training loss  0.327 in Step 700
# Training loss  0.338 in Step 800
# Training loss  0.384 in Step 900
# Training loss  0.377 in Step 1000
# Training loss  0.332 in Step 1100
# Training loss  0.368 in Step 1200
# Training loss  0.378 in Step 1300
# Training loss  0.372 in Step 1400
# Training loss  0.348 in Step 1500
# Training loss  0.353 in Step 1600
# Training loss  0.382 in Step 1700
# ※※※Training loss  0.353※※※
# Training timepoint saved
# Valid loss  0.513 in Step 0
# Valid loss  0.493 in Step 50
# Valid loss  0.516 in Step 100
# Valid loss  0.482 in Step 150
# Valid loss  0.494 in Step 200
# Valid loss  0.503 in Step 250
# Valid loss  0.492 in Step 300
# Valid loss  0.479 in Step 350
# Valid loss  0.503 in Step 400
# ※※※Valid loss  0.497※※※
# Epoch 15
# Training loss  0.345 in Step 0
# Training loss  0.324 in Step 100
# Training loss  0.377 in Step 200
# Training loss  0.340 in Step 300
# Training loss  0.342 in Step 400
# Training loss  0.354 in Step 500
# Training loss  0.336 in Step 600
# Training loss  0.359 in Step 700
# Training loss  0.399 in Step 800
# Training loss  0.357 in Step 900
# Training loss  0.358 in Step 1000
# Training loss  0.370 in Step 1100
# Training loss  0.343 in Step 1200
# Training loss  0.356 in Step 1300
# Training loss  0.329 in Step 1400
# Training loss  0.335 in Step 1500
# Training loss  0.342 in Step 1600
# Training loss  0.339 in Step 1700
# ※※※Training loss  0.352※※※
# Training timepoint saved
# Valid loss  0.525 in Step 0
# Valid loss  0.508 in Step 50
# Valid loss  0.529 in Step 100
# Valid loss  0.496 in Step 150
# Valid loss  0.510 in Step 200
# Valid loss  0.518 in Step 250
# Valid loss  0.508 in Step 300
# Valid loss  0.495 in Step 350
# Valid loss  0.518 in Step 400
# ※※※Valid loss  0.512※※※
# Epoch 16
# Training loss  0.356 in Step 0
# Training loss  0.365 in Step 100
# Training loss  0.338 in Step 200
# Training loss  0.382 in Step 300
# Training loss  0.369 in Step 400
# Training loss  0.349 in Step 500
# Training loss  0.352 in Step 600
# Training loss  0.337 in Step 700
# Training loss  0.354 in Step 800
# Training loss  0.312 in Step 900
# Training loss  0.333 in Step 1000
# Training loss  0.356 in Step 1100
# Training loss  0.368 in Step 1200
# Training loss  0.367 in Step 1300
# Training loss  0.386 in Step 1400
# Training loss  0.320 in Step 1500
# Training loss  0.338 in Step 1600
# Training loss  0.367 in Step 1700
# ※※※Training loss  0.351※※※
# Training timepoint saved
# Valid loss  0.531 in Step 0
# Valid loss  0.514 in Step 50
# Valid loss  0.535 in Step 100
# Valid loss  0.503 in Step 150
# Valid loss  0.517 in Step 200
# Valid loss  0.523 in Step 250
# Valid loss  0.511 in Step 300
# Valid loss  0.500 in Step 350
# Valid loss  0.521 in Step 400
# ※※※Valid loss  0.517※※※
# Epoch 17
# Training loss  0.368 in Step 0
# Training loss  0.325 in Step 100
# Training loss  0.347 in Step 200
# Training loss  0.347 in Step 300
# Training loss  0.361 in Step 400
# Training loss  0.320 in Step 500
# Training loss  0.338 in Step 600
# Training loss  0.336 in Step 700
# Training loss  0.357 in Step 800
# Training loss  0.363 in Step 900
# Training loss  0.328 in Step 1000
# Training loss  0.355 in Step 1100
# Training loss  0.323 in Step 1200
# Training loss  0.345 in Step 1300
# Training loss  0.365 in Step 1400
# Training loss  0.333 in Step 1500
# Training loss  0.383 in Step 1600
# Training loss  0.329 in Step 1700
# ※※※Training loss  0.350※※※
# Training timepoint saved
# Valid loss  0.537 in Step 0
# Valid loss  0.520 in Step 50
# Valid loss  0.540 in Step 100
# Valid loss  0.509 in Step 150
# Valid loss  0.523 in Step 200
# Valid loss  0.528 in Step 250
# Valid loss  0.519 in Step 300
# Valid loss  0.506 in Step 350
# Valid loss  0.528 in Step 400
# ※※※Valid loss  0.523※※※
# Epoch 18
# Training loss  0.344 in Step 0
# Training loss  0.351 in Step 100
# Training loss  0.346 in Step 200
# Training loss  0.338 in Step 300
# Training loss  0.371 in Step 400
# Training loss  0.350 in Step 500
# Training loss  0.338 in Step 600
# Training loss  0.361 in Step 700
# Training loss  0.329 in Step 800
# Training loss  0.336 in Step 900
# Training loss  0.361 in Step 1000
# Training loss  0.346 in Step 1100
# Training loss  0.367 in Step 1200
# Training loss  0.340 in Step 1300
# Training loss  0.400 in Step 1400
# Training loss  0.357 in Step 1500
# Training loss  0.369 in Step 1600
# Training loss  0.367 in Step 1700
# ※※※Training loss  0.350※※※
# Training timepoint saved
# Valid loss  0.550 in Step 0
# Valid loss  0.535 in Step 50
# Valid loss  0.555 in Step 100
# Valid loss  0.524 in Step 150
# Valid loss  0.538 in Step 200
# Valid loss  0.543 in Step 250
# Valid loss  0.533 in Step 300
# Valid loss  0.522 in Step 350
# Valid loss  0.543 in Step 400
# ※※※Valid loss  0.538※※※
# Epoch 19
# Training loss  0.342 in Step 0
# Training loss  0.363 in Step 100
# Training loss  0.324 in Step 200
# Training loss  0.375 in Step 300
# Training loss  0.344 in Step 400
# Training loss  0.368 in Step 500
# Training loss  0.350 in Step 600
# Training loss  0.334 in Step 700
# Training loss  0.308 in Step 800
# Training loss  0.352 in Step 900
# Training loss  0.341 in Step 1000
# Training loss  0.323 in Step 1100
# Training loss  0.347 in Step 1200
# Training loss  0.353 in Step 1300
# Training loss  0.311 in Step 1400
# Training loss  0.321 in Step 1500
# Training loss  0.382 in Step 1600
# Training loss  0.341 in Step 1700
# ※※※Training loss  0.349※※※
# Training timepoint saved
# Valid loss  0.567 in Step 0
# Valid loss  0.550 in Step 50
# Valid loss  0.570 in Step 100
# Valid loss  0.538 in Step 150
# Valid loss  0.553 in Step 200
# Valid loss  0.560 in Step 250
# Valid loss  0.547 in Step 300
# Valid loss  0.535 in Step 350
# Valid loss  0.555 in Step 400
# ※※※Valid loss  0.552※※※
# Epoch 20
# Training loss  0.346 in Step 0
# Training loss  0.344 in Step 100
# Training loss  0.339 in Step 200
# Training loss  0.328 in Step 300
# Training loss  0.322 in Step 400
# Training loss  0.336 in Step 500
# Training loss  0.358 in Step 600
# Training loss  0.341 in Step 700
# Training loss  0.345 in Step 800
# Training loss  0.345 in Step 900
# Training loss  0.318 in Step 1000
# Training loss  0.362 in Step 1100
# Training loss  0.322 in Step 1200
# Training loss  0.316 in Step 1300
# Training loss  0.378 in Step 1400
# Training loss  0.330 in Step 1500
# Training loss  0.352 in Step 1600
# Training loss  0.344 in Step 1700
# ※※※Training loss  0.348※※※
# Training timepoint saved
# Valid loss  0.585 in Step 0
# Valid loss  0.569 in Step 50
# Valid loss  0.587 in Step 100
# Valid loss  0.553 in Step 150
# Valid loss  0.575 in Step 200
# Valid loss  0.580 in Step 250
# Valid loss  0.568 in Step 300
# Valid loss  0.558 in Step 350
# Valid loss  0.578 in Step 400
# ※※※Valid loss  0.572※※※
# Epoch 21
# Training loss  0.383 in Step 0
# Training loss  0.346 in Step 100
# Training loss  0.357 in Step 200
# Training loss  0.382 in Step 300
# Training loss  0.342 in Step 400
# Training loss  0.357 in Step 500
# Training loss  0.345 in Step 600
# Training loss  0.365 in Step 700
# Training loss  0.341 in Step 800
# Training loss  0.325 in Step 900
# Training loss  0.359 in Step 1000
# Training loss  0.366 in Step 1100
# Training loss  0.348 in Step 1200
# Training loss  0.368 in Step 1300
# Training loss  0.362 in Step 1400
# Training loss  0.359 in Step 1500
# Training loss  0.352 in Step 1600
# Training loss  0.333 in Step 1700
# ※※※Training loss  0.348※※※
# Training timepoint saved
# Valid loss  0.600 in Step 0
# Valid loss  0.588 in Step 50
# Valid loss  0.605 in Step 100
# Valid loss  0.572 in Step 150
# Valid loss  0.592 in Step 200
# Valid loss  0.597 in Step 250
# Valid loss  0.586 in Step 300
# Valid loss  0.577 in Step 350
# Valid loss  0.597 in Step 400
# ※※※Valid loss  0.590※※※
# Epoch 22
# Training loss  0.319 in Step 0
# Training loss  0.341 in Step 100
# Training loss  0.322 in Step 200
# Training loss  0.340 in Step 300
# Training loss  0.366 in Step 400
# Training loss  0.362 in Step 500
# Training loss  0.341 in Step 600
# Training loss  0.372 in Step 700
# Training loss  0.338 in Step 800
# Training loss  0.348 in Step 900
# Training loss  0.352 in Step 1000
# Training loss  0.335 in Step 1100
# Training loss  0.338 in Step 1200
# Training loss  0.375 in Step 1300
# Training loss  0.337 in Step 1400
# Training loss  0.389 in Step 1500
# Training loss  0.364 in Step 1600
# Training loss  0.345 in Step 1700
# ※※※Training loss  0.347※※※
# Training timepoint saved
# Valid loss  0.590 in Step 0
# Valid loss  0.570 in Step 50
# Valid loss  0.591 in Step 100
# Valid loss  0.558 in Step 150
# Valid loss  0.576 in Step 200
# Valid loss  0.583 in Step 250
# Valid loss  0.569 in Step 300
# Valid loss  0.558 in Step 350
# Valid loss  0.577 in Step 400
# ※※※Valid loss  0.574※※※
# Epoch 23
# Training loss  0.321 in Step 0
# Training loss  0.332 in Step 100
# Training loss  0.364 in Step 200
# Training loss  0.316 in Step 300
# Training loss  0.373 in Step 400
# Training loss  0.343 in Step 500
# Training loss  0.335 in Step 600
# Training loss  0.341 in Step 700
# Training loss  0.367 in Step 800
# Training loss  0.369 in Step 900
# Training loss  0.346 in Step 1000
# Training loss  0.374 in Step 1100
# Training loss  0.398 in Step 1200
# Training loss  0.348 in Step 1300
# Training loss  0.379 in Step 1400
# Training loss  0.367 in Step 1500
# Training loss  0.328 in Step 1600
# Training loss  0.353 in Step 1700
# ※※※Training loss  0.347※※※
# Training timepoint saved
# Valid loss  0.596 in Step 0
# Valid loss  0.584 in Step 50
# Valid loss  0.601 in Step 100
# Valid loss  0.567 in Step 150
# Valid loss  0.589 in Step 200
# Valid loss  0.593 in Step 250
# Valid loss  0.582 in Step 300
# Valid loss  0.573 in Step 350
# Valid loss  0.592 in Step 400
# ※※※Valid loss  0.586※※※
# Epoch 24
# Training loss  0.351 in Step 0
# Training loss  0.339 in Step 100
# Training loss  0.380 in Step 200
# Training loss  0.346 in Step 300
# Training loss  0.330 in Step 400
# Training loss  0.344 in Step 500
# Training loss  0.353 in Step 600
# Training loss  0.351 in Step 700
# Training loss  0.362 in Step 800
# Training loss  0.349 in Step 900
# Training loss  0.331 in Step 1000
# Training loss  0.348 in Step 1100
# Training loss  0.328 in Step 1200
# Training loss  0.344 in Step 1300
# Training loss  0.335 in Step 1400
# Training loss  0.321 in Step 1500
# Training loss  0.355 in Step 1600
# Training loss  0.356 in Step 1700
# ※※※Training loss  0.346※※※
# Training timepoint saved
# Valid loss  0.609 in Step 0
# Valid loss  0.594 in Step 50
# Valid loss  0.610 in Step 100
# Valid loss  0.577 in Step 150
# Valid loss  0.600 in Step 200
# Valid loss  0.604 in Step 250
# Valid loss  0.593 in Step 300
# Valid loss  0.584 in Step 350
# Valid loss  0.604 in Step 400
# ※※※Valid loss  0.597※※※
# Epoch 25
# Training loss  0.341 in Step 0
# Training loss  0.353 in Step 100
# Training loss  0.304 in Step 200
# Training loss  0.370 in Step 300
# Training loss  0.367 in Step 400
# Training loss  0.353 in Step 500
# Training loss  0.351 in Step 600
# Training loss  0.380 in Step 700
# Training loss  0.331 in Step 800
# Training loss  0.316 in Step 900
# Training loss  0.350 in Step 1000
# Training loss  0.353 in Step 1100
# Training loss  0.378 in Step 1200
# Training loss  0.349 in Step 1300
# Training loss  0.323 in Step 1400
# Training loss  0.341 in Step 1500
# Training loss  0.352 in Step 1600
# Training loss  0.340 in Step 1700
# ※※※Training loss  0.346※※※
# Training timepoint saved
# Valid loss  0.633 in Step 0
# Valid loss  0.617 in Step 50
# Valid loss  0.636 in Step 100
# Valid loss  0.601 in Step 150
# Valid loss  0.623 in Step 200
# Valid loss  0.628 in Step 250
# Valid loss  0.616 in Step 300
# Valid loss  0.608 in Step 350
# Valid loss  0.626 in Step 400
# ※※※Valid loss  0.620※※※
# Epoch 26
# Training loss  0.330 in Step 0
# Training loss  0.338 in Step 100
# Training loss  0.358 in Step 200
# Training loss  0.349 in Step 300
# Training loss  0.331 in Step 400
# Training loss  0.330 in Step 500
# Training loss  0.353 in Step 600
# Training loss  0.343 in Step 700
# Training loss  0.346 in Step 800
# Training loss  0.333 in Step 900
# Training loss  0.353 in Step 1000
# Training loss  0.347 in Step 1100
# Training loss  0.319 in Step 1200
# Training loss  0.345 in Step 1300
# Training loss  0.332 in Step 1400
# Training loss  0.347 in Step 1500
# Training loss  0.342 in Step 1600
# Training loss  0.368 in Step 1700
# ※※※Training loss  0.345※※※
# Training timepoint saved
# Valid loss  0.608 in Step 0
# Valid loss  0.592 in Step 50
# Valid loss  0.612 in Step 100
# Valid loss  0.577 in Step 150
# Valid loss  0.597 in Step 200
# Valid loss  0.604 in Step 250
# Valid loss  0.593 in Step 300
# Valid loss  0.583 in Step 350
# Valid loss  0.603 in Step 400
# ※※※Valid loss  0.596※※※
# Epoch 27
# Training loss  0.386 in Step 0
# Training loss  0.371 in Step 100
# Training loss  0.348 in Step 200
# Training loss  0.353 in Step 300
# Training loss  0.347 in Step 400
# Training loss  0.331 in Step 500
# Training loss  0.337 in Step 600
# Training loss  0.328 in Step 700
# Training loss  0.335 in Step 800
# Training loss  0.349 in Step 900
# Training loss  0.354 in Step 1000
# Training loss  0.334 in Step 1100
# Training loss  0.339 in Step 1200
# Training loss  0.361 in Step 1300
# Training loss  0.291 in Step 1400
# Training loss  0.347 in Step 1500
# Training loss  0.378 in Step 1600
# Training loss  0.329 in Step 1700
# ※※※Training loss  0.345※※※
# Training timepoint saved
# Valid loss  0.621 in Step 0
# Valid loss  0.603 in Step 50
# Valid loss  0.622 in Step 100
# Valid loss  0.589 in Step 150
# Valid loss  0.608 in Step 200
# Valid loss  0.615 in Step 250
# Valid loss  0.603 in Step 300
# Valid loss  0.593 in Step 350
# Valid loss  0.613 in Step 400
# ※※※Valid loss  0.606※※※
# Epoch 28
# Training loss  0.342 in Step 0
# Training loss  0.382 in Step 100
# Training loss  0.349 in Step 200
# Training loss  0.340 in Step 300
# Training loss  0.371 in Step 400
# Training loss  0.340 in Step 500
# Training loss  0.341 in Step 600
# Training loss  0.344 in Step 700
# Training loss  0.373 in Step 800
# Training loss  0.350 in Step 900
# Training loss  0.316 in Step 1000
# Training loss  0.347 in Step 1100
# Training loss  0.362 in Step 1200
# Training loss  0.331 in Step 1300
# Training loss  0.364 in Step 1400
# Training loss  0.355 in Step 1500
# Training loss  0.308 in Step 1600
# Training loss  0.303 in Step 1700
# ※※※Training loss  0.345※※※
# Training timepoint saved
# Valid loss  0.630 in Step 0
# Valid loss  0.613 in Step 50
# Valid loss  0.630 in Step 100
# Valid loss  0.601 in Step 150
# Valid loss  0.618 in Step 200
# Valid loss  0.625 in Step 250
# Valid loss  0.610 in Step 300
# Valid loss  0.604 in Step 350
# Valid loss  0.619 in Step 400
# ※※※Valid loss  0.614※※※
# Epoch 29
# Training loss  0.380 in Step 0
# Training loss  0.368 in Step 100
# Training loss  0.337 in Step 200
# Training loss  0.364 in Step 300
# Training loss  0.343 in Step 400
# Training loss  0.368 in Step 500
# Training loss  0.373 in Step 600
# Training loss  0.319 in Step 700
# Training loss  0.328 in Step 800
# Training loss  0.355 in Step 900
# Training loss  0.368 in Step 1000
# Training loss  0.319 in Step 1100
# Training loss  0.332 in Step 1200
# Training loss  0.321 in Step 1300
# Training loss  0.361 in Step 1400
# Training loss  0.320 in Step 1500
# Training loss  0.355 in Step 1600
# Training loss  0.349 in Step 1700
# ※※※Training loss  0.344※※※
# Training timepoint saved
# Valid loss  0.656 in Step 0
# Valid loss  0.632 in Step 50
# Valid loss  0.650 in Step 100
# Valid loss  0.619 in Step 150
# Valid loss  0.641 in Step 200
# Valid loss  0.647 in Step 250
# Valid loss  0.630 in Step 300
# Valid loss  0.622 in Step 350
# Valid loss  0.640 in Step 400
# ※※※Valid loss  0.635※※※
# Epoch 30
# Training loss  0.316 in Step 0
# Training loss  0.353 in Step 100
# Training loss  0.336 in Step 200
# Training loss  0.351 in Step 300
# Training loss  0.359 in Step 400
# Training loss  0.370 in Step 500
# Training loss  0.315 in Step 600
# Training loss  0.345 in Step 700
# Training loss  0.348 in Step 800
# Training loss  0.360 in Step 900
# Training loss  0.349 in Step 1000
# Training loss  0.332 in Step 1100
# Training loss  0.354 in Step 1200
# Training loss  0.344 in Step 1300
# Training loss  0.355 in Step 1400
# Training loss  0.334 in Step 1500
# Training loss  0.327 in Step 1600
# Training loss  0.346 in Step 1700
# ※※※Training loss  0.345※※※
# Training timepoint saved
# Valid loss  0.659 in Step 0
# Valid loss  0.635 in Step 50
# Valid loss  0.653 in Step 100
# Valid loss  0.624 in Step 150
# Valid loss  0.643 in Step 200
# Valid loss  0.648 in Step 250
# Valid loss  0.634 in Step 300
# Valid loss  0.627 in Step 350
# Valid loss  0.644 in Step 400
# ※※※Valid loss  0.638※※※
# Epoch 31
# Training loss  0.383 in Step 0
# Training loss  0.335 in Step 100
# Training loss  0.309 in Step 200
# Training loss  0.373 in Step 300
# Training loss  0.338 in Step 400
# Training loss  0.380 in Step 500
# Training loss  0.351 in Step 600
# Training loss  0.363 in Step 700
# Training loss  0.320 in Step 800
# Training loss  0.310 in Step 900
# Training loss  0.340 in Step 1000
# Training loss  0.348 in Step 1100
# Training loss  0.333 in Step 1200
# Training loss  0.342 in Step 1300
# Training loss  0.317 in Step 1400
# Training loss  0.344 in Step 1500
# Training loss  0.369 in Step 1600
# Training loss  0.364 in Step 1700
# ※※※Training loss  0.343※※※
# Training timepoint saved
# Valid loss  0.679 in Step 0
# Valid loss  0.651 in Step 50
# Valid loss  0.669 in Step 100
# Valid loss  0.640 in Step 150
# Valid loss  0.662 in Step 200
# Valid loss  0.668 in Step 250
# Valid loss  0.649 in Step 300
# Valid loss  0.642 in Step 350
# Valid loss  0.656 in Step 400
# ※※※Valid loss  0.655※※※
# Epoch 32
# Training loss  0.325 in Step 0
# Training loss  0.359 in Step 100
# Training loss  0.340 in Step 200
# Training loss  0.345 in Step 300
# Training loss  0.325 in Step 400
# Training loss  0.375 in Step 500
# Training loss  0.366 in Step 600
# Training loss  0.358 in Step 700
# Training loss  0.349 in Step 800
# Training loss  0.348 in Step 900
# Training loss  0.357 in Step 1000
# Training loss  0.341 in Step 1100
# Training loss  0.350 in Step 1200
# Training loss  0.324 in Step 1300
# Training loss  0.326 in Step 1400
# Training loss  0.401 in Step 1500
# Training loss  0.335 in Step 1600
# Training loss  0.354 in Step 1700
# ※※※Training loss  0.343※※※
# Training timepoint saved
# Valid loss  0.650 in Step 0
# Valid loss  0.628 in Step 50
# Valid loss  0.649 in Step 100
# Valid loss  0.621 in Step 150
# Valid loss  0.635 in Step 200
# Valid loss  0.643 in Step 250
# Valid loss  0.628 in Step 300
# Valid loss  0.621 in Step 350
# Valid loss  0.637 in Step 400
# ※※※Valid loss  0.633※※※
# Epoch 33
# Training loss  0.342 in Step 0
# Training loss  0.338 in Step 100
# Training loss  0.348 in Step 200
# Training loss  0.317 in Step 300
# Training loss  0.342 in Step 400
# Training loss  0.374 in Step 500
# Training loss  0.322 in Step 600
# Training loss  0.331 in Step 700
# Training loss  0.354 in Step 800
# Training loss  0.394 in Step 900
# Training loss  0.330 in Step 1000
# Training loss  0.317 in Step 1100
# Training loss  0.343 in Step 1200
# Training loss  0.333 in Step 1300
# Training loss  0.333 in Step 1400
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /home/ldlmdl/Documents/wavln/scripts/A_09.ipynb Cell 25 line 2
#       <a href='vscode-notebook-cell:/home/ldlmdl/Documents/wavln/scripts/A_09.ipynb#X33sZmlsZQ%3D%3D?line=0'>1</a> if __name__ == "__main__":
# ----> <a href='vscode-notebook-cell:/home/ldlmdl/Documents/wavln/scripts/A_09.ipynb#X33sZmlsZQ%3D%3D?line=1'>2</a>     train()
#
# /home/ldlmdl/Documents/wavln/scripts/A_09.ipynb Cell 25 line 1
#      <a href='vscode-notebook-cell:/home/ldlmdl/Documents/wavln/scripts/A_09.ipynb#X33sZmlsZQ%3D%3D?line=13'>14</a> x = x.to(device)
#      <a href='vscode-notebook-cell:/home/ldlmdl/Documents/wavln/scripts/A_09.ipynb#X33sZmlsZQ%3D%3D?line=14'>15</a> y = y.to(device)
# ---> <a href='vscode-notebook-cell:/home/ldlmdl/Documents/wavln/scripts/A_09.ipynb#X33sZmlsZQ%3D%3D?line=16'>17</a> recon_x, attn_weight = model(x, x_lens, x_mask)
#      <a href='vscode-notebook-cell:/home/ldlmdl/Documents/wavln/scripts/A_09.ipynb#X33sZmlsZQ%3D%3D?line=18'>19</a> loss = model_loss.get_loss(recon_x, y, x_mask)
#      <a href='vscode-notebook-cell:/home/ldlmdl/Documents/wavln/scripts/A_09.ipynb#X33sZmlsZQ%3D%3D?line=20'>21</a> train_loss += loss.item()
#
# File ~/anaconda3/envs/wavln/lib/python3.11/site-packages/torch/nn/modules/module.py:1501, in Module._call_impl(self, *args, **kwargs)
#    1496 # If we don't have any hooks, we want to skip the rest of the logic in
#    1497 # this function, and just call forward.
#    1498 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1499         or _global_backward_pre_hooks or _global_backward_hooks
#    1500         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1501     return forward_call(*args, **kwargs)
#    1502 # Do not call functions when jit is used
#    1503 full_backward_hooks, non_full_backward_hooks = [], []
#
# File ~/Documents/wavln/scripts/model.py:603, in TwoLinPhxLearner.forward(self, inputs, input_lens, in_mask)
#     600 dec_hid, init_in = self.decoder.inits(batch_size=batch_size, device=self.device)
#     602 enc_out = self.encoder(inputs, input_lens, in_mask)
# --> 603 dec_out, attn_w = self.decoder(enc_out, in_mask, init_in, dec_hid)
#     604 return dec_out, attn_w
#
# File ~/anaconda3/envs/wavln/lib/python3.11/site-packages/torch/nn/modules/module.py:1501, in Module._call_impl(self, *args, **kwargs)
#    1496 # If we don't have any hooks, we want to skip the rest of the logic in
#    1497 # this function, and just call forward.
#    1498 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1499         or _global_backward_pre_hooks or _global_backward_hooks
#    1500         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1501     return forward_call(*args, **kwargs)
#    1502 # Do not call functions when jit is used
#    1503 full_backward_hooks, non_full_backward_hooks = [], []
#
# File ~/Documents/wavln/scripts/model.py:517, in LRALDecoder.forward(self, hid_r, in_mask, init_in, hidden)
#     515 dec_x, hidden = self.rnn(dec_x, hidden)
#     516 # dec_x = self.lin_2(dec_x)
# --> 517 dec_x, attention_weight = self.attention(dec_x, hid_r, hid_r, in_mask.unsqueeze(1))    # unsqueeze mask here for broadcast
#     518 dec_x = self.lin_3(dec_x)
#     519 # dec_x = self.act(dec_x)
#
# File ~/anaconda3/envs/wavln/lib/python3.11/site-packages/torch/nn/modules/module.py:1501, in Module._call_impl(self, *args, **kwargs)
#    1496 # If we don't have any hooks, we want to skip the rest of the logic in
#    1497 # this function, and just call forward.
#    1498 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1499         or _global_backward_pre_hooks or _global_backward_hooks
#    1500         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1501     return forward_call(*args, **kwargs)
#    1502 # Do not call functions when jit is used
#    1503 full_backward_hooks, non_full_backward_hooks = [], []
#
# File ~/Documents/wavln/scripts/attention.py:27, in ScaledDotProductAttention.forward(self, q, k, v, mask)
#      24 v = self.w_v(v)
#      26 # Step 1: Compute the dot product between queries and keys
# ---> 27 attn_scores = torch.bmm(q, k.transpose(1, 2))  # (batch_size, num_queries, num_keys)
#      29 # Step 2: Scale the attention scores
#      30 attn_scores = attn_scores / (self.d_k ** 0.5)
#
# KeyboardInterrupt:

# %%
### Save
train_losses.save()

valid_losses.save()

text_hist.save()

# %%
plt.plot(train_losses.get(), label='Train')
plt.plot(valid_losses.get(), label='Valid')
plt.title("Learning Curve Loss")
plt.legend()

# %% [markdown]
# ## Conclusion
# This model should converge to loss around 0.49x.
